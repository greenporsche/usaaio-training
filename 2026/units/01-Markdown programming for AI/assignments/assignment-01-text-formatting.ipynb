# %% [markdown]
# # Assignment 01 — Text Formatting for USAAIO (100 points)
#
# **Unit**: AI 100 — Markdown Programming for AI
# **Competition alignment**: USAAIO 2026 Round 1 (paper-based)
#
# ---
#
# ## Background
#
# The USAAIO Round 1 paper-based component requires contestants to write solutions in Google Colab text cells using Markdown. Clear formatting is not optional — it is how you communicate your answer to the grader. A correct derivation that the grader cannot parse will lose points.
#
# In this assignment you will practice the core Markdown formatting skills needed for USAAIO: headings, emphasis, lists, tables, blockquotes, and links. Every problem is modeled on real USAAIO solution formats.
#
# ## Notation
#
# | Symbol / Syntax | Meaning |
# |---|---|
# | `#` through `######` | Heading levels 1–6 |
# | `**text**` | Bold |
# | `*text*` | Italic |
# | `- item` | Unordered list item |
# | `1. item` | Ordered list item |
# | `\|` | Table column separator |
# | `> text` | Blockquote |

# %%
"""
DO NOT MAKE ANY CHANGE IN THIS CELL.
"""
# No imports needed for this assignment.
# All solutions are written in Markdown cells.
# This cell exists only to maintain the standard USAAIO notebook structure.

# %% [markdown]
# > **WARNING !!!**
# >
# - This assignment tests your ability to write **Markdown in text cells**, not Python code.
# - All solutions should be written in **markdown cells** unless a code cell is explicitly provided.
# - Render each cell with `Shift+Enter` to verify your formatting looks correct.
# - **Rule of thumb:** Each part has its particular purpose to intentionally test a specific formatting skill. Do not skip the formatting requirements even if you know the content.

# %% [markdown]
# ---
#
# ## Part 1 (10 points, non-coding task)
#
# **Document Structure**
#
# Create a properly structured USAAIO solution header. Your markdown cell must contain **all** of the following, in this order:
#
# 1. An H1 heading: `USAAIO 2026 Round 1`
# 2. An H2 heading: `Student: [Your Name]`
# 3. A horizontal rule (`---`)
# 4. An H2 heading: `Problem 8: Classification Metrics`
# 5. A brief italicized note: `All computations shown below.`
# 6. An H3 heading: `Part 8.1: Accuracy`
#
# When rendered, the heading hierarchy should be visually distinct (H1 largest, H3 smallest).
#
# *Reasoning is not required.*

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
#
# ## Part 2 (15 points, non-coding task)
#
# **Confusion Matrix Table**
#
# A binary classifier produces the following results on a test set of 200 samples:
#
# - True Positives: 80
# - False Positives: 15
# - True Negatives: 90
# - False Negatives: 15
#
# Create a Markdown table representing this confusion matrix with the following requirements:
#
# **(a)** (10 points) Build the table with:
# - Row headers in **bold**: `**Actual Positive**`, `**Actual Negative**`
# - Column headers: `Predicted Positive`, `Predicted Negative`
# - Each cell contains the count followed by the label in parentheses, e.g., `80 (TP)`
# - Center-align the numeric columns using `:---:` syntax
#
# **(b)** (5 points) Below the table, add a single line stating the total number of samples using inline LaTeX: $N = TP + TN + FP + FN = 200$.
#
# *Reasoning is not required.*

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
#
# Now that you can build tables, the next skill is structuring step-by-step explanations. USAAIO solutions frequently describe algorithms as numbered procedures with technical terms highlighted.
#
# ---
#
# ## Part 3 (15 points, non-coding task)
#
# **Algorithm Description with Lists and Emphasis**
#
# Format the following k-Nearest Neighbors (kNN) algorithm as a properly structured Markdown cell.
#
# Raw unformatted text:
# ```
# step 1 choose k which is the number of neighbors
# step 2 compute the euclidean distance between the test point and all training points
# step 3 sort the distances from smallest to largest
# step 4 select the k nearest neighbors
# step 5 for classification take a majority vote among the k neighbors
# step 6 return the predicted class label
# ```
#
# Requirements:
# - Use an H3 heading: `### k-Nearest Neighbors Algorithm`
# - Use a **numbered list** for the steps
# - **Bold** the key action word in each step (e.g., **Choose**, **Compute**, **Sort**, **Select**, **Vote**, **Return**)
# - Use inline code (backticks) for technical terms: `k`, `Euclidean distance`
# - Under step 5, add a nested unordered sub-list with an alternative: "For **regression**, take the **mean** of the `k` neighbors' target values."
#
# *Reasoning is not required.*

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
#
# ## Part 4 (15 points, non-coding task)
#
# **Hyperparameter Comparison Table**
#
# A student ran a grid search over kNN hyperparameters and obtained these results:
#
# | Config | k | Accuracy | F1-Score | Training Time |
# |:---|:---|:---|:---|:---|
# | A | 1 | 0.72 | 0.68 | 0.1s |
# | B | 3 | 0.81 | 0.79 | 0.2s |
# | C | 5 | 0.85 | 0.83 | 0.3s |
# | D | 7 | 0.83 | 0.81 | 0.3s |
# | E | 11 | 0.80 | 0.78 | 0.4s |
#
# **(a)** (10 points) Recreate this table with:
# - Left-aligned first two columns (Config, k)
# - Right-aligned numeric columns (Accuracy, F1-Score, Training Time)
# - **Bold the entire row** for the configuration with the best accuracy
# - Add an H3 heading above the table: `### Hyperparameter Search Results`
#
# **(b)** (5 points) Below the table, add a **blockquote** that summarizes the result:
# > **Best configuration**: Config C with `k=5` achieves the highest accuracy of **0.85** and F1-score of **0.83**.
#
# *Reasoning is not required.*

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
#
# ## Part 5 (10 points, non-coding task)
#
# **Error Detection and Correction**
#
# The following Markdown contains **6 errors**. Find each error, explain what is wrong, and provide the corrected version.
#
# ```markdown
# #Problem 8
#
# ##Part 8.1
#
# The accuracy is **0.85.
#
# We compute it using the formula:
# - Step 1: Add TP + TN = 85
# - Step 2; Divide by total = 100
#   -Step 3: Result = 0.85
#
# The answer is [85%].
# ```
#
# **(a)** (5 points) List all 6 errors with a brief description of each.
#
# **(b)** (5 points) Write the corrected Markdown.
#
# *Reasoning is required.*

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
#
# Parts 1–5 tested individual formatting skills in isolation. In a real USAAIO submission, you must combine all of these simultaneously: headings for structure, tables for data, bold for answers, LaTeX for formulas, and lists for procedures. The final part tests this integration.
#
# ---
#
# ## Part 6 (35 points, non-coding task)
#
# **Complete USAAIO Solution Formatting**
#
# Format a complete USAAIO Round 1 solution for the following problem. Your answer must combine headings, tables, bold emphasis, inline and display LaTeX, numbered derivation steps, and a comparison table.
#
# **Problem Statement**: A kNN classifier is evaluated on a dataset of 200 samples with the following confusion matrix:
#
# | | Predicted + | Predicted - |
# |---|---|---|
# | Actual + | 60 (TP) | 15 (FN) |
# | Actual - | 10 (FP) | 115 (TN) |
#
# **(a)** (10 points) Present the confusion matrix as a properly formatted Markdown table (bold row headers, center-aligned numbers).
#
# **(b)** (10 points) Compute all four metrics using display-mode LaTeX formulas. Show each formula, substitute values, and bold the final answer:
# - Accuracy: $\frac{TP + TN}{N}$
# - Precision: $\frac{TP}{TP + FP}$
# - Recall: $\frac{TP}{TP + FN}$
# - F1-Score: $2 \cdot \frac{P \cdot R}{P + R}$
#
# **(c)** (10 points) The model is retrained with `StandardScaler` preprocessing. New results: TP=70, FP=8, FN=5, TN=117. Compute the same four metrics and present a **comparison table** with columns: Metric, Without Scaling, With Scaling, Improvement.
#
# **(d)** (5 points) Write a concluding paragraph in a **blockquote** explaining which model is better and why, referencing specific metric improvements.
#
# *Reasoning is required for parts (b) and (d).*

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """
