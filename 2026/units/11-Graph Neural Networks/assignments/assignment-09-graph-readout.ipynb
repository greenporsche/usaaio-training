# %% [markdown]
# # Assignment 09: Graph-Level Readout (100 points)
#
# Compare mean, sum, and max pooling for graph-level representations. Understand the theoretical and practical differences between readout functions.
#
# **Topics:** Readout functions, multiset distinguishability, graph isomorphism, pooling properties

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, GINConv, global_mean_pool, global_add_pool, global_max_pool
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader

# %% [markdown]
# ---
#
# **WARNING:** Do not modify any cell that you are not explicitly asked to modify. Do not add or remove cells.

# %% [markdown]
# ## Part 1: Manual Readout Implementation (15 points)
#
# Implement mean, sum, and max readout from scratch (without PyG's pooling functions).
#
# Given node embeddings and a batch vector, compute graph-level embeddings.

# %%
def manual_readout(
    x: torch.FloatTensor,
    batch: torch.LongTensor,
    mode: str = "mean"
) -> torch.FloatTensor:
    """
    Compute graph-level embeddings from node embeddings.

    Args:
        x: Node embeddings of shape (total_nodes, F)
        batch: Graph assignment vector of shape (total_nodes,)
               batch[i] = index of graph that node i belongs to
        mode: "mean", "sum", or "max"

    Returns:
        graph_emb: Graph embeddings of shape (num_graphs, F)
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Multiset Distinguishability (20 points)
#
# Demonstrate that sum readout is more expressive than mean and max.
#
# Create three graphs with carefully chosen node features such that:
# - Graph A and Graph B can be distinguished by sum but not by mean
# - Graph B and Graph C can be distinguished by sum but not by max
#
# Return the graph embeddings under each readout and boolean flags for distinguishability.

# %%
def distinguishability_demo() -> dict:
    """
    Demonstrate expressiveness differences between readout functions.

    Returns:
        result: dict with keys:
            - graphs: dict mapping "A"/"B"/"C" -> node features tensor
            - embeddings: dict mapping readout -> dict of graph embeddings
            - sum_distinguishes_AB: bool
            - mean_distinguishes_AB: bool
            - sum_distinguishes_BC: bool
            - max_distinguishes_BC: bool
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 3: GCN + Readout Model (20 points)
#
# Build a graph classification model with configurable readout. Use 3 GCN layers followed by the chosen readout and a 2-layer MLP.
#
# Include **batch normalization** after each GCN layer.

# %%
class ReadoutModel(nn.Module):
    """
    GCN + configurable readout + MLP.

    Args:
        in_features: Node feature dimension
        hidden_dim: GCN and MLP hidden dimension
        num_classes: Number of graph classes
        readout: "mean", "sum", or "max"
        dropout: Dropout rate
    """

    def __init__(self, in_features, hidden_dim, num_classes, readout="mean", dropout=0.5):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

    def forward(self, x, edge_index, batch):
        """
        Returns:
            out: Log-probabilities (num_graphs, num_classes)
        """
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Readout Comparison on PROTEINS (25 points)
#
# Compare mean, sum, and max readout on the PROTEINS dataset.
#
# For each readout:
# - Use 10-fold cross-validation
# - Train for 100 epochs per fold
# - Report mean and std of test accuracy across folds

# %%
def readout_comparison_proteins(
    num_folds: int = 10,
    num_epochs: int = 100,
    hidden_dim: int = 64
) -> dict:
    """
    10-fold CV comparison of readout functions on PROTEINS.

    Returns:
        results: dict mapping readout_name -> {
            "mean_acc": float,
            "std_acc": float,
            "fold_accs": list of float
        }
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Combined Readout (20 points)
#
# Implement a **combined readout** that concatenates mean, sum, and max pooling:
#
# $$h_G = [\text{mean}(\{h_v\}) \| \text{sum}(\{h_v\}) \| \text{max}(\{h_v\})]$$
#
# The graph embedding dimension is $3F$ instead of $F$.
#
# Compare this combined readout against individual readouts on PROTEINS.

# %%
class CombinedReadoutModel(nn.Module):
    """
    GCN + combined (mean||sum||max) readout + MLP.

    Output graph embedding dimension is 3 * hidden_dim.
    """

    def __init__(self, in_features, hidden_dim, num_classes, dropout=0.5):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

    def forward(self, x, edge_index, batch):
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """


def compare_combined_readout(num_folds: int = 10, num_epochs: int = 100) -> dict:
    """
    Compare combined readout vs individual readouts.

    Returns:
        results: dict with "combined", "mean", "sum", "max" keys,
                 each mapping to {"mean_acc": float, "std_acc": float}
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """
