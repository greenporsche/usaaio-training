# %% [markdown]
# # Assignment 08: Link Prediction (100 points)
#
# Predict missing edges in a graph using GNN-based node embeddings and scoring functions.
#
# **Topics:** Link prediction, negative sampling, dot-product scoring, AUC-ROC, train/test edge splitting

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid
from torch_geometric.nn import GCNConv
from torch_geometric.utils import negative_sampling
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ---
#
# **WARNING:** Do not modify any cell that you are not explicitly asked to modify. Do not add or remove cells.

# %% [markdown]
# ## Part 1: Train/Test Edge Split (20 points)
#
# Split the edges of the Cora graph into training (85%) and test (15%) sets.
#
# For the test set, also sample an equal number of **negative edges** (non-existing edges) for evaluation.
#
# The training graph should only contain training edges.

# %%
def split_edges(
    data,
    test_ratio: float = 0.15,
    seed: int = 42
):
    """
    Split edges into train and test sets.

    Args:
        data: PyG Data object
        test_ratio: Fraction of edges for testing
        seed: Random seed

    Returns:
        train_edge_index: LongTensor (2, num_train_edges) — training edges
        test_pos_edge_index: LongTensor (2, num_test_edges) — positive test edges
        test_neg_edge_index: LongTensor (2, num_test_edges) — negative test edges
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 2: GCN Encoder (15 points)
#
# Build a 2-layer GCN that outputs node embeddings (not class probabilities).
#
# No softmax at the end — the raw embeddings will be used for link scoring.

# %%
class GCNEncoder(nn.Module):
    """
    GCN encoder that produces node embeddings.

    Args:
        in_features: Input feature dimension
        hidden_dim: Hidden layer dimension
        out_dim: Output embedding dimension
    """

    def __init__(self, in_features: int, hidden_dim: int, out_dim: int):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

    def forward(self, x, edge_index):
        """
        Returns:
            z: Node embeddings of shape (N, out_dim)
        """
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Link Scoring Functions (20 points)
#
# Implement three scoring functions for edge $(u, v)$ given embeddings $z_u, z_v$:
#
# 1. **Dot product:** $s_{uv} = z_u^T z_v$
# 2. **Cosine similarity:** $s_{uv} = \frac{z_u^T z_v}{\|z_u\| \|z_v\|}$
# 3. **MLP:** $s_{uv} = \text{MLP}([z_u \| z_v])$
#
# Each function takes pairs of node embeddings and returns scores.

# %%
def dot_product_score(z: torch.FloatTensor, edge_index: torch.LongTensor) -> torch.FloatTensor:
    """
    Dot product scoring for edge pairs.

    Args:
        z: Node embeddings (N, D)
        edge_index: Edge pairs (2, M)

    Returns:
        scores: (M,) dot product scores
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """


def cosine_score(z: torch.FloatTensor, edge_index: torch.LongTensor) -> torch.FloatTensor:
    """
    Cosine similarity scoring.

    Returns:
        scores: (M,) cosine similarity scores
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """


class MLPScore(nn.Module):
    """
    MLP-based edge scoring: MLP([z_u || z_v]) -> scalar.

    Args:
        embed_dim: Dimension of node embeddings D
        hidden_dim: MLP hidden dimension
    """

    def __init__(self, embed_dim: int, hidden_dim: int = 64):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

    def forward(self, z: torch.FloatTensor, edge_index: torch.LongTensor) -> torch.FloatTensor:
        """
        Returns:
            scores: (M,) MLP scores
        """
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Training Loop (25 points)
#
# Train the GCN encoder for link prediction:
#
# 1. Encode all nodes using training edges: $Z = \text{GCN}(X, \text{train\_edges})$
# 2. Sample negative edges for the batch
# 3. Score positive and negative edges
# 4. Compute BCE loss
# 5. Evaluate on test edges using AUC-ROC

# %%
def train_link_predictor(
    hidden_dim: int = 64,
    embed_dim: int = 32,
    lr: float = 0.01,
    num_epochs: int = 200
) -> dict:
    """
    Train a GCN-based link predictor on Cora.

    Args:
        hidden_dim: GCN hidden dimension
        embed_dim: Output embedding dimension
        lr: Learning rate
        num_epochs: Training epochs

    Returns:
        results: dict with keys:
            - train_losses: list of float
            - test_aucs: list of float (AUC per epoch)
            - best_auc: float
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Scoring Function Comparison (20 points)
#
# Compare dot-product and cosine scoring on the link prediction task.
#
# Train the same GCN encoder but evaluate with both scoring functions.
#
# Report AUC-ROC for each and analyze differences.

# %%
def compare_scoring_functions() -> dict:
    """
    Train a link predictor and compare dot-product vs cosine scoring.

    Returns:
        results: dict with keys:
            - dot_auc: float — test AUC with dot product
            - cosine_auc: float — test AUC with cosine similarity
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """
