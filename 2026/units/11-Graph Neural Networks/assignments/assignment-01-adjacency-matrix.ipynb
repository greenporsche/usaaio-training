# %% [markdown]
# # Assignment 01: Adjacency Matrix Operations (100 points)
#
# Build adjacency matrices, compute degree matrices, and perform normalization — the foundational operations of Graph Neural Networks.
#
# **Topics:** Graph representation, adjacency matrix, degree matrix, symmetric normalization, self-loops

# %%
import numpy as np
import torch

# %% [markdown]
# ---
#
# **WARNING:** Do not modify any cell that you are not explicitly asked to modify. Do not add or remove cells.

# %% [markdown]
# ## Part 1: Build an Adjacency Matrix (15 points)
#
# Given an edge list for an **undirected** graph with 5 nodes (0-indexed), construct the adjacency matrix.
#
# ```
# edges = [(0,1), (0,2), (1,2), (1,3), (3,4)]
# ```
#
# Return a `torch.FloatTensor` of shape `(5, 5)`.

# %%
def build_adjacency_matrix(edges: list[tuple[int, int]], num_nodes: int) -> torch.FloatTensor:
    """
    Build an adjacency matrix from an edge list.

    Args:
        edges: List of (src, dst) tuples representing undirected edges
        num_nodes: Number of nodes in the graph

    Returns:
        A: torch.FloatTensor of shape (num_nodes, num_nodes)
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Degree Matrix (15 points)
#
# Compute the degree matrix $D$ from an adjacency matrix. $D$ is diagonal with $D_{ii} = \sum_j A_{ij}$.
#
# Return a `torch.FloatTensor` of shape `(N, N)`.

# %%
def compute_degree_matrix(A: torch.FloatTensor) -> torch.FloatTensor:
    """
    Compute the degree matrix from an adjacency matrix.

    Args:
        A: Adjacency matrix of shape (N, N)

    Returns:
        D: Degree matrix of shape (N, N), diagonal
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Add Self-Loops (10 points)
#
# Compute $\hat{A} = A + I$ and the corresponding $\hat{D}$.
#
# Return both as `torch.FloatTensor`.

# %%
def add_self_loops(A: torch.FloatTensor) -> tuple[torch.FloatTensor, torch.FloatTensor]:
    """
    Add self-loops to the adjacency matrix and compute the new degree matrix.

    Args:
        A: Adjacency matrix of shape (N, N)

    Returns:
        A_hat: (N, N) adjacency matrix with self-loops
        D_hat: (N, N) degree matrix of A_hat
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Symmetric Normalization (20 points)
#
# Compute the symmetrically normalized adjacency matrix:
#
# $$\tilde{A} = \hat{D}^{-1/2} \hat{A} \hat{D}^{-1/2}$$
#
# Use $\hat{A} = A + I$ and $\hat{D}$ from Part 3.
#
# Return a `torch.FloatTensor` of shape `(N, N)`.

# %%
def symmetric_normalization(A: torch.FloatTensor) -> torch.FloatTensor:
    """
    Compute the symmetrically normalized adjacency with self-loops.

    Args:
        A: Adjacency matrix of shape (N, N)

    Returns:
        A_tilde: Normalized adjacency of shape (N, N)
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Propagation (20 points)
#
# Given the normalized adjacency $\tilde{A}$ and node features $X \in \mathbb{R}^{N \times F}$, compute a single propagation step:
#
# $$H = \tilde{A} X W$$
#
# where $W \in \mathbb{R}^{F \times F'}$ is a weight matrix.
#
# Use the following test data:
# - 5-node graph from Part 1
# - $X \in \mathbb{R}^{5 \times 3}$: random features
# - $W \in \mathbb{R}^{3 \times 2}$: random weights
#
# Return $H$ of shape `(N, F')`.

# %%
def propagate(A_tilde: torch.FloatTensor, X: torch.FloatTensor, W: torch.FloatTensor) -> torch.FloatTensor:
    """
    Perform one GCN-style propagation step: H = A_tilde @ X @ W

    Args:
        A_tilde: Normalized adjacency of shape (N, N)
        X: Node features of shape (N, F)
        W: Weight matrix of shape (F, F')

    Returns:
        H: Output features of shape (N, F')
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 6: Edge List to COO Format (20 points)
#
# Convert an edge list for an **undirected** graph into PyTorch Geometric's COO format: a `(2, 2*M)` LongTensor where each undirected edge appears twice (once in each direction).
#
# Also implement the reverse: convert COO back to an adjacency matrix.

# %%
def edges_to_coo(edges: list[tuple[int, int]], num_nodes: int) -> torch.LongTensor:
    """
    Convert edge list to PyG COO format for an undirected graph.

    Each undirected edge (i, j) should produce two directed entries: (i,j) and (j,i).

    Args:
        edges: List of (src, dst) tuples
        num_nodes: Number of nodes

    Returns:
        edge_index: LongTensor of shape (2, 2*len(edges))
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """


def coo_to_adjacency(edge_index: torch.LongTensor, num_nodes: int) -> torch.FloatTensor:
    """
    Convert COO edge_index back to a dense adjacency matrix.

    Args:
        edge_index: LongTensor of shape (2, num_edges)
        num_nodes: Number of nodes

    Returns:
        A: FloatTensor of shape (num_nodes, num_nodes)
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """
