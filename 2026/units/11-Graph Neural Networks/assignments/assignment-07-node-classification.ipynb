# %% [markdown]
# # Assignment 07: Node Classification (100 points)
#
# Perform semi-supervised node classification on a citation network using GCN and GAT. Explore the effect of label rate and model architecture.
#
# **Topics:** Semi-supervised learning, transductive setting, label propagation, GCN vs GAT

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid
from torch_geometric.nn import GCNConv, GATConv

# %% [markdown]
# ---
#
# **WARNING:** Do not modify any cell that you are not explicitly asked to modify. Do not add or remove cells.

# %% [markdown]
# ## Part 1: Dataset Preparation (10 points)
#
# Load the Cora dataset and create custom train/val/test masks with a configurable label rate.
#
# - `label_rate`: fraction of nodes used for training (e.g., 0.05 = 5%)
# - Stratified: maintain class balance in the training set
# - 20% of remaining for validation, 80% for test

# %%
def create_masks(data, label_rate: float = 0.05, seed: int = 42):
    """
    Create stratified train/val/test masks.

    Args:
        data: PyG Data object
        label_rate: Fraction of nodes for training
        seed: Random seed

    Returns:
        train_mask: BoolTensor (N,)
        val_mask: BoolTensor (N,)
        test_mask: BoolTensor (N,)
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 2: GCN Model (15 points)
#
# Build a configurable GCN model using PyG's `GCNConv`:
# - Variable number of layers (2-4)
# - Hidden dimension configurable
# - Dropout between layers
# - ReLU activation (except last layer)

# %%
class NodeGCN(nn.Module):
    """
    GCN for node classification with configurable depth.

    Args:
        in_features: Input feature dim
        hidden_dim: Hidden layer dim
        num_classes: Number of classes
        num_layers: Number of GCN layers (>= 2)
        dropout: Dropout rate
    """

    def __init__(self, in_features, hidden_dim, num_classes, num_layers=2, dropout=0.5):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

    def forward(self, x, edge_index):
        """
        Returns:
            out: Log-probabilities (N, num_classes)
        """
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 3: GAT Model (20 points)
#
# Build a 2-layer GAT model using PyG's `GATConv`:
# - Layer 1: multi-head attention (8 heads, 8 dim per head) with ELU
# - Layer 2: single head, output `num_classes`
# - Dropout on both inputs and attention coefficients

# %%
class NodeGAT(nn.Module):
    """
    GAT for node classification.

    Args:
        in_features: Input dim
        num_classes: Number of classes
        hidden_per_head: Dim per attention head
        num_heads: Number of heads in layer 1
        dropout: Dropout rate
    """

    def __init__(self, in_features, num_classes, hidden_per_head=8,
                 num_heads=8, dropout=0.6):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

    def forward(self, x, edge_index):
        """
        Returns:
            out: Log-probabilities (N, num_classes)
        """
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Training and Comparison (30 points)
#
# Train both GCN and GAT on Cora with the default split. Compare:
# - Final test accuracy
# - Training curves (loss and validation accuracy)
# - Number of parameters
#
# Return a comparison dictionary.

# %%
def compare_gcn_gat(
    num_epochs: int = 200,
    lr: float = 0.005,
    weight_decay: float = 5e-4
) -> dict:
    """
    Train GCN and GAT on Cora, compare results.

    Returns:
        comparison: dict with keys "gcn" and "gat", each containing:
            - test_acc: float
            - val_acc: float
            - num_params: int
            - train_losses: list of float
            - val_accs: list of float
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Label Rate Experiment (25 points)
#
# Investigate how the number of labeled nodes affects performance.
#
# Train a GCN with label rates: 1%, 2%, 5%, 10%, 20%, 50%.
#
# For each label rate:
# - Create new masks with `create_masks`
# - Train for 200 epochs
# - Record best test accuracy
#
# **Expected:** More labels should improve performance, but GNNs can work surprisingly well with very few labels due to graph structure.

# %%
def label_rate_experiment(
    label_rates: list[float] = [0.01, 0.02, 0.05, 0.1, 0.2, 0.5]
) -> dict[float, float]:
    """
    Test GCN performance across different label rates.

    Args:
        label_rates: List of training label fractions

    Returns:
        results: dict mapping label_rate -> best test accuracy
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """
