# %% [markdown]
# # Assignment 04: GCN with PyTorch Geometric (100 points)
#
# Use PyTorch Geometric (PyG) to build and train a GCN for node classification on the Cora citation dataset.
#
# **Topics:** PyG data objects, GCNConv, training pipeline, evaluation, hyperparameter tuning

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.datasets import Planetoid
from torch_geometric.nn import GCNConv

# %% [markdown]
# ---
#
# **WARNING:** Do not modify any cell that you are not explicitly asked to modify. Do not add or remove cells.

# %% [markdown]
# ## Part 1: Load and Explore the Cora Dataset (10 points)
#
# Load the Cora dataset using `Planetoid`. Print the following:
# - Number of nodes, edges, features, and classes
# - Shape of node features `data.x`
# - Shape of edge index `data.edge_index`
# - Number of training, validation, and test nodes
#
# Return a dictionary with keys: `num_nodes`, `num_edges`, `num_features`, `num_classes`, `num_train`, `num_val`, `num_test`.

# %%
def explore_cora() -> dict:
    """
    Load Cora and return dataset statistics.

    Returns:
        stats: dict with keys num_nodes, num_edges, num_features,
               num_classes, num_train, num_val, num_test
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Build a GCN Model with PyG (20 points)
#
# Build a 2-layer GCN using `GCNConv`:
# - Layer 1: `num_features` -> `hidden_dim` with ReLU and dropout
# - Layer 2: `hidden_dim` -> `num_classes`
# - Output: log-softmax
#
# Use `GCNConv` from `torch_geometric.nn`.

# %%
class GCN_PyG(nn.Module):
    """
    2-layer GCN using PyTorch Geometric's GCNConv.

    Args:
        num_features: Input feature dimension
        hidden_dim: Hidden layer dimension
        num_classes: Number of output classes
        dropout: Dropout probability
    """

    def __init__(self, num_features: int, hidden_dim: int, num_classes: int, dropout: float = 0.5):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

    def forward(self, data):
        """
        Forward pass.

        Args:
            data: PyG Data object with data.x and data.edge_index

        Returns:
            out: Log-probabilities of shape (N, num_classes)
        """
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Training and Evaluation (25 points)
#
# Write `train_one_epoch` and `evaluate` functions.
#
# - `train_one_epoch`: forward pass, compute NLL loss on training nodes, backprop
# - `evaluate`: compute accuracy on a given mask (val or test)

# %%
def train_one_epoch(model: GCN_PyG, data, optimizer) -> float:
    """
    Train for one epoch.

    Args:
        model: GCN model
        data: PyG Data object
        optimizer: torch optimizer

    Returns:
        loss: Training loss (float)
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """


@torch.no_grad()
def evaluate(model: GCN_PyG, data, mask: torch.BoolTensor) -> float:
    """
    Evaluate accuracy on nodes selected by mask.

    Args:
        model: GCN model
        data: PyG Data object
        mask: Boolean mask selecting nodes to evaluate

    Returns:
        accuracy: float in [0, 1]
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Full Training Pipeline (25 points)
#
# Train the GCN for 200 epochs. Track training loss, validation accuracy, and test accuracy.
#
# Use early stopping: stop if validation accuracy does not improve for 10 consecutive epochs.
#
# Report the best validation accuracy and the corresponding test accuracy.

# %%
def full_training_pipeline(
    hidden_dim: int = 16,
    lr: float = 0.01,
    weight_decay: float = 5e-4,
    dropout: float = 0.5,
    num_epochs: int = 200,
    patience: int = 10
) -> dict:
    """
    Full training pipeline with early stopping.

    Args:
        hidden_dim: GCN hidden dimension
        lr: Learning rate
        weight_decay: L2 regularization
        dropout: Dropout rate
        num_epochs: Maximum epochs
        patience: Early stopping patience

    Returns:
        results: dict with keys:
            - best_val_acc: float
            - test_acc_at_best_val: float
            - epochs_trained: int
            - train_losses: list of floats
            - val_accs: list of floats
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Depth Experiment (20 points)
#
# Investigate the effect of GCN depth on performance.
#
# Modify your GCN to accept a variable number of layers (1 to 8). Train each variant and record the best test accuracy.
#
# **Expected result:** Performance should peak at 2-3 layers and degrade for deeper models (over-smoothing).

# %%
class GCN_Variable_Depth(nn.Module):
    """
    GCN with configurable number of layers.

    Args:
        num_features: Input dimension
        hidden_dim: Hidden dimension for all intermediate layers
        num_classes: Output dimension
        num_layers: Total number of GCN layers (minimum 1)
        dropout: Dropout probability
    """

    def __init__(self, num_features, hidden_dim, num_classes, num_layers=2, dropout=0.5):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

    def forward(self, data):
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """


def depth_experiment(max_layers: int = 8) -> dict[int, float]:
    """
    Train GCNs with 1 to max_layers layers and report test accuracy.

    Returns:
        results: dict mapping num_layers -> best test accuracy
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """
