# %% [markdown]
# # Assignment 06: Graph Classification (100 points)
#
# Build a GNN that classifies entire graphs by combining node-level GCN layers with graph-level readout pooling.
#
# **Topics:** Graph-level readout, mean/sum/max pooling, graph batching, MUTAG dataset

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, global_mean_pool, global_add_pool, global_max_pool
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader

# %% [markdown]
# ---
#
# **WARNING:** Do not modify any cell that you are not explicitly asked to modify. Do not add or remove cells.

# %% [markdown]
# ## Part 1: Load and Explore MUTAG (10 points)
#
# Load the MUTAG dataset (molecular graphs labeled as mutagenic or not). Print:
# - Number of graphs
# - Number of classes
# - Number of node features
# - Average number of nodes per graph
# - Average number of edges per graph
#
# Return a dict with these statistics.

# %%
def explore_mutag() -> dict:
    """
    Load MUTAG and return dataset statistics.

    Returns:
        stats: dict with keys num_graphs, num_classes, num_features,
               avg_nodes, avg_edges
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Graph Classification Model (25 points)
#
# Build a GCN-based graph classifier:
#
# 1. Three GCN layers: `in -> hidden -> hidden -> hidden` with ReLU
# 2. Graph-level readout (configurable: mean, sum, or max)
# 3. Two-layer MLP: `hidden -> hidden -> num_classes`
#
# The `readout` parameter selects the pooling function.

# %%
class GraphClassifier(nn.Module):
    """
    GCN + readout + MLP for graph classification.

    Args:
        in_features: Node feature dimension
        hidden_dim: Hidden dimension for GCN and MLP
        num_classes: Number of graph classes
        readout: Pooling method — "mean", "sum", or "max"
        dropout: Dropout probability
    """

    def __init__(self, in_features: int, hidden_dim: int, num_classes: int,
                 readout: str = "mean", dropout: float = 0.5):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

    def forward(self, x, edge_index, batch):
        """
        Forward pass.

        Args:
            x: Node features (total_nodes, F)
            edge_index: Edge indices (2, total_edges)
            batch: Graph assignment vector (total_nodes,)

        Returns:
            out: Log-probabilities (num_graphs, num_classes)
        """
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Data Splitting and Batching (15 points)
#
# Split the MUTAG dataset into train (80%) and test (20%) sets. Create PyG `DataLoader`s with batch size 32.
#
# Use a fixed random seed for reproducibility.

# %%
def prepare_data(seed: int = 42, batch_size: int = 32):
    """
    Load MUTAG, split into train/test, create DataLoaders.

    Returns:
        train_loader: DataLoader for training
        test_loader: DataLoader for testing
        dataset: The full MUTAG dataset
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Training and Evaluation (25 points)
#
# Write the training loop for graph classification.
#
# Train for 100 epochs. Report training loss and test accuracy per epoch.

# %%
def train_graph_classifier(
    readout: str = "mean",
    hidden_dim: int = 64,
    lr: float = 0.01,
    num_epochs: int = 100
) -> dict:
    """
    Train and evaluate a graph classifier.

    Args:
        readout: Pooling method
        hidden_dim: Hidden dimension
        lr: Learning rate
        num_epochs: Number of epochs

    Returns:
        results: dict with keys:
            - train_losses: list of floats
            - test_accs: list of floats
            - best_test_acc: float
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Readout Comparison (25 points)
#
# Compare the three readout functions (mean, sum, max) on MUTAG.
#
# Train each variant 3 times with different seeds and report:
# - Mean and standard deviation of best test accuracy across runs
# - Which readout performs best and hypothesize why

# %%
def readout_comparison(num_runs: int = 3) -> dict:
    """
    Compare mean, sum, max readout on MUTAG.

    Args:
        num_runs: Number of random seeds per readout

    Returns:
        results: dict mapping readout_name -> {
            "mean_acc": float,
            "std_acc": float,
            "all_accs": list of floats
        }
    """
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """
