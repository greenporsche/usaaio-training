# %% [markdown]
# # Assignment 02: UNet from Scratch (100 points)
#
# **Unit 10: Computer Vision & Generative AI | AI 520**
#
# Build a complete UNet architecture for image segmentation from scratch in PyTorch.
# You will implement each component: ConvBlock, encoder path, decoder path with skip connections, and the full UNet.
#
# **Format**: USAAIO Round 2 Style

# %%
# DO NOT CHANGE THIS CELL
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ---
# **WARNING**: Do not import any additional libraries. Do not use any pretrained models. Implement everything from scratch.
#
# ---

# %% [markdown]
# ## Part 1: ConvBlock (15 points)
#
# Implement a double convolution block: `Conv2d -> BatchNorm2d -> ReLU -> Conv2d -> BatchNorm2d -> ReLU`.
#
# - First conv: `in_channels -> out_channels`, kernel 3, padding 1
# - Second conv: `out_channels -> out_channels`, kernel 3, padding 1
# - Output shape should equal input spatial dimensions (same padding)

# %%
class ConvBlock(nn.Module):
    """Double convolution block with BatchNorm and ReLU."""
    def __init__(self, in_channels: int, out_channels: int):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: (B, in_channels, H, W) -> (B, out_channels, H, W)
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Encoder Block (15 points)
#
# Implement an encoder block: `ConvBlock -> MaxPool2d(2, 2)`.
#
# Returns BOTH the convolved features (for skip connection) AND the pooled features (for next level).

# %%
class EncoderBlock(nn.Module):
    def __init__(self, in_channels: int, out_channels: int):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


    def forward(self, x: torch.Tensor):
        # Returns: (skip_features, pooled_features)
        # skip_features: (B, out_channels, H, W)
        # pooled_features: (B, out_channels, H//2, W//2)
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Decoder Block (20 points)
#
# Implement a decoder block:
# 1. `ConvTranspose2d` to upsample (kernel=2, stride=2)
# 2. Concatenate with skip connection from encoder
# 3. `ConvBlock` on the concatenated features
#
# Note: The ConvBlock input channels = `in_channels` (from upsample) + `skip_channels` (from encoder).

# %%
class DecoderBlock(nn.Module):
    def __init__(self, in_channels: int, skip_channels: int, out_channels: int):
        super().__init__()
        # in_channels: channels from previous decoder level (before upsample)
        # skip_channels: channels from corresponding encoder level
        # out_channels: output channels after conv block
        ### WRITE YOUR SOLUTION HERE ###


    def forward(self, x: torch.Tensor, skip: torch.Tensor) -> torch.Tensor:
        # x: (B, in_channels, H, W) from previous decoder level
        # skip: (B, skip_channels, 2H, 2W) from encoder
        # Output: (B, out_channels, 2H, 2W)
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Full UNet (25 points)
#
# Assemble the full UNet with:
# - 4 encoder levels with feature channels `[64, 128, 256, 512]`
# - Bottleneck with 1024 channels
# - 4 decoder levels (symmetric to encoder)
# - Final 1x1 conv to `num_classes` output channels
#
# **Input**: `(B, in_channels, H, W)` where H, W are divisible by 16
# **Output**: `(B, num_classes, H, W)` — same spatial dimensions as input

# %%
class UNet(nn.Module):
    def __init__(self, in_channels: int = 1, num_classes: int = 2):
        super().__init__()
        # Encoder: 4 levels [64, 128, 256, 512]
        # Bottleneck: 1024
        # Decoder: 4 levels [512, 256, 128, 64]
        # Final: 1x1 conv to num_classes
        ### WRITE YOUR SOLUTION HERE ###


    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: (B, in_channels, H, W)
        # Returns: (B, num_classes, H, W)
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Dice Loss (10 points)
#
# Implement the Dice loss for binary segmentation.
#
# $$\mathcal{L}_{\text{Dice}} = 1 - \frac{2\sum_i p_i g_i + \epsilon}{\sum_i p_i + \sum_i g_i + \epsilon}$$
#
# where $p_i$ is the predicted probability and $g_i$ is the ground truth (binary), $\epsilon = 10^{-6}$.

# %%
def dice_loss(pred: torch.Tensor, target: torch.Tensor, epsilon: float = 1e-6) -> torch.Tensor:
    """
    Compute Dice loss.
    pred: (B, 1, H, W) predicted probabilities after sigmoid
    target: (B, 1, H, W) binary ground truth
    Returns: scalar loss
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 6: Shape Verification (free — test your implementation)
#
# Run the cell below to verify your UNet produces the correct output shapes.

# %%
# DO NOT CHANGE THIS CELL
model = UNet(in_channels=1, num_classes=2)
x = torch.randn(2, 1, 128, 128)
out = model(x)
assert out.shape == (2, 2, 128, 128), f"Expected (2, 2, 128, 128), got {out.shape}"
print(f"Output shape: {out.shape} -- CORRECT")
print(f"Total parameters: {sum(p.numel() for p in model.parameters()):,}")
