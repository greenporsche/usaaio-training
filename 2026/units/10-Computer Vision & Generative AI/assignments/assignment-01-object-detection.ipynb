# %% [markdown]
# # Assignment 01: Object Detection Metrics (100 points)
#
# **Unit 10: Computer Vision & Generative AI | AI 520**
#
# In this assignment, you will implement fundamental object detection metrics from scratch:
# IoU (Intersection over Union), NMS (Non-Maximum Suppression), and mAP (mean Average Precision).
#
# **Format**: USAAIO Round 2 Style

# %%
# DO NOT CHANGE THIS CELL
import torch
import torch.nn.functional as F
import numpy as np

# %% [markdown]
# ---
# **WARNING**: Do not import any additional libraries. Do not use `torchvision.ops` or any built-in detection utilities. Implement everything from scratch using only `torch` and `numpy`.
#
# ---

# %% [markdown]
# ## Part 1: Compute IoU Between Two Boxes (15 points)
#
# Implement a function that computes IoU between two single bounding boxes.
#
# **Input**:
# - `box_a`: `torch.Tensor` of shape `(4,)` in format $(x_1, y_1, x_2, y_2)$
# - `box_b`: `torch.Tensor` of shape `(4,)` in format $(x_1, y_1, x_2, y_2)$
#
# **Output**: scalar `torch.Tensor` with the IoU value
#
# $$\text{IoU} = \frac{\text{Area}(A \cap B)}{\text{Area}(A) + \text{Area}(B) - \text{Area}(A \cap B)}$$

# %%
def compute_iou_single(box_a: torch.Tensor, box_b: torch.Tensor) -> torch.Tensor:
    """
    Compute IoU between two bounding boxes.
    box_a: (4,) tensor [x1, y1, x2, y2]
    box_b: (4,) tensor [x1, y1, x2, y2]
    Returns: scalar IoU value
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Pairwise IoU Matrix (15 points)
#
# Implement a **vectorized** function that computes IoU between all pairs of boxes.
#
# **Input**:
# - `boxes_a`: `torch.Tensor` of shape `(N, 4)`
# - `boxes_b`: `torch.Tensor` of shape `(M, 4)`
#
# **Output**: `torch.Tensor` of shape `(N, M)` where entry $(i, j)$ is IoU between `boxes_a[i]` and `boxes_b[j]`
#
# Use broadcasting. No loops.

# %%
def compute_iou_matrix(boxes_a: torch.Tensor, boxes_b: torch.Tensor) -> torch.Tensor:
    """
    Compute pairwise IoU between two sets of boxes.
    boxes_a: (N, 4)  boxes_b: (M, 4)
    Returns: (N, M) IoU matrix
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Non-Maximum Suppression (20 points)
#
# Implement NMS from scratch.
#
# **Input**:
# - `boxes`: `torch.Tensor` of shape `(N, 4)` in $(x_1, y_1, x_2, y_2)$ format
# - `scores`: `torch.Tensor` of shape `(N,)` confidence scores
# - `iou_threshold`: float, suppress boxes with IoU above this
#
# **Output**: `torch.Tensor` of shape `(K,)` — indices of kept boxes
#
# **Algorithm**:
# 1. Sort boxes by score (descending)
# 2. Pick the highest-scoring box, add to kept list
# 3. Remove all boxes with IoU > threshold against the picked box
# 4. Repeat until no boxes remain

# %%
def nms(boxes: torch.Tensor, scores: torch.Tensor, iou_threshold: float) -> torch.Tensor:
    """
    Non-Maximum Suppression.
    boxes: (N, 4)  scores: (N,)  iou_threshold: float
    Returns: (K,) indices of kept boxes
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Match Predictions to Ground Truth (15 points)
#
# Given predicted boxes and ground truth boxes, match each prediction to the best ground truth.
#
# **Input**:
# - `pred_boxes`: `torch.Tensor` of shape `(N, 4)`
# - `pred_scores`: `torch.Tensor` of shape `(N,)`
# - `gt_boxes`: `torch.Tensor` of shape `(M, 4)`
# - `iou_threshold`: float (default 0.5)
#
# **Output**: `torch.Tensor` of shape `(N,)` with values 1 (TP) or 0 (FP)
#
# **Rules**:
# - Sort predictions by score (descending)
# - A prediction is TP if IoU with best unmatched GT > threshold
# - Each GT can only be matched once

# %%
def match_predictions(
    pred_boxes: torch.Tensor,
    pred_scores: torch.Tensor,
    gt_boxes: torch.Tensor,
    iou_threshold: float = 0.5
) -> torch.Tensor:
    """
    Match predictions to ground truth boxes.
    Returns: (N,) tensor of 1s (TP) and 0s (FP), sorted by score descending.
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Compute Average Precision (20 points)
#
# Given TP/FP labels (from Part 4) and the total number of ground truth boxes, compute AP.
#
# **Input**:
# - `tp_fp`: `torch.Tensor` of shape `(N,)` with 1s (TP) and 0s (FP), sorted by confidence
# - `num_gt`: int, total number of ground truth boxes
#
# **Output**: scalar AP value (area under interpolated precision-recall curve)
#
# Use all-point interpolation: at each recall level, precision is the maximum precision at any recall >= that level.

# %%
def compute_ap(tp_fp: torch.Tensor, num_gt: int) -> float:
    """
    Compute Average Precision using all-point interpolation.
    tp_fp: (N,) binary tensor sorted by confidence descending
    num_gt: total number of ground truth boxes
    Returns: scalar AP value
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 6: Box Format Conversion (15 points)
#
# Implement conversion between corner format $(x_1, y_1, x_2, y_2)$ and center format $(cx, cy, w, h)$.
#
# **6a** (7 points): `corner_to_center` — convert `(N, 4)` from corner to center format.
#
# **6b** (8 points): `center_to_corner` — convert `(N, 4)` from center to corner format.
#
# Both must be vectorized (no loops).

# %%
def corner_to_center(boxes: torch.Tensor) -> torch.Tensor:
    """Convert (N, 4) boxes from [x1,y1,x2,y2] to [cx,cy,w,h]."""
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """


def center_to_corner(boxes: torch.Tensor) -> torch.Tensor:
    """Convert (N, 4) boxes from [cx,cy,w,h] to [x1,y1,x2,y2]."""
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """
