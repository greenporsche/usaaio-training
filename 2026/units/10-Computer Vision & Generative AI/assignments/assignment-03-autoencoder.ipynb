# %% [markdown]
# # Assignment 03: Autoencoder from Scratch (100 points)
#
# **Unit 10: Computer Vision & Generative AI | AI 520**
#
# Build an autoencoder, train it on MNIST, and explore the latent space.
#
# **Format**: USAAIO Round 2 Style

# %%
# DO NOT CHANGE THIS CELL
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %% [markdown]
# ---
# **WARNING**: Do not import additional libraries. Implement everything from scratch.
#
# ---

# %% [markdown]
# ## Part 1: Encoder (15 points)
#
# Implement the encoder: `Linear(784, 256) -> ReLU -> Linear(256, 64) -> ReLU -> Linear(64, latent_dim)`
#
# The input is a flattened MNIST image of shape `(B, 784)`. Output is `(B, latent_dim)`.

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim: int = 784, latent_dim: int = 2):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: (B, 784) -> (B, latent_dim)
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Decoder (15 points)
#
# Implement the decoder (mirror of encoder): `Linear(latent_dim, 64) -> ReLU -> Linear(64, 256) -> ReLU -> Linear(256, 784) -> Sigmoid`
#
# Output is in [0, 1] (pixel values).

# %%
class Decoder(nn.Module):
    def __init__(self, latent_dim: int = 2, output_dim: int = 784):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


    def forward(self, z: torch.Tensor) -> torch.Tensor:
        # z: (B, latent_dim) -> (B, 784)
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Autoencoder (10 points)
#
# Combine encoder and decoder. The forward method returns both the reconstruction and the latent code.

# %%
class Autoencoder(nn.Module):
    def __init__(self, input_dim: int = 784, latent_dim: int = 2):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


    def forward(self, x: torch.Tensor):
        # x: (B, 784)
        # Returns: (x_hat, z) where x_hat: (B, 784), z: (B, latent_dim)
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Reconstruction Loss (10 points)
#
# Implement both MSE and BCE reconstruction losses.
#
# **4a** (5 points): MSE loss: $\mathcal{L} = \frac{1}{N}\sum_{i} \|x_i - \hat{x}_i\|^2$
#
# **4b** (5 points): BCE loss: $\mathcal{L} = -\frac{1}{N}\sum_i \sum_j [x_{ij}\log\hat{x}_{ij} + (1-x_{ij})\log(1-\hat{x}_{ij})]$

# %%
def mse_reconstruction_loss(x: torch.Tensor, x_hat: torch.Tensor) -> torch.Tensor:
    """MSE reconstruction loss, averaged over batch."""
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """


def bce_reconstruction_loss(x: torch.Tensor, x_hat: torch.Tensor) -> torch.Tensor:
    """BCE reconstruction loss, summed over features, averaged over batch."""
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Training Loop (20 points)
#
# Implement a training function that trains the autoencoder for one epoch.
#
# Use Adam optimizer with given learning rate and MSE loss.

# %%
def train_one_epoch(
    model: Autoencoder,
    dataloader,
    optimizer: torch.optim.Optimizer,
) -> float:
    """
    Train autoencoder for one epoch.
    dataloader yields (images, labels) where images: (B, 1, 28, 28).
    Returns: average loss over the epoch.
    
    Steps per batch:
    1. Flatten images to (B, 784)
    2. Forward pass through model
    3. Compute MSE loss
    4. Backward pass and optimizer step
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 6: Latent Space Interpolation (15 points)
#
# Implement a function that generates images by interpolating between two points in latent space.
#
# Given two latent codes $z_1$ and $z_2$, produce $n$ images along the interpolation path:
# $$z(\alpha) = (1-\alpha) z_1 + \alpha z_2, \quad \alpha \in [0, 1]$$

# %%
def interpolate_latent(
    decoder: Decoder,
    z1: torch.Tensor,
    z2: torch.Tensor,
    n_steps: int = 10
) -> torch.Tensor:
    """
    Generate images by interpolating between z1 and z2.
    z1, z2: (latent_dim,) tensors
    n_steps: number of interpolation steps (including endpoints)
    Returns: (n_steps, 784) tensor of generated images
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 7: Parameter Count (15 points)
#
# Implement a function that counts total trainable parameters in any `nn.Module`.

# %%
def count_parameters(model: nn.Module) -> int:
    """Count total trainable parameters."""
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """
