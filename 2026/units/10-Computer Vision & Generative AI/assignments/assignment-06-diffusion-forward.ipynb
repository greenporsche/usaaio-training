# %% [markdown]
# # Assignment 06: Diffusion Forward Process (100 points)
#
# **Unit 10: Computer Vision & Generative AI | AI 520**
#
# Implement the DDPM forward (noising) process: noise schedule, closed-form forward, and visualization.
#
# **Format**: USAAIO Round 2 Style

# %%
# DO NOT CHANGE THIS CELL
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %% [markdown]
# ---
# **WARNING**: Do not import additional libraries.
#
# ---

# %% [markdown]
# ## Part 1: Linear Beta Schedule (10 points)
#
# Implement the linear noise schedule: $\beta_t$ linearly interpolated from $\beta_1$ to $\beta_T$.
#
# **Input**: `T` (timesteps), `beta_start`, `beta_end`
# **Output**: tensor of shape `(T,)` with beta values

# %%
def linear_beta_schedule(T: int, beta_start: float = 1e-4, beta_end: float = 0.02) -> torch.Tensor:
    """Linear noise schedule. Returns (T,) tensor."""
    ### WRITE YOUR SOLUTION HERE ###


    """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Compute Alpha Schedule (15 points)
#
# From betas, compute:
# - $\alpha_t = 1 - \beta_t$
# - $\bar{\alpha}_t = \prod_{s=1}^{t} \alpha_s$ (cumulative product)
# - $\sqrt{\bar{\alpha}_t}$ and $\sqrt{1 - \bar{\alpha}_t}$ (for the forward formula)
#
# Return a dictionary with all four tensors.

# %%
def compute_alpha_schedule(betas: torch.Tensor) -> dict:
    """
    betas: (T,) noise schedule
    Returns dict with keys:
      'alphas': (T,)
      'alpha_bars': (T,)
      'sqrt_alpha_bars': (T,)
      'sqrt_one_minus_alpha_bars': (T,)
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Forward Diffusion — Single Step (15 points)
#
# Implement one step of the forward process:
# $$x_t = \sqrt{1-\beta_t} \cdot x_{t-1} + \sqrt{\beta_t} \cdot \epsilon_t$$
#
# where $\epsilon_t \sim \mathcal{N}(0, I)$.

# %%
def forward_step(x_prev: torch.Tensor, beta_t: float) -> tuple:
    """
    One step of forward diffusion.
    x_prev: (B, C, H, W) image at t-1
    beta_t: noise level at step t
    Returns: (x_t, epsilon) where x_t is noised and epsilon is the noise added
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Forward Diffusion — Closed Form (20 points)
#
# Implement the closed-form forward process that jumps directly from $x_0$ to $x_t$:
# $$x_t = \sqrt{\bar{\alpha}_t} \cdot x_0 + \sqrt{1-\bar{\alpha}_t} \cdot \epsilon$$
#
# This is the key function used during DDPM training.

# %%
def forward_diffusion(x_0: torch.Tensor, t: torch.Tensor, schedule: dict) -> tuple:
    """
    Closed-form forward diffusion.
    x_0: (B, C, H, W) clean images
    t: (B,) timestep indices (0 to T-1)
    schedule: dict from compute_alpha_schedule
    Returns: (x_t, epsilon) where epsilon is the noise that was added
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Signal-to-Noise Ratio (10 points)
#
# Compute the SNR at each timestep: $\text{SNR}(t) = \frac{\bar{\alpha}_t}{1 - \bar{\alpha}_t}$
#
# Also compute log-SNR: $\log\text{SNR}(t) = \log\bar{\alpha}_t - \log(1-\bar{\alpha}_t)$

# %%
def compute_snr(schedule: dict) -> tuple:
    """
    Compute SNR and log-SNR for each timestep.
    Returns: (snr, log_snr) each of shape (T,)
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 6: Verify Forward Process (15 points)
#
# Verify that iterating single steps gives the same result as the closed-form.
#
# Given $x_0$ and a **fixed** noise sequence $\epsilon_1, \ldots, \epsilon_T$, compute $x_T$ two ways:
# 1. Iteratively: apply `forward_step` $T$ times
# 2. Closed-form: use `forward_diffusion` with the equivalent combined noise
#
# Implement the iterative version and compare.

# %%
def forward_iterative(x_0: torch.Tensor, betas: torch.Tensor, T: int) -> torch.Tensor:
    """
    Iterate forward process T steps.
    x_0: (B, C, H, W)
    betas: (T,) noise schedule
    Returns: x_T after T forward steps
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 7: Cosine Beta Schedule (15 points)
#
# Implement the cosine schedule from Nichol & Dhariwal (2021):
#
# $$\bar{\alpha}_t = \frac{f(t)}{f(0)}, \quad f(t) = \cos\left(\frac{t/T + s}{1+s} \cdot \frac{\pi}{2}\right)^2$$
#
# with offset $s = 0.008$. Then $\beta_t = 1 - \frac{\bar{\alpha}_t}{\bar{\alpha}_{t-1}}$, clipped to $[0, 0.999]$.

# %%
def cosine_beta_schedule(T: int, s: float = 0.008) -> torch.Tensor:
    """
    Cosine noise schedule.
    Returns: (T,) tensor of beta values
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """
