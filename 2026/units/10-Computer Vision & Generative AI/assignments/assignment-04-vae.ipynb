# %% [markdown]
# # Assignment 04: VAE from Scratch (100 points)
#
# **Unit 10: Computer Vision & Generative AI | AI 520**
#
# Implement a Variational Autoencoder with reparameterization trick, ELBO loss, and generation.
#
# **Format**: USAAIO Round 2 Style

# %%
# DO NOT CHANGE THIS CELL
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %% [markdown]
# ---
# **WARNING**: Do not import additional libraries. Implement everything from scratch.
#
# ---

# %% [markdown]
# ## Part 1: VAE Encoder (15 points)
#
# The encoder maps input $x$ to parameters of $q(z|x) = \mathcal{N}(\mu, \text{diag}(\sigma^2))$.
#
# Architecture: `Linear(784, 256) -> ReLU -> Linear(256, 128) -> ReLU`, then two heads:
# - `mu_head`: `Linear(128, latent_dim)` for $\mu$
# - `logvar_head`: `Linear(128, latent_dim)` for $\log \sigma^2$
#
# **Output**: `(mu, logvar)` each of shape `(B, latent_dim)`

# %%
class VAEEncoder(nn.Module):
    def __init__(self, input_dim: int = 784, latent_dim: int = 2):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


    def forward(self, x: torch.Tensor):
        # x: (B, 784)
        # Returns: (mu, logvar) each (B, latent_dim)
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Reparameterization Trick (15 points)
#
# Implement the reparameterization trick:
# $$z = \mu + \sigma \odot \epsilon, \quad \epsilon \sim \mathcal{N}(0, I)$$
#
# where $\sigma = \exp(0.5 \cdot \log\sigma^2)$.
#
# **Input**: `mu` and `logvar`, each `(B, latent_dim)`
# **Output**: `z` of shape `(B, latent_dim)`

# %%
def reparameterize(mu: torch.Tensor, logvar: torch.Tensor) -> torch.Tensor:
    """
    Reparameterization trick: z = mu + std * eps
    mu: (B, D)  logvar: (B, D)
    Returns: z (B, D)
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 3: VAE Decoder (10 points)
#
# Mirror of encoder: `Linear(latent_dim, 128) -> ReLU -> Linear(128, 256) -> ReLU -> Linear(256, 784) -> Sigmoid`

# %%
class VAEDecoder(nn.Module):
    def __init__(self, latent_dim: int = 2, output_dim: int = 784):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


    def forward(self, z: torch.Tensor) -> torch.Tensor:
        # z: (B, latent_dim) -> (B, 784)
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 4: KL Divergence (15 points)
#
# Implement the closed-form KL divergence between $q(z|x) = \mathcal{N}(\mu, \text{diag}(\sigma^2))$ and $p(z) = \mathcal{N}(0, I)$:
#
# $$D_{KL} = -\frac{1}{2}\sum_{j=1}^{d}(1 + \log\sigma_j^2 - \mu_j^2 - \sigma_j^2)$$
#
# Return the KL summed over latent dimensions, summed over the batch.

# %%
def kl_divergence(mu: torch.Tensor, logvar: torch.Tensor) -> torch.Tensor:
    """
    KL(q(z|x) || p(z)) for diagonal Gaussian q and standard Gaussian p.
    mu: (B, D)  logvar: (B, D)
    Returns: scalar KL divergence (summed over batch and dimensions)
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Full VAE + ELBO Loss (15 points)
#
# Assemble the full VAE and implement the ELBO loss:
#
# $$\mathcal{L} = \text{BCE}(x, \hat{x}) + D_{KL}(q(z|x) \| p(z))$$
#
# where BCE is summed over pixels and samples.

# %%
class VAE(nn.Module):
    def __init__(self, input_dim: int = 784, latent_dim: int = 2):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


    def forward(self, x: torch.Tensor):
        # x: (B, 784)
        # Returns: (x_hat, mu, logvar)
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """


def vae_loss(x: torch.Tensor, x_hat: torch.Tensor, mu: torch.Tensor, logvar: torch.Tensor) -> torch.Tensor:
    """
    ELBO loss = Reconstruction (BCE) + KL divergence.
    All terms summed over pixels and batch.
    Returns: scalar loss
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 6: Training Step (10 points)
#
# Implement a single training step for the VAE.

# %%
def vae_train_step(
    model: VAE,
    batch: torch.Tensor,
    optimizer: torch.optim.Optimizer
) -> dict:
    """
    Single VAE training step.
    batch: (B, 1, 28, 28) images
    Returns: dict with keys 'loss', 'recon_loss', 'kl_loss'
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 7: Generation (10 points)
#
# Generate new images by sampling $z \sim \mathcal{N}(0, I)$ and decoding.

# %%
@torch.no_grad()
def generate_samples(model: VAE, n_samples: int = 16) -> torch.Tensor:
    """
    Generate images by sampling from the prior.
    Returns: (n_samples, 1, 28, 28) tensor of generated images
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """
