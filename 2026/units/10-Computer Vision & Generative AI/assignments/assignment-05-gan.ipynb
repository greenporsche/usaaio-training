# %% [markdown]
# # Assignment 05: GAN Training (100 points)
#
# **Unit 10: Computer Vision & Generative AI | AI 520**
#
# Implement a GAN with generator and discriminator, train with the minimax objective.
#
# **Format**: USAAIO Round 2 Style

# %%
# DO NOT CHANGE THIS CELL
import torch
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# ---
# **WARNING**: Do not import additional libraries. Implement everything from scratch.
#
# ---

# %% [markdown]
# ## Part 1: Generator (15 points)
#
# Maps random noise $z \in \mathbb{R}^{100}$ to a fake image $\in \mathbb{R}^{784}$.
#
# Architecture: `Linear(100, 256) -> LeakyReLU(0.2) -> Linear(256, 512) -> LeakyReLU(0.2) -> Linear(512, 784) -> Tanh`
#
# Output is in $[-1, 1]$ (Tanh).

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim: int = 100, output_dim: int = 784):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


    def forward(self, z: torch.Tensor) -> torch.Tensor:
        # z: (B, 100) -> (B, 784)
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Discriminator (15 points)
#
# Classifies inputs as real or fake.
#
# Architecture: `Linear(784, 512) -> LeakyReLU(0.2) -> Linear(512, 256) -> LeakyReLU(0.2) -> Linear(256, 1) -> Sigmoid`

# %%
class Discriminator(nn.Module):
    def __init__(self, input_dim: int = 784):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###


    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # x: (B, 784) -> (B, 1)
        ### WRITE YOUR SOLUTION HERE ###


        """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Discriminator Loss (15 points)
#
# $$\mathcal{L}_D = -\frac{1}{N}[\sum_i \log D(x_i) + \sum_j \log(1 - D(G(z_j)))]$$
#
# Implement using `F.binary_cross_entropy`.
#
# **Input**: `d_real` (discriminator output on real), `d_fake` (discriminator output on fake)
# **Output**: scalar loss

# %%
def discriminator_loss(d_real: torch.Tensor, d_fake: torch.Tensor) -> torch.Tensor:
    """
    d_real: (B, 1) discriminator output on real images
    d_fake: (B, 1) discriminator output on fake images
    Returns: scalar loss
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Generator Loss (10 points)
#
# Non-saturating generator loss: $\mathcal{L}_G = -\frac{1}{N}\sum_j \log D(G(z_j))$
#
# **Input**: `d_fake` (discriminator output on generator's fake images)
# **Output**: scalar loss

# %%
def generator_loss(d_fake: torch.Tensor) -> torch.Tensor:
    """
    Non-saturating generator loss.
    d_fake: (B, 1) discriminator output on fake images
    Returns: scalar loss
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Training Step (25 points)
#
# Implement a single GAN training step that:
# 1. Trains the discriminator on real and fake data
# 2. Trains the generator to fool the discriminator
#
# **Important**: Detach fake images when training discriminator to avoid backprop through generator.

# %%
def gan_train_step(
    generator: Generator,
    discriminator: Discriminator,
    real_images: torch.Tensor,
    opt_g: torch.optim.Optimizer,
    opt_d: torch.optim.Optimizer,
    latent_dim: int = 100
) -> dict:
    """
    Single GAN training step.
    real_images: (B, 784) real images (scaled to [-1, 1])
    Returns: dict with 'loss_d', 'loss_g', 'd_real_mean', 'd_fake_mean'
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 6: Generate Samples (10 points)
#
# Generate fake images from the trained generator.

# %%
@torch.no_grad()
def generate_gan_samples(generator: Generator, n_samples: int = 16, latent_dim: int = 100) -> torch.Tensor:
    """
    Generate fake images.
    Returns: (n_samples, 1, 28, 28) tensor in [0, 1] range
    (rescale from [-1, 1] to [0, 1])
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """

# %% [markdown]
# ## Part 7: Mode Collapse Detection (10 points)
#
# Implement a function that detects mode collapse by measuring diversity of generated samples.
#
# Compute the mean pairwise L2 distance between generated images. Low diversity = mode collapse.

# %%
@torch.no_grad()
def measure_diversity(generator: Generator, n_samples: int = 100, latent_dim: int = 100) -> float:
    """
    Measure generation diversity as mean pairwise L2 distance.
    Returns: scalar mean pairwise distance
    """
    ### WRITE YOUR SOLUTION HERE ###



    """ END OF THIS PART """
