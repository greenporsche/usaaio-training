# %% [markdown]
# # Assignment 06: K-Means Clustering from Scratch (100 points)
#
# In this assignment, you will implement K-means clustering with Lloyd's algorithm
# and k-means++ initialization. You will explore convergence behavior,
# initialization effects, and methods for choosing $k$.
#
# **Notation:**
# - $k$: number of clusters
# - $\mu_j$: centroid of cluster $j$, $j = 1, \ldots, k$
# - $c_i$: cluster assignment of point $i$
# - Inertia (WCSS): $J = \sum_{j=1}^{k}\sum_{i \in C_j} \|x_i - \mu_j\|^2$
# - K-means++ selects centroids with $P(x) \propto D(x)^2$

# %%
"""DO NOT MAKE ANY CHANGE IN THIS CELL."""
import numpy as np
from sklearn.datasets import make_blobs, make_moons
import matplotlib.pyplot as plt

np.random.seed(42)

# %% [markdown]
# ### WARNING
# For all coding tasks, you may only use `numpy` and standard Python libraries.
# Do NOT use `sklearn.cluster` or any clustering implementation.

# %% [markdown]
# ---
# ## Part 1 (20 points, coding task)
#
# **Reasoning not required.**
#
# Implement Lloyd's algorithm:
#
# 1. `assign_clusters(X, centroids)` — Assign each point to its nearest centroid. Return labels array.
# 2. `update_centroids(X, labels, k)` — Compute new centroids as mean of assigned points.
# 3. `kmeans(X, k, max_iters=100, seed=42)` — Full algorithm with random initialization. Return `(labels, centroids, inertia, n_iters)`.
#
# Use vectorized NumPy operations (no loops over data points for distance computation).

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 2 (20 points, coding task)
#
# **Reasoning not required.**
#
# Implement k-means++ initialization:
#
# 1. `kmeans_plus_plus(X, k, rng)` — Select $k$ initial centroids using the k-means++ algorithm:
#    - Choose the first centroid uniformly at random from data points.
#    - For each subsequent centroid, compute $D(x)^2$ (squared distance to nearest existing centroid) for all points.
#    - Sample the next centroid with probability proportional to $D(x)^2$.
# 2. Modify your `kmeans` function to accept an `init` parameter: `'random'` or `'kmeans++'`.
# 3. Compare random vs k-means++ initialization: run each 20 times on `make_blobs(centers=5)` and plot the distribution of final inertias.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 3 (20 points, coding task)
#
# **Reasoning not required.**
#
# Implement methods for choosing $k$:
#
# 1. **Elbow method**: Run k-means for $k = 1, 2, \ldots, 10$. Plot inertia vs $k$. Identify the elbow.
# 2. **Silhouette score**: Implement `silhouette_score(X, labels)`. For each point, compute $a_i$ (mean intra-cluster distance) and $b_i$ (mean nearest-cluster distance). Return the mean silhouette $\frac{1}{N}\sum_i \frac{b_i - a_i}{\max(a_i, b_i)}$.
# 3. Plot silhouette score vs $k$. Which $k$ is optimal?
# 4. Use `make_blobs` with `centers=4` and verify that both methods correctly identify $k=4$.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 4 (20 points, coding task)
#
# **Reasoning not required.**
#
# Visualize convergence and local minima:
#
# 1. Create an animation-style visualization: for a 2D dataset with 3 clusters, show the centroids and cluster assignments at each iteration (plot iterations 0, 1, 2, 3, and final as a 1x5 subplot grid).
# 2. Demonstrate local minima: run k-means 10 times with different random initializations on the same data. Plot the cluster assignments for the best and worst results (by inertia). Show both inertia values.
# 3. Show that k-means fails on `make_moons(n_samples=500, noise=0.1)`. Visualize the result for $k=2$.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 5 (20 points, non-coding task)
#
# **Reasoning required.**
#
# 1. Prove that Lloyd's algorithm converges in a finite number of steps. (Hint: show that inertia is monotonically non-increasing and there are finitely many possible assignments.)
# 2. K-means finds a local minimum, not necessarily the global minimum. Why is finding the global minimum NP-hard in general?
# 3. Explain the connection between k-means and the Expectation-Maximization (EM) algorithm for Gaussian Mixture Models. Specifically, what happens to EM when all covariance matrices are $\sigma^2 I$ and $\sigma \to 0$?
# 4. Why does k-means fail on the moons dataset? What property of the clusters violates k-means' assumptions?

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """
