# %% [markdown]
# # Assignment 02: Random Forest (100 points)
#
# In this assignment, you will implement a Random Forest classifier by combining
# bootstrap aggregation (bagging) with feature subsampling.
# You will compare its performance to a single decision tree and analyze
# out-of-bag error and feature importance.
#
# **Notation:**
# - $B$: number of trees in the forest
# - $m$: number of features sampled at each split ($m \approx \sqrt{p}$ for classification)
# - OOB error: error estimated using out-of-bag samples
# - $\text{Var}(\bar{f}) = \rho\sigma^2 + \frac{1-\rho}{B}\sigma^2$

# %%
"""DO NOT MAKE ANY CHANGE IN THIS CELL."""
import numpy as np
from sklearn.datasets import load_iris, load_wine, make_classification
from sklearn.model_selection import train_test_split
from collections import Counter
import matplotlib.pyplot as plt

np.random.seed(42)

# %% [markdown]
# ### WARNING
# For all coding tasks, you may only use `numpy`, `collections`, and standard Python libraries.
# Do NOT use `sklearn.ensemble` or any ensemble implementation.
# You may reuse your decision tree code from Assignment 01.

# %% [markdown]
# ---
# ## Part 1 (15 points, coding task)
#
# **Reasoning not required.**
#
# Implement `bootstrap_sample(X, y, rng)` that:
# 1. Creates a bootstrap sample by drawing $N$ samples with replacement from $N$ original samples.
# 2. Returns the bootstrap data `(X_boot, y_boot)` and the indices of out-of-bag samples.
#
# Verify empirically that approximately 63.2% of unique samples appear in each bootstrap.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 2 (25 points, coding task)
#
# **Reasoning not required.**
#
# Implement a `RandomForest` class with:
# - `__init__(self, n_trees=100, max_depth=10, max_features='sqrt', seed=42)`
# - `fit(self, X, y)` — For each tree: create a bootstrap sample, randomly select `max_features` features, train a decision tree on the subset.
# - `predict(self, X)` — Majority vote across all trees.
#
# Key implementation detail: feature subsampling should ideally happen **at each split**, not per tree. However, per-tree subsampling is acceptable for this assignment.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 3 (20 points, coding task)
#
# **Reasoning not required.**
#
# Implement OOB error estimation:
# 1. During `fit`, track which samples are OOB for each tree and store their predictions.
# 2. Implement `oob_score(self, y)` that computes the OOB accuracy by majority-voting over OOB predictions for each sample.
#
# Compare the OOB error to a held-out test set error on the Iris dataset. They should be similar.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 4 (20 points, coding task)
#
# **Reasoning not required.**
#
# Compare your Random Forest to a single Decision Tree on the Wine dataset:
# 1. Train a single decision tree (`max_depth=5`) and report train/test accuracy.
# 2. Train a random forest (`n_trees=50, max_depth=5`) and report train/test accuracy.
# 3. Plot test accuracy vs. number of trees ($B = 1, 5, 10, 25, 50, 100$).
# 4. Plot test accuracy vs. max_features ($m = 1, 2, \sqrt{p}, p/2, p$) with fixed $B=50$.
#
# Use the Wine dataset with an 80/20 train-test split.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 5 (20 points, non-coding task)
#
# **Reasoning required.**
#
# Based on your experiments, answer the following:
#
# 1. Why does the random forest achieve higher test accuracy than the single tree? Explain in terms of bias and variance.
# 2. How does increasing the number of trees affect performance? Is there a point of diminishing returns?
# 3. What is the effect of `max_features` on performance? What happens at the extremes ($m=1$ and $m=p$)?
# 4. If $m = p$ (all features at every split), how does the random forest differ from simple bagging? Is it still better than a single tree?

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """
