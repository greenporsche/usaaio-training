# %% [markdown]
# # Assignment 10: Comprehensive ML2 Assessment (100 points)
#
# This is a contest-style assessment covering all topics in Unit 05.
# It simulates the format and difficulty of USAAIO Round 2 problems.
# You have both coding and reasoning tasks spanning decision trees, ensemble methods,
# PCA, clustering, and SVMs.
#
# **Time guideline**: 2-3 hours
#
# **Rules**:
# - For coding tasks: only `numpy` and standard Python unless stated otherwise.
# - For reasoning tasks: show your work clearly.
# - Partial credit is awarded for correct methodology even if the final answer is wrong.

# %%
"""DO NOT MAKE ANY CHANGE IN THIS CELL."""
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(2026)

# %% [markdown]
# ### WARNING
# For coding tasks, you may only use `numpy` and `matplotlib` unless explicitly stated.
# Do NOT use sklearn or any ML library.

# %% [markdown]
# ---
# ## Part 1 (15 points, non-coding task)
#
# **Reasoning required.**
#
# A node in a decision tree contains 20 samples: 12 from class A, 5 from class B, and 3 from class C.
#
# a) (5 pts) Compute the Gini impurity and the entropy of this node. Show all steps.
#
# b) (5 pts) A candidate split produces:
# - Left child: 10A, 1B, 0C (11 samples)
# - Right child: 2A, 4B, 3C (9 samples)
#
# Compute the information gain (using entropy).
#
# c) (5 pts) Another split produces:
# - Left child: 6A, 5B, 3C (14 samples)
# - Right child: 6A, 0B, 0C (6 samples)
#
# Compute the information gain. Which split is better?

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 2 (15 points, coding task)
#
# **Reasoning not required.**
#
# Implement `adaboost_predict(X, stumps, alphas)` that makes predictions using a trained AdaBoost ensemble.
#
# Each stump is a dictionary: `{'feature': j, 'threshold': t, 'polarity': p}` where the stump predicts $+1$ if $\text{polarity} \cdot x_j > \text{polarity} \cdot t$, else $-1$.
#
# Given the following trained ensemble:
# ```python
# stumps = [
#     {'feature': 0, 'threshold': 3.0, 'polarity': 1},
#     {'feature': 1, 'threshold': 2.5, 'polarity': -1},
#     {'feature': 0, 'threshold': 5.0, 'polarity': 1}
# ]
# alphas = [0.5, 0.3, 0.8]
# ```
#
# Predict the class for $x = [4.0, 2.0]$ and $x = [6.0, 3.0]$. Show the intermediate calculations.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 3 (20 points, coding task)
#
# **Reasoning not required.**
#
# Implement PCA from scratch and apply it:
#
# Given the following 5x3 data matrix (already centered):
# ```python
# X_c = np.array([
#     [-2.0, 1.0, -1.0],
#     [ 1.0, -1.0, 0.5],
#     [ 0.0, 2.0, -0.5],
#     [ 3.0, -1.0, 1.5],
#     [-2.0, -1.0, -0.5]
# ])
# ```
#
# a) (8 pts) Compute the 3x3 covariance matrix $\Sigma$.
#
# b) (6 pts) Find the eigenvalues and eigenvectors. What fraction of variance is explained by the first principal component?
#
# c) (6 pts) Project the data onto the first 2 principal components. Compute the reconstruction error.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 4 (20 points, coding task)
#
# **Reasoning not required.**
#
# Implement and trace K-means:
#
# Given 8 points in 2D:
# ```python
# X = np.array([
#     [1, 2], [2, 1], [1.5, 1.5],  # cluster A
#     [6, 5], [7, 6], [6.5, 5.5],  # cluster B
#     [1, 5], [2, 6]               # cluster C
# ])
# ```
#
# a) (8 pts) With initial centroids $\mu_1 = [1, 2]$ and $\mu_2 = [7, 6]$ and $\mu_3 = [1, 5]$ ($k=3$), trace TWO full iterations of Lloyd's algorithm. Show assignments and centroids at each step.
#
# b) (6 pts) Compute the inertia (WCSS) after convergence.
#
# c) (6 pts) Implement the silhouette score computation for your final clustering. Report the mean silhouette score and identify the point with the lowest silhouette score.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 5 (15 points, non-coding task)
#
# **Reasoning required.**
#
# SVM theory:
#
# a) (5 pts) Given weight vector $w = [3, 4]$ and bias $b = -5$, compute the margin width and classify the points $x_1 = [2, 1]$ and $x_2 = [0, 2]$.
#
# b) (5 pts) Explain why the RBF kernel $K(x, z) = \exp(-\gamma\|x-z\|^2)$ is a valid kernel (hint: Mercer's theorem). What does $\gamma$ control geometrically?
#
# c) (5 pts) A soft-margin SVM with $C = 100$ achieves 100% training accuracy but only 75% test accuracy. Another SVM with $C = 0.1$ achieves 90% training and 88% test accuracy. Explain this in terms of bias, variance, and the role of $C$.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 6 (15 points, coding task)
#
# **Reasoning not required.**
#
# Build a complete ML pipeline from scratch:
#
# Given a synthetic dataset:
# ```python
# rng = np.random.default_rng(2026)
# # 3 clusters in 10D, but only 2D contain signal
# N = 300
# signal = np.vstack([
#     rng.normal([0, 0], 0.5, (100, 2)),
#     rng.normal([3, 3], 0.5, (100, 2)),
#     rng.normal([0, 3], 0.5, (100, 2))
# ])
# noise = rng.normal(0, 1, (N, 8))
# X = np.hstack([signal, noise])
# ```
#
# a) (5 pts) Apply your PCA implementation to find the intrinsic dimensionality. How many components are needed to capture 90% of the variance?
#
# b) (5 pts) Apply K-means (your implementation) with k-means++ initialization on the PCA-reduced data. Use the elbow method to determine $k$.
#
# c) (5 pts) Compute and report the silhouette score and visualize the final clustering in 2D.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """
