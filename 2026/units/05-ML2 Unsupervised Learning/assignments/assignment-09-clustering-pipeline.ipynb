# %% [markdown]
# # Assignment 09: Clustering Pipeline (100 points)
#
# In this assignment, you will build a full clustering pipeline:
# preprocessing, dimensionality reduction, multiple clustering algorithms,
# and evaluation. This mirrors real-world unsupervised learning workflows.
#
# **Pipeline stages:**
# 1. Data preprocessing (scaling, handling missing values)
# 2. Dimensionality reduction (PCA)
# 3. Clustering (K-means, hierarchical, DBSCAN)
# 4. Evaluation (silhouette, visualization)
# 5. Interpretation

# %%
"""DO NOT MAKE ANY CHANGE IN THIS CELL."""
import numpy as np
from sklearn.datasets import load_digits, load_wine, make_blobs
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import (
    silhouette_score, adjusted_rand_score, normalized_mutual_info_score
)
import matplotlib.pyplot as plt

np.random.seed(42)

# %% [markdown]
# ### WARNING
# You may use scikit-learn for this pipeline assignment.
# The focus is on building a complete, well-evaluated clustering pipeline.

# %% [markdown]
# ---
# ## Part 1 (15 points, coding task)
#
# **Reasoning not required.**
#
# Preprocessing and dimensionality reduction:
#
# 1. Load the digits dataset (1797 images, 64 features).
# 2. Standardize the features using `StandardScaler`.
# 3. Apply PCA to reduce to various dimensions: $k = 2, 5, 10, 20, 50$.
# 4. For each $k$, report the cumulative variance explained.
# 5. Visualize the 2D PCA projection, colored by true digit labels.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 2 (25 points, coding task)
#
# **Reasoning not required.**
#
# K-means clustering on the digits dataset:
#
# 1. Apply PCA with $k=20$ components (a good balance of information retention and noise reduction).
# 2. Run K-means with $k = 5, 8, 10, 12, 15$ clusters.
# 3. For each $k$, compute:
#    - Silhouette score
#    - Adjusted Rand Index (ARI) against true labels
#    - Normalized Mutual Information (NMI) against true labels
# 4. Plot all three metrics vs $k$. Which $k$ is optimal?
# 5. For $k=10$, create a confusion-matrix-style visualization: for each cluster, show the distribution of true digit labels.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 3 (25 points, coding task)
#
# **Reasoning not required.**
#
# Compare multiple clustering algorithms:
#
# 1. On the PCA-reduced digits data (20 components), apply:
#    - K-means ($k=10$)
#    - Agglomerative clustering ($k=10$, linkage='ward')
#    - DBSCAN (experiment with `eps` and `min_samples`)
# 2. For each algorithm, report silhouette score, ARI, and NMI.
# 3. Visualize all three clusterings in 2D (using PCA to project to 2D for visualization).
# 4. For DBSCAN, determine good hyperparameters using a k-distance plot (plot sorted distances to the $k$-th nearest neighbor and look for an elbow).

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 4 (20 points, coding task)
#
# **Reasoning not required.**
#
# Apply your pipeline to the Wine dataset:
#
# 1. Load and preprocess the Wine dataset (13 features, 3 classes).
# 2. Apply PCA and determine the number of components to retain 95% variance.
# 3. Run K-means with $k = 2, 3, 4, 5$ and identify the optimal $k$ using silhouette analysis.
# 4. Compare K-means and Agglomerative clustering for the optimal $k$. Which aligns better with the true wine classes?
# 5. Create a comprehensive summary plot: PCA scatter with true labels, K-means labels, and Agglomerative labels side-by-side.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 5 (15 points, non-coding task)
#
# **Reasoning required.**
#
# 1. Explain the role of dimensionality reduction as a preprocessing step for clustering. When does it help? When might it hurt?
# 2. Why is it problematic to evaluate clustering using only silhouette score? What additional information does ARI provide?
# 3. DBSCAN requires no specification of $k$ but needs `eps` and `min_samples`. Discuss the tradeoffs compared to K-means.
# 4. In a real-world scenario where you have NO ground truth labels, how would you evaluate and choose between clustering results?

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """
