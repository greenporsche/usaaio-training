# %% [markdown]
# # Assignment 08: Ensemble Comparison (100 points)
#
# In this assignment, you will systematically compare decision trees, random forests,
# and boosting methods on multiple datasets. You will analyze their strengths and
# weaknesses through controlled experiments.
#
# **Models to compare:**
# - Single Decision Tree
# - Random Forest (bagging + feature subsampling)
# - AdaBoost (with decision stumps)
# - Gradient Boosting
#
# **Evaluation metrics:** accuracy, training time, robustness to noise

# %%
"""DO NOT MAKE ANY CHANGE IN THIS CELL."""
import numpy as np
import time
from sklearn.datasets import make_classification, load_digits, make_moons
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
)
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

np.random.seed(42)

# %% [markdown]
# ### WARNING
# You may use scikit-learn implementations for this comparison assignment.
# The focus is on experimental methodology and analysis, not implementation.

# %% [markdown]
# ---
# ## Part 1 (20 points, coding task)
#
# **Reasoning not required.**
#
# Create a benchmarking framework:
#
# 1. Define 3 datasets of increasing difficulty:
#    - Easy: `make_classification(n_samples=1000, n_features=10, n_informative=8, n_redundant=2)`
#    - Medium: `make_classification(n_samples=1000, n_features=20, n_informative=10, n_redundant=5, n_clusters_per_class=2)`
#    - Hard: `make_moons(n_samples=1000, noise=0.3)`
#
# 2. Train all 4 models on each dataset (80/20 split). Report train/test accuracy and training time.
# 3. Present results in a summary table.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 2 (20 points, coding task)
#
# **Reasoning not required.**
#
# Analyze robustness to label noise:
#
# 1. Using the "Easy" dataset, randomly flip 0%, 5%, 10%, 20%, and 30% of training labels.
# 2. Train all 4 models at each noise level. Plot test accuracy vs. noise level for all models on the same plot.
# 3. Which model is most robust to noise? Which is least robust?
# 4. Explain the results in terms of each model's learning mechanism.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 3 (20 points, coding task)
#
# **Reasoning not required.**
#
# Analyze the effect of ensemble size:
#
# 1. For Random Forest and Gradient Boosting, plot test accuracy vs. number of estimators ($n = 1, 5, 10, 25, 50, 100, 200, 500$) on the digits dataset.
# 2. Plot training time vs. number of estimators for both.
# 3. At what point do additional trees stop improving performance (diminishing returns)?
# 4. Which method achieves good accuracy with fewer trees?

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 4 (20 points, coding task)
#
# **Reasoning not required.**
#
# Decision boundary visualization:
#
# 1. Generate a 2D dataset using `make_moons(n_samples=500, noise=0.25)`.
# 2. Train all 4 models and plot their decision boundaries side-by-side (2x2 grid).
# 3. For each model, annotate with train/test accuracy.
# 4. Generate a second dataset with `make_classification(n_samples=500, n_features=2, n_redundant=0, n_clusters_per_class=2)` and repeat the visualization.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 5 (20 points, non-coding task)
#
# **Reasoning required.**
#
# Based on all your experiments, write a comparison essay (300-500 words) addressing:
#
# 1. When would you choose a single decision tree over an ensemble? (Hint: interpretability.)
# 2. When would you choose Random Forest vs. Gradient Boosting?
# 3. How does each method handle the bias-variance tradeoff differently?
# 4. If you had to recommend ONE method as a "default" for tabular classification, which would it be and why?
# 5. What are the computational tradeoffs between these methods for training and inference?

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """
