# %% [markdown]
# # Assignment 05: PCA Applications (100 points)
#
# In this assignment, you will apply PCA to real-world tasks:
# image compression, feature extraction for classification, and data visualization.
#
# **Notation:**
# - $X \in \mathbb{R}^{N \times D}$: data matrix (each row is a flattened image or feature vector)
# - $V_k \in \mathbb{R}^{D \times k}$: matrix of top-$k$ principal components
# - Reconstruction: $\hat{X} = X_c V_k V_k^T + \bar{X}$
# - Compression ratio: $\frac{k(N + D)}{ND}$

# %%
"""DO NOT MAKE ANY CHANGE IN THIS CELL."""
import numpy as np
from sklearn.datasets import load_digits, fetch_olivetti_faces
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

np.random.seed(42)

# %% [markdown]
# ### WARNING
# You may use `sklearn.decomposition.PCA` in this assignment (since you built it from scratch in Assignment 04).
# You may also use `KNeighborsClassifier` for downstream classification tasks.

# %% [markdown]
# ---
# ## Part 1 (25 points, coding task)
#
# **Reasoning not required.**
#
# **Image Compression with PCA.**
#
# 1. Load the digits dataset (`load_digits`): 1797 images of size 8x8 (64 pixels).
# 2. Fit PCA with $k = 5, 10, 20, 40, 64$ components.
# 3. For each $k$, reconstruct the images and compute the mean squared reconstruction error.
# 4. Display the first 5 digits: original and reconstructed for each $k$ value (5 rows x 6 columns grid).
# 5. Plot compression ratio vs. reconstruction error.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 2 (25 points, coding task)
#
# **Reasoning not required.**
#
# **Eigenfaces: PCA on Face Images.**
#
# 1. Load the Olivetti faces dataset (400 images, 64x64 = 4096 pixels).
# 2. Fit PCA and plot the scree plot. How many components capture 95% variance?
# 3. Display the first 10 principal components as images ("eigenfaces"). These are the $v_k$ vectors reshaped to 64x64.
# 4. Reconstruct a sample face using $k = 10, 50, 100, 200$ components. Display the progression.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 3 (25 points, coding task)
#
# **Reasoning not required.**
#
# **PCA as Feature Extraction for Classification.**
#
# 1. Using the digits dataset, train a K-NN classifier ($k=5$) on the raw 64-dimensional data. Report test accuracy.
# 2. Apply PCA to reduce to $k = 2, 5, 10, 20, 30, 40, 50, 64$ dimensions. Train K-NN on the reduced data.
# 3. Plot test accuracy vs. number of PCA components.
# 4. What is the smallest number of components that achieves accuracy within 1% of the full-dimensional baseline?
# 5. Plot training time vs. number of components (use `time.time()` to measure).

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 4 (15 points, coding task)
#
# **Reasoning not required.**
#
# **Visualization: PCA Biplots.**
#
# 1. Load the Iris dataset and standardize it.
# 2. Compute PCA with 2 components.
# 3. Create a biplot: scatter plot of samples (colored by class) with arrows showing the loading vectors (how each original feature contributes to PC1 and PC2).
# 4. Interpret the biplot: which features are most correlated? Which features contribute most to PC1 vs PC2?

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
# ## Part 5 (10 points, non-coding task)
#
# **Reasoning required.**
#
# 1. In the image compression task, why does PCA work well for compressing face images but might not work as well for compressing natural scene images with diverse content?
# 2. Explain why using too few PCA components can hurt classification accuracy, while using too many can also sometimes hurt. What is this phenomenon called?
# 3. A colleague claims: "PCA with 2 components on my 1000-dimensional data shows two clear clusters, so the data naturally has 2 groups." What is wrong with this reasoning?

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """
