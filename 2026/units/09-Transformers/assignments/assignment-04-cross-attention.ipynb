# %% [markdown]
# # Assignment 04 — Cross-Attention and Masked Attention (100 points)
#
# In this assignment you will extend MHA to handle cross-attention (different attending/attended sequences) and masked self-attention (causal masking for autoregressive models).
#
# **Notation:**
# - $B$: batch size
# - $L_1$: attending sequence length, $L_2$: being attended sequence length
# - $D_1$: hidden dimension of attending sequence, $D_2$: hidden dimension of being attended sequence
# - $H$: number of heads, $D_{qk}$: query/key dim, $D_v$: value dim

# %%
"""
DO NOT MAKE ANY CHANGE IN THIS CELL.
"""
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %% [markdown]
# **WARNING**: You may only use `torch`, `torch.nn`, `torch.nn.functional`, and `numpy`. No other imports are allowed.

# %% [markdown]
# ## Part 1 (10 points, non-coding task)
#
# An encoder-decoder model has encoder output of shape $(B, L_{\text{enc}}, D_{\text{enc}}) = (4, 100, 768)$ and decoder hidden states of shape $(B, L_{\text{dec}}, D_{\text{dec}}) = (4, 50, 512)$ with $H = 8$, $D_{qk} = 64$, $D_v = 64$.
#
# For the cross-attention layer (decoder attends to encoder):
#
# 1. What is the shape of $W^Q$? (2 points)
# 2. What is the shape of $W^K$? (2 points)
# 3. What is the shape of $W^V$? (2 points)
# 4. What is the shape of the attention matrix? (2 points)
# 5. What is the shape of $W^O$? (2 points)
#
# Reasoning is required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 2 (15 points, coding task)
#
# Implement `MyMHAWithMask` extending the MHA from Assignment 03 to support an optional attention mask.
#
# The `forward` method should accept:
# - `X1`: $(B, L_1, D_1)$ — attending sequence
# - `X2`: $(B, L_2, D_2)$ — being attended sequence
# - `mask`: optional tensor of shape $(L_1, L_2)$ or $(B, 1, L_1, L_2)$. Where mask is 0, set logits to $-\infty$ before softmax.
#
# NO LOOPS. Shape annotations required.
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 3 (10 points, coding task)
#
# Implement a function `create_causal_mask(L)` that returns a lower-triangular mask of shape $(L, L)$.
#
# Then test it:
# 1. Create a causal mask for $L = 6$.
# 2. Print the mask.
# 3. Verify that `mask[i][j] == 1` if and only if $j \leq i$.
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 4 (15 points, coding task)
#
# Test masked self-attention (causal attention).
#
# 1. Create `MyMHAWithMask` with $D_1 = D_2 = 16, H = 2, D_{qk} = D_v = 8$.
# 2. Create random input $X$ of shape $(1, 4, 16)$.
# 3. Create a causal mask of shape $(4, 4)$.
# 4. Compute output with causal mask.
# 5. **Verification**: Extract the attention logits (before softmax) from your computation. Verify that after masking, all positions above the diagonal are $-\infty$.
# 6. Verify that the attention weights (after softmax) for position 0 are $[1, 0, 0, 0]$ for each head (since position 0 can only attend to itself).
#
# Hint: You may need to modify your module to return attention weights for verification, or compute them separately.
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 5 (15 points, coding task)
#
# Test cross-attention (different sequence dimensions).
#
# 1. Create `MyMHAWithMask` with $D_1 = 32, D_2 = 64, H = 4, D_{qk} = 16, D_v = 16$.
# 2. Create decoder states $X_1$ of shape $(2, 5, 32)$.
# 3. Create encoder outputs $X_2$ of shape $(2, 10, 64)$.
# 4. Compute cross-attention: `mha(X1, X2)` with NO mask.
# 5. Assert output shape is $(2, 5, 32)$ — same shape as $X_1$.
# 6. Now try to use `mha(X2, X1)` (reverse). What output shape do you expect? Does it work with the same module? Why or why not? Answer in a comment.
#
# Reasoning is required for part 6.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 6 (10 points, non-coding task)
#
# A transformer decoder block has three sub-layers. For each, state:
# - The type of attention (self or cross)
# - Where Q, K, V come from
# - Whether a mask is used and what kind
# - The shape of the attention matrix (given $L_{\text{enc}} = 100, L_{\text{dec}} = 50, H = 8$)
#
# 1. First sub-layer: Masked multi-head self-attention (4 points)
# 2. Second sub-layer: Multi-head cross-attention (4 points)
# 3. Why is a causal mask needed in sub-layer 1 but NOT in sub-layer 2? (2 points)
#
# Reasoning is required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 7 (10 points, coding task)
#
# Implement a padding mask and combine it with the causal mask.
#
# Given a batch of 3 sequences with actual lengths `[4, 2, 5]` padded to max length 5:
#
# 1. Create the padding mask of shape $(3, 5)$. (3 points)
# 2. Reshape it for broadcasting with attention logits of shape $(B, H, L, L)$. (3 points)
# 3. Create a causal mask of shape $(5, 5)$. (1 point)
# 4. Combine padding and causal masks. (3 points)
# 5. Print the combined mask for each sequence in the batch.
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 8 (5 points, non-coding task)
#
# Consider attention with a padding mask where the sequence has 3 real tokens and 2 padding tokens (total length 5).
#
# 1. After applying the padding mask and softmax, what are the attention weights for position 1 (a real token) attending to all 5 positions? (2 points)
# 2. What are the attention weights for position 4 (a padding token) attending to all 5 positions? Is there a problem? (3 points)
#
# Hint: What happens when ALL entries in a softmax row are $-\infty$?
#
# Reasoning is required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """
