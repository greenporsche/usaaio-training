# %% [markdown]
# # Assignment 07 — Transformer Decoder (100 points)
#
# Build a complete transformer decoder block with masked self-attention, cross-attention, and FFN. Then assemble a full encoder-decoder transformer.
#
# **Notation:**
# - $B$: batch size
# - $L_{\text{enc}}$: encoder sequence length, $L_{\text{dec}}$: decoder sequence length
# - $D$: model dimension, $D_{\text{enc}}$: encoder output dimension
# - $H$: heads, $D_{qk}$: query/key dim, $D_v$: value dim, $D_{ff}$: FFN hidden dim

# %%
"""
DO NOT MAKE ANY CHANGE IN THIS CELL.
"""
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %% [markdown]
# **WARNING**: You may only use `torch`, `torch.nn`, `torch.nn.functional`, and `numpy`. No other imports are allowed.

# %% [markdown]
# ## Part 1 (10 points, coding task)
#
# Implement `MyMHAWithMask` — MHA that supports an optional attention mask.
#
# Copy your MHA from previous assignments, adding a `mask` parameter to `forward`.
# - `mask`: optional, shape $(L_1, L_2)$ or $(B, 1, L_1, L_2)$. Where mask==0, set logits to $-\infty$.
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# Also implement `FFN` as in Assignment 06.

# %% [markdown]
# ## Part 2 (15 points, coding task)
#
# Implement `TransformerDecoderBlock` with pre-norm.
#
# A decoder block has three sub-layers:
# 1. Masked self-attention (with causal mask)
# 2. Cross-attention (decoder attends to encoder output)
# 3. FFN
#
# Each with residual connection and LayerNorm (pre-norm).
#
# Constructor: `TransformerDecoderBlock(D, D_enc, H, D_qk, D_v, D_ff)`
# Forward: `forward(x, encoder_out, causal_mask)` where:
# - `x`: $(B, L_{\text{dec}}, D)$
# - `encoder_out`: $(B, L_{\text{enc}}, D_{\text{enc}})$
# - `causal_mask`: $(L_{\text{dec}}, L_{\text{dec}})$
#
# Returns: $(B, L_{\text{dec}}, D)$
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 3 (10 points, coding task)
#
# Test the decoder block.
#
# 1. Create with $D = 64, D_{\text{enc}} = 64, H = 4, D_{qk} = 16, D_v = 16, D_{ff} = 256$.
# 2. Create decoder input $(2, 8, 64)$ and encoder output $(2, 12, 64)$.
# 3. Create causal mask of shape $(8, 8)$.
# 4. Forward pass. Assert output shape $(2, 8, 64)$.
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 4 (10 points, non-coding task)
#
# Shape analysis for the decoder block.
#
# Given $B=4, L_{\text{dec}}=20, L_{\text{enc}}=50, D=512, D_{\text{enc}}=512, H=8, D_{qk}=D_v=64, D_{ff}=2048$.
#
# Trace shapes through each sub-layer:
#
# 1. Masked self-attention: Q from ?, K from ?, V from ?. Attention matrix shape? (3 points)
# 2. Cross-attention: Q from ?, K from ?, V from ?. Attention matrix shape? (3 points)
# 3. FFN: input shape, hidden shape after $W_1$, output shape after $W_2$. (2 points)
# 4. Does the output shape match the input? Why is this necessary? (2 points)
#
# Reasoning is required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 5 (10 points, coding task)
#
# Implement `TransformerDecoder` — a stack of $N$ decoder blocks.
#
# - Constructor: `TransformerDecoder(D, D_enc, H, D_qk, D_v, D_ff, N)`
# - Forward: apply blocks sequentially, passing encoder output and causal mask to each
# - Test with $N = 6$
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 6 (10 points, coding task)
#
# Implement a complete `Transformer` (encoder-decoder) model.
#
# Components:
# - Source and target embedding layers (`nn.Embedding`)
# - Positional encoding (sinusoidal, from Assignment 05)
# - Encoder stack ($N_{\text{enc}}$ layers)
# - Decoder stack ($N_{\text{dec}}$ layers)
# - Output linear layer (projects to target vocabulary)
#
# Forward: `forward(src_ids, tgt_ids)` returns logits over target vocabulary.
# - `src_ids`: $(B, L_{\text{src}})$ integer token IDs
# - `tgt_ids`: $(B, L_{\text{tgt}})$ integer token IDs
# - Returns: $(B, L_{\text{tgt}}, V_{\text{tgt}})$ where $V_{\text{tgt}}$ is target vocab size
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 7 (10 points, coding task)
#
# Test the full Transformer.
#
# Create with: src_vocab=1000, tgt_vocab=1000, $D=64, H=4, D_{qk}=D_v=16, D_{ff}=256, N_{\text{enc}}=N_{\text{dec}}=2$.
#
# 1. Create random source tokens $(2, 10)$ and target tokens $(2, 8)$ (integers in $[0, 1000)$).
# 2. Forward pass. Assert output shape is $(2, 8, 1000)$.
# 3. Apply softmax to get probabilities. Assert each position sums to 1.
# 4. Count total parameters.
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 8 (5 points, non-coding task)
#
# Compare encoder-only (BERT), decoder-only (GPT), and encoder-decoder (original Transformer) architectures.
#
# For each:
# 1. What type(s) of attention does it use? (1 point each, 3 points total)
# 2. Give one task each is well-suited for. (2 points)
#
# Reasoning is required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 9 (10 points, coding task)
#
# Implement a GPT-style **decoder-only** model.
#
# This is simpler than the full transformer:
# - No encoder, no cross-attention
# - Each block: masked self-attention + FFN (with pre-norm)
# - Embedding + positional encoding + $N$ blocks + output projection
#
# Forward: `forward(token_ids)` returns logits $(B, L, V)$.
#
# Test with vocab=500, $D=32, H=4, D_{qk}=D_v=8, D_{ff}=128, N=4$.
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 10 (10 points, coding task)
#
# Autoregressive generation with your GPT model.
#
# Implement a `generate(model, prompt_ids, max_new_tokens)` function:
# 1. Start with `prompt_ids` of shape $(1, L_{\text{prompt}})$.
# 2. For each step:
#    - Forward pass through the model
#    - Take the logits at the LAST position
#    - Sample from the distribution (or take argmax)
#    - Append the new token to the sequence
# 3. Return the full sequence.
#
# Test: generate 20 tokens starting from prompt `[1, 2, 3]`. The output will be random (untrained model) but the shape and process should be correct.
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """
