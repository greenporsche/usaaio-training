# %% [markdown]
# # Assignment 01 — Self-Attention from Scratch (100 points)
#
# In this assignment, you will build single-head self-attention from the ground up, understanding every component.
#
# **Notation:**
# - $B$: batch size
# - $L$: sequence length
# - $D$: input/model hidden dimension
# - $D_{qk}$: query/key dimension
# - $D_v$: value dimension
# - $W^Q \in \mathbb{R}^{D \times D_{qk}}$: query projection
# - $W^K \in \mathbb{R}^{D \times D_{qk}}$: key projection
# - $W^V \in \mathbb{R}^{D \times D_v}$: value projection

# %%
"""
DO NOT MAKE ANY CHANGE IN THIS CELL.
"""
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

# %% [markdown]
# **WARNING**: You may only use `torch`, `torch.nn`, `torch.nn.functional`, and `numpy`. No other imports are allowed.

# %% [markdown]
# ## Part 1 (10 points, non-coding task)
#
# Given input $X \in \mathbb{R}^{L \times D}$ with $L = 8$, $D = 32$, $D_{qk} = 16$, $D_v = 24$:
#
# 1. What is the shape of $Q = XW^Q$?
# 2. What is the shape of $K = XW^K$?
# 3. What is the shape of $V = XW^V$?
# 4. What is the shape of $QK^T$?
# 5. What is the shape of the output $\text{softmax}(QK^T / \sqrt{D_{qk}}) V$?
#
# Reasoning is required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 2 (10 points, non-coding task)
#
# Explain the role of each component in self-attention:
#
# 1. Why do we use three separate projection matrices ($W^Q$, $W^K$, $W^V$) instead of using $X$ directly for all three? (5 points)
# 2. Why must $Q$ and $K$ have the same last dimension $D_{qk}$, while $V$ can have a different dimension $D_v$? (5 points)
#
# Reasoning is required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 3 (15 points, coding task)
#
# Implement a function `compute_attention_weights` that takes Q, K (without batch dimension) and returns the attention weight matrix.
#
# Specifically:
# - Input: $Q \in \mathbb{R}^{L_1 \times D_{qk}}$, $K \in \mathbb{R}^{L_2 \times D_{qk}}$
# - Compute scaled dot-product scores: $QK^T / \sqrt{D_{qk}}$
# - Apply softmax along the last dimension
# - Return: $\alpha \in \mathbb{R}^{L_1 \times L_2}$
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 4 (15 points, coding task)
#
# Implement a function `single_head_attention` that performs the complete single-head attention computation.
#
# - Input: $X \in \mathbb{R}^{L \times D}$, $W^Q \in \mathbb{R}^{D \times D_{qk}}$, $W^K \in \mathbb{R}^{D \times D_{qk}}$, $W^V \in \mathbb{R}^{D \times D_v}$
# - Output: attention output $\in \mathbb{R}^{L \times D_v}$, attention weights $\in \mathbb{R}^{L \times L}$
#
# Return both the output and the attention weights as a tuple.
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 5 (20 points, coding task)
#
# Implement `MySingleHeadAttention` as an `nn.Module` that supports **batched** inputs.
#
# Your module must:
# - Accept `D`, `D_qk`, `D_v` as constructor arguments
# - Use `nn.Linear` (with `bias=False`) for $W^Q$, $W^K$, $W^V$
# - `forward(self, X)` takes $X$ of shape $(B, L, D)$ and returns output of shape $(B, L, D_v)$
# - Use `.mT` for batched transpose (NOT `.T`)
#
# Annotate shapes after every operation.
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 6 (10 points, coding task)
#
# Test your `MySingleHeadAttention` module:
#
# 1. Create an instance with $D = 16$, $D_{qk} = 8$, $D_v = 12$.
# 2. Create a random input tensor with $B = 2$, $L = 5$, $D = 16$.
# 3. Pass the input through the module.
# 4. Assert that the output shape is $(2, 5, 12)$.
# 5. Assert that the output is a valid tensor (no NaN or Inf values).
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 7 (10 points, non-coding task)
#
# Consider the attention weight matrix $\alpha \in \mathbb{R}^{L \times L}$.
#
# 1. Prove that each row of $\alpha$ sums to 1. (3 points)
# 2. Prove that all entries of $\alpha$ are strictly positive (assuming finite inputs). (3 points)
# 3. The output for token $i$ is $\sum_j \alpha_{ij} V_j$. This is a convex combination of the value vectors. What geometric property does this imply about the output? (4 points)
#
# Reasoning is required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ## Part 8 (10 points, coding task)
#
# Verify numerically that self-attention is **permutation equivariant** (without positional encoding).
#
# 1. Create a `MySingleHeadAttention` module with $D = 8$, $D_{qk} = 4$, $D_v = 6$.
# 2. Create a random input $X$ of shape $(1, 4, 8)$.
# 3. Compute output $Y = \text{attn}(X)$.
# 4. Create a permutation of the sequence dimension (e.g., $[2, 0, 3, 1]$).
# 5. Compute $Y' = \text{attn}(X_{\text{permuted}})$.
# 6. Verify that $Y'$ equals $Y_{\text{permuted}}$ (up to floating-point tolerance).
#
# Use `torch.allclose` with appropriate tolerance.
#
# Reasoning is not required.

# %% [markdown]
# ### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """
