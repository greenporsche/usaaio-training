# %% [markdown]
# # Assignment 10: Comprehensive NLP Challenge (100 points)
#
# **Unit 08 — Natural Language Processing (AI 510-NLP)**
#
# This is a contest-style assignment that combines tokenization, embeddings, and transformer models into a unified NLP system. You will build a document analysis pipeline that performs multiple NLP tasks.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from collections import Counter
from transformers import BertTokenizer, BertModel, GPT2LMHeadModel, GPT2Tokenizer

# %% [markdown]
# ---
#
# **WARNING**: Do **not** modify any cell that you are not explicitly asked to modify. Do **not** import additional libraries unless specified. Write all solutions where indicated by `### WRITE YOUR SOLUTION HERE ###`.

# %% [markdown]
# ## Part 1: Custom Tokenizer with BPE (20 points)
#
# Implement a `CompactBPE` class that combines BPE training and inference in a clean interface.
#
# Requirements:
# 1. Train on a corpus with configurable number of merges
# 2. Encode text to integer IDs (with special tokens)
# 3. Decode IDs back to text
# 4. Report vocabulary size and compression ratio
#
# Special tokens: `<pad>` (0), `<unk>` (1), `<bos>` (2), `<eos>` (3)

# %%
class CompactBPE:
    """Complete BPE tokenizer with special token support."""

    SPECIAL_TOKENS = {'<pad>': 0, '<unk>': 1, '<bos>': 2, '<eos>': 3}

    def __init__(self, num_merges: int = 1000):
        self.num_merges = num_merges
        self.merges: list[tuple[str, str]] = []
        self.token_to_id: dict[str, int] = {}
        self.id_to_token: dict[int, str] = {}

    def train(self, corpus: str) -> None:
        """Train BPE on corpus. Build merges list and token-to-ID mapping."""
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def encode(self, text: str) -> list[int]:
        """Encode text to token IDs with <bos> and <eos>.
        Unknown tokens map to <unk>."""
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def decode(self, ids: list[int]) -> str:
        """Decode token IDs back to text. Strip special tokens."""
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    @property
    def vocab_size(self) -> int:
        return len(self.token_to_id)

# %% [markdown]
# ## Part 2: Semantic Search with BERT (25 points)
#
# Implement a `SemanticSearch` class that:
# 1. Encodes documents into dense vectors using BERT [CLS] embeddings
# 2. Builds an index of document embeddings
# 3. Given a query, finds the most relevant documents by cosine similarity
#
# **Shapes**:
# - Document embeddings index: (N, 768) where N = number of documents
# - Query embedding: (768,)
# - Similarity scores: (N,)

# %%
class SemanticSearch:
    """BERT-based semantic search over a document corpus."""

    def __init__(self, tokenizer: BertTokenizer, model: BertModel,
                 max_length: int = 128):
        self.tokenizer = tokenizer
        self.model = model
        self.max_length = max_length
        self.document_embeddings: np.ndarray | None = None  # (N, 768)
        self.documents: list[str] = []

    def _encode_text(self, text: str) -> np.ndarray:
        """Encode a single text into a 768-dim vector using BERT [CLS].

        Returns: (768,) numpy array
        """
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def index_documents(self, documents: list[str]) -> None:
        """Build embedding index for a list of documents.

        Sets self.document_embeddings to (N, 768) array.
        """
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def search(self, query: str, top_k: int = 5) -> list[tuple[str, float]]:
        """Search for most relevant documents.

        Args:
            query: Search query text
            top_k: Number of results

        Returns:
            List of (document_text, similarity_score) tuples
        """
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Contextual Word Similarity (20 points)
#
# Implement `contextual_word_similarity` that computes how similar a word's usage is across different sentences, using BERT's contextualized embeddings.
#
# This is useful for word sense disambiguation — the same word in different contexts should have different embeddings.
#
# **Shapes**:
# - Per-sentence word embedding: (768,)
# - Similarity matrix: (N, N) for N sentences

# %%
def contextual_word_similarity(
    target_word: str,
    sentences: list[str],
    tokenizer: BertTokenizer,
    model: BertModel
) -> tuple[np.ndarray, list[np.ndarray]]:
    """Compute contextual similarity of a word across sentences.

    For each sentence, extract the target word's embedding from BERT's last layer.
    If the word is split into subwords, average the subword embeddings.

    Args:
        target_word: Word to analyze
        sentences: List of N sentences containing target_word
        tokenizer: BERT tokenizer
        model: BERT model

    Returns:
        sim_matrix: (N, N) pairwise cosine similarity matrix
        embeddings: List of N (768,) arrays, one per sentence
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Conditional Text Generation (20 points)
#
# Implement `generate_continuation` that uses GPT-2 to generate text continuations with configurable parameters.
#
# The function should support:
# - Multiple generation strategies (greedy, temperature, top-k, nucleus)
# - Repetition penalty (reduce probability of recently generated tokens)
# - Stop sequences (stop generation when a specific string is generated)
#
# **Repetition penalty**: For previously generated tokens, divide their logits by the penalty factor:
# $$z_w \leftarrow z_w / \text{penalty} \quad \text{if } w \in \text{generated tokens}$$

# %%
def generate_continuation(
    prompt: str,
    tokenizer: GPT2Tokenizer,
    model: GPT2LMHeadModel,
    max_new_tokens: int = 100,
    temperature: float = 1.0,
    top_k: int = 0,
    top_p: float = 1.0,
    repetition_penalty: float = 1.0,
    stop_sequences: list[str] | None = None
) -> str:
    """Generate text with advanced controls.

    Args:
        prompt: Starting text
        tokenizer: GPT-2 tokenizer
        model: GPT-2 model
        max_new_tokens: Maximum tokens to generate
        temperature: Sampling temperature (>0)
        top_k: Top-k filtering (0 = disabled)
        top_p: Nucleus filtering (1.0 = disabled)
        repetition_penalty: Penalty for repeating tokens (1.0 = none)
        stop_sequences: Stop if any of these strings appear in output

    Returns:
        Full generated text (prompt + continuation)
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Multi-task Document Analyzer (15 points)
#
# Combine the components into a `DocumentAnalyzer` class that, given a document:
# 1. Tokenizes it with BPE and reports statistics
# 2. Generates a continuation using GPT-2
# 3. Finds similar documents from a corpus using BERT
#
# This demonstrates the integration of all NLP concepts from this unit.

# %%
class DocumentAnalyzer:
    """Multi-task document analysis using NLP models."""

    def __init__(self, bpe_tokenizer: CompactBPE,
                 semantic_search: SemanticSearch,
                 gpt_tokenizer: GPT2Tokenizer,
                 gpt_model: GPT2LMHeadModel):
        self.bpe = bpe_tokenizer
        self.search = semantic_search
        self.gpt_tokenizer = gpt_tokenizer
        self.gpt_model = gpt_model

    def analyze(self, document: str, top_k_similar: int = 3,
                continuation_length: int = 50) -> dict:
        """Perform full document analysis.

        Args:
            document: Input document text
            top_k_similar: Number of similar documents to retrieve
            continuation_length: Tokens to generate as continuation

        Returns:
            Dictionary with:
            - 'bpe_tokens': list of BPE token strings
            - 'bpe_ids': list of token IDs
            - 'num_tokens': number of BPE tokens
            - 'compression_ratio': len(document) / num_tokens
            - 'similar_documents': list of (text, score) tuples
            - 'continuation': generated text continuation
        """
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """
