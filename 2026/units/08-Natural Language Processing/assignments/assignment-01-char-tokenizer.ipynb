# %% [markdown]
# # Assignment 01: Character Tokenizer from Scratch (100 points)
#
# **Unit 08 — Natural Language Processing (AI 510-NLP)**
#
# Build a complete character-level tokenizer with encode/decode functionality, vocabulary management, and batch processing.

# %%
import torch
import torch.nn as nn
import numpy as np
from typing import Optional

# %% [markdown]
# ---
#
# **WARNING**: Do **not** modify any cell that you are not explicitly asked to modify. Do **not** import additional libraries unless specified. Write all solutions where indicated by `### WRITE YOUR SOLUTION HERE ###`.

# %% [markdown]
# ## Part 1: Basic Character Tokenizer (30 points)
#
# Implement a `CharTokenizer` class that:
# 1. Builds a vocabulary from a given text string
# 2. Includes special tokens: `<pad>` (0), `<unk>` (1), `<bos>` (2), `<eos>` (3)
# 3. Encodes text to a list of integer token IDs
# 4. Decodes a list of integer token IDs back to text
#
# **Shapes**:
# - `encode(text: str) -> list[int]` — length equals `len(text) + 2` (BOS + text + EOS)
# - `decode(ids: list[int]) -> str` — strips special tokens, returns original text
# - `vocab_size` property — returns total vocabulary size (special tokens + unique characters)

# %%
class CharTokenizer:
    """Character-level tokenizer with special tokens."""

    SPECIAL_TOKENS = ['<pad>', '<unk>', '<bos>', '<eos>']

    def __init__(self):
        self.char_to_id: dict[str, int] = {}
        self.id_to_char: dict[int, str] = {}

    def train(self, text: str) -> None:
        """Build vocabulary from text.

        Assigns IDs 0-3 to special tokens, then sorted unique characters get IDs from 4 onwards.
        """
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    @property
    def vocab_size(self) -> int:
        """Return total vocabulary size."""
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def encode(self, text: str) -> list[int]:
        """Encode text to token IDs. Wraps with <bos> and <eos>.

        Unknown characters map to <unk> ID.
        Returns list of length len(text) + 2.
        """
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def decode(self, ids: list[int]) -> str:
        """Decode token IDs back to text. Strips special tokens."""
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Batch Encoding with Padding (30 points)
#
# Implement `batch_encode` that:
# 1. Takes a list of strings
# 2. Encodes each string (with BOS/EOS)
# 3. Pads all sequences to the same length using the `<pad>` token
# 4. Returns a PyTorch tensor of shape `(B, L_max)` and an attention mask of shape `(B, L_max)`
#
# **Shapes**:
# - `input_ids: (B, L_max)` — int64 tensor, padded with 0s
# - `attention_mask: (B, L_max)` — float32 tensor, 1.0 for real tokens, 0.0 for padding

# %%
def batch_encode(tokenizer: CharTokenizer, texts: list[str]) -> tuple[torch.Tensor, torch.Tensor]:
    """Encode a batch of texts with padding.

    Args:
        tokenizer: Trained CharTokenizer
        texts: List of B strings

    Returns:
        input_ids: (B, L_max) int64 tensor
        attention_mask: (B, L_max) float32 tensor
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Character Embedding Layer (20 points)
#
# Create a `CharEmbedding` module that:
# 1. Uses `nn.Embedding` to map token IDs to dense vectors
# 2. Adds learned positional embeddings
# 3. Sets padding token embedding to zero (using `padding_idx`)
#
# **Shapes**:
# - Input: `(B, L)` int64 token IDs
# - Output: `(B, L, embed_dim)` float32 embeddings
# - `nn.Embedding` vocab table: `(vocab_size, embed_dim)`
# - Positional embedding table: `(max_len, embed_dim)`

# %%
class CharEmbedding(nn.Module):
    """Character embedding with positional encoding."""

    def __init__(self, vocab_size: int, embed_dim: int, max_len: int = 512):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def forward(self, input_ids: torch.Tensor) -> torch.Tensor:
        """Compute embeddings.

        Args:
            input_ids: (B, L) token IDs

        Returns:
            embeddings: (B, L, embed_dim)
        """
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Tokenizer Analysis (20 points)
#
# Using your `CharTokenizer`, analyze tokenization statistics for the following corpus:
#
# ```
# corpus = [
#     "The quick brown fox jumps over the lazy dog",
#     "Natural language processing with neural networks",
#     "BERT uses bidirectional transformers",
#     "GPT generates text autoregressively"
# ]
# ```
#
# Implement `analyze_tokenizer` that returns a dictionary with:
# - `vocab_size`: total vocabulary size
# - `avg_seq_length`: average encoded sequence length (including BOS/EOS)
# - `max_seq_length`: maximum encoded sequence length
# - `compression_ratio`: average ratio of original text length to encoded sequence length (should be close to 1.0 for character-level)
# - `unique_chars`: number of unique characters (excluding special tokens)

# %%
def analyze_tokenizer(tokenizer: CharTokenizer, corpus: list[str]) -> dict:
    """Analyze tokenization statistics.

    Args:
        tokenizer: Trained CharTokenizer
        corpus: List of text strings

    Returns:
        Dictionary with keys: vocab_size, avg_seq_length, max_seq_length,
        compression_ratio, unique_chars
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """
