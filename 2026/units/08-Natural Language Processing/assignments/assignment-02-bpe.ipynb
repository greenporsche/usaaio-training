# %% [markdown]
# # Assignment 02: Byte Pair Encoding from Scratch (100 points)
#
# **Unit 08 — Natural Language Processing (AI 510-NLP)**
#
# Implement the BPE tokenization algorithm: training (learning merge rules) and inference (applying merges to tokenize new text).

# %%
import torch
import numpy as np
from collections import Counter

# %% [markdown]
# ---
#
# **WARNING**: Do **not** modify any cell that you are not explicitly asked to modify. Do **not** import additional libraries unless specified. Write all solutions where indicated by `### WRITE YOUR SOLUTION HERE ###`.

# %% [markdown]
# ## Part 1: Count Adjacent Pairs (20 points)
#
# Implement `get_pair_counts` that counts all adjacent symbol pairs in the corpus.
#
# The corpus is represented as a dictionary mapping space-separated symbol sequences to their frequency.
#
# Example:
# ```python
# word_freqs = {
#     'l o w _': 5,
#     'n e w _': 3,
# }
# # Returns: Counter({('l', 'o'): 5, ('o', 'w'): 5, ('w', '_'): 8, ('n', 'e'): 3, ('e', 'w'): 3})
# ```

# %%
def get_pair_counts(word_freqs: dict[str, int]) -> Counter:
    """Count all adjacent symbol pairs across the corpus.

    Args:
        word_freqs: Dict mapping space-separated symbol sequences to frequency

    Returns:
        Counter mapping (symbol_a, symbol_b) tuples to their total count
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Merge a Pair (20 points)
#
# Implement `merge_pair` that replaces all occurrences of a given adjacent pair with the merged symbol.
#
# Example:
# ```python
# word_freqs = {'l o w _': 5}
# merge_pair(('l', 'o'), word_freqs)
# # Returns: {'lo w _': 5}
# ```

# %%
def merge_pair(pair: tuple[str, str], word_freqs: dict[str, int]) -> dict[str, int]:
    """Merge all occurrences of pair in the corpus.

    Args:
        pair: (symbol_a, symbol_b) to merge
        word_freqs: Current corpus representation

    Returns:
        New word_freqs with pair merged into single symbol
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 3: BPE Training (25 points)
#
# Implement `train_bpe` that learns merge rules from a text corpus.
#
# Steps:
# 1. Tokenize the corpus into words and count word frequencies
# 2. Represent each word as space-separated characters with end-of-word marker `_`
# 3. For `num_merges` iterations: find most frequent pair, merge it, record the merge
#
# Return the ordered list of merges and the final vocabulary.

# %%
def train_bpe(text: str, num_merges: int) -> tuple[list[tuple[str, str]], set[str]]:
    """Train BPE on a text corpus.

    Args:
        text: Training text
        num_merges: Number of merge operations to perform

    Returns:
        merges: Ordered list of (symbol_a, symbol_b) merge rules
        vocab: Set of all symbols in the final vocabulary
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 4: BPE Inference (25 points)
#
# Implement `bpe_tokenize` that tokenizes new text using learned merge rules.
#
# For each word:
# 1. Split into characters with end-of-word marker
# 2. Apply each merge rule in order
# 3. Collect resulting tokens
#
# Return the list of subword tokens.

# %%
def bpe_tokenize(text: str, merges: list[tuple[str, str]]) -> list[str]:
    """Tokenize text using learned BPE merge rules.

    Args:
        text: Text to tokenize
        merges: Ordered list of merge rules from train_bpe

    Returns:
        List of subword tokens
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: BPE Analysis (10 points)
#
# Train BPE with different numbers of merges on the given corpus and analyze the vocabulary size vs. average sequence length tradeoff.
#
# Return a list of `(num_merges, vocab_size, avg_tokens_per_word)` tuples for `num_merges` in `[0, 5, 10, 20, 50]`.

# %%
corpus = """the cat sat on the mat the cat ate the rat
the dog sat on the log the dog bit the frog
lower lowest newer newest wider widest"""

def analyze_bpe_tradeoff(text: str, merge_counts: list[int]) -> list[tuple[int, int, float]]:
    """Analyze vocab size vs sequence length for different merge counts.

    Args:
        text: Training corpus
        merge_counts: List of num_merges values to try

    Returns:
        List of (num_merges, vocab_size, avg_tokens_per_word) tuples
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """
