# %% [markdown]
# # Assignment 03: Skip-gram with Negative Sampling (100 points)
#
# **Unit 08 — Natural Language Processing (AI 510-NLP)**
#
# Implement the Word2Vec Skip-gram model with negative sampling from scratch in PyTorch.

# %%
import torch
import torch.nn as nn
import numpy as np
from collections import Counter
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# ---
#
# **WARNING**: Do **not** modify any cell that you are not explicitly asked to modify. Do **not** import additional libraries unless specified. Write all solutions where indicated by `### WRITE YOUR SOLUTION HERE ###`.

# %% [markdown]
# ## Part 1: Build Vocabulary and Training Pairs (20 points)
#
# Implement:
# 1. `build_vocab(corpus, min_count)` — build word-to-index mapping, filtering rare words
# 2. `generate_pairs(corpus_ids, window_size)` — generate (center, context) training pairs
#
# **Shapes**:
# - `corpus_ids`: list of int (token IDs for the entire corpus)
# - pairs: list of (int, int) tuples

# %%
def build_vocab(corpus: list[str], min_count: int = 2) -> tuple[dict[str, int], dict[int, str], list[int]]:
    """Build vocabulary from tokenized corpus.

    Args:
        corpus: List of words (already tokenized)
        min_count: Minimum frequency to include a word

    Returns:
        word_to_id: Word to index mapping
        id_to_word: Index to word mapping
        word_counts: List where word_counts[i] = frequency of word i
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """


def generate_pairs(corpus_ids: list[int], window_size: int = 5) -> list[tuple[int, int]]:
    """Generate (center, context) training pairs.

    Args:
        corpus_ids: List of token IDs for the corpus
        window_size: Number of context words on each side

    Returns:
        List of (center_id, context_id) tuples
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Noise Distribution (15 points)
#
# Implement the noise distribution for negative sampling:
#
# $$P_n(w) = \frac{\text{count}(w)^{3/4}}{\sum_{w'} \text{count}(w')^{3/4}}$$
#
# Return a tensor of shape `(V,)` representing the sampling probability for each word.

# %%
def build_noise_distribution(word_counts: list[int], power: float = 0.75) -> torch.Tensor:
    """Build the noise distribution for negative sampling.

    Args:
        word_counts: List where word_counts[i] = frequency of word i
        power: Exponent to smooth the distribution (default 0.75)

    Returns:
        probs: (V,) tensor of sampling probabilities, sums to 1
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Skip-gram Model (30 points)
#
# Implement the Skip-gram model with negative sampling loss.
#
# The model has two embedding matrices:
# - `center_embeddings`: (V, D) — embeddings for center words
# - `context_embeddings`: (V, D) — embeddings for context words
#
# The negative sampling loss for one (center, context) pair with K negatives is:
#
# $$J = -\log \sigma(u_{w_o}^T v_{w_c}) - \sum_{k=1}^{K} \log \sigma(-u_{w_k}^T v_{w_c})$$
#
# **Shapes**:
# - `center_ids`: (B,)
# - `context_ids`: (B,)
# - `negative_ids`: (B, K)
# - loss: scalar

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_size: int, embed_dim: int):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def forward(self, center_ids: torch.Tensor, context_ids: torch.Tensor,
                negative_ids: torch.Tensor) -> torch.Tensor:
        """Compute negative sampling loss.

        Args:
            center_ids:   (B,) center word indices
            context_ids:  (B,) positive context word indices
            negative_ids: (B, K) negative sample indices

        Returns:
            loss: scalar tensor
        """
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def get_embeddings(self) -> torch.Tensor:
        """Return the center word embeddings as the final word vectors.

        Returns:
            embeddings: (V, D) tensor
        """
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Training Loop (20 points)
#
# Implement the training loop. Use the noise distribution for sampling negatives.
#
# You must:
# 1. Create a Dataset class for the training pairs
# 2. Sample negatives from the noise distribution during each batch
# 3. Train for the specified number of epochs
# 4. Return the training loss history

# %%
class SkipGramDataset(Dataset):
    def __init__(self, pairs: list[tuple[int, int]]):
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def __len__(self):
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def __getitem__(self, idx):
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """


def train_skipgram(model: SkipGram, pairs: list[tuple[int, int]],
                   noise_dist: torch.Tensor, num_negatives: int = 5,
                   epochs: int = 10, batch_size: int = 256,
                   lr: float = 0.001) -> list[float]:
    """Train the Skip-gram model.

    Args:
        model: SkipGram model
        pairs: Training (center, context) pairs
        noise_dist: (V,) noise distribution for negative sampling
        num_negatives: Number of negative samples per positive pair
        epochs: Number of training epochs
        batch_size: Batch size
        lr: Learning rate

    Returns:
        losses: List of average loss per epoch
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Evaluation — Cosine Similarity and Analogies (15 points)
#
# Implement `most_similar` and `analogy` functions using the learned embeddings.

# %%
def most_similar(word: str, embeddings: torch.Tensor, word_to_id: dict,
                 id_to_word: dict, top_k: int = 5) -> list[tuple[str, float]]:
    """Find the top-k most similar words by cosine similarity.

    Args:
        word: Query word
        embeddings: (V, D) embedding matrix
        word_to_id: Word to index mapping
        id_to_word: Index to word mapping
        top_k: Number of results

    Returns:
        List of (word, similarity) tuples, sorted by decreasing similarity
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """


def analogy(a: str, b: str, c: str, embeddings: torch.Tensor,
            word_to_id: dict, id_to_word: dict, top_k: int = 5) -> list[tuple[str, float]]:
    """Solve analogy: a is to b as c is to ?

    Computes: result = embeddings[b] - embeddings[a] + embeddings[c]
    Returns top-k words closest to result (excluding a, b, c).

    Args:
        a, b, c: Analogy words
        embeddings: (V, D) embedding matrix
        word_to_id: Word to index mapping
        id_to_word: Index to word mapping
        top_k: Number of results

    Returns:
        List of (word, similarity) tuples
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """
