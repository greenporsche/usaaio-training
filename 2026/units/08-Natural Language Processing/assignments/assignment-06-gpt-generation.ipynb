# %% [markdown]
# # Assignment 06: GPT Text Generation (100 points)
#
# **Unit 08 — Natural Language Processing (AI 510-NLP)**
#
# Use pretrained GPT-2 for autoregressive text generation. Implement greedy, temperature, top-k, and nucleus sampling strategies.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %% [markdown]
# ---
#
# **WARNING**: Do **not** modify any cell that you are not explicitly asked to modify. Do **not** import additional libraries unless specified. Write all solutions where indicated by `### WRITE YOUR SOLUTION HERE ###`.

# %% [markdown]
# ## Part 1: Greedy Generation (20 points)
#
# Implement `generate_greedy` that generates text by always selecting the highest-probability next token.
#
# **Shapes**:
# - Input IDs: (1, L) → grows each step
# - Model output logits: (1, L, V) where V = 50257
# - Next token: take argmax of logits at last position → (1, 1)
# - Concatenate to input → (1, L+1)

# %%
def generate_greedy(prompt: str, tokenizer: GPT2Tokenizer,
                    model: GPT2LMHeadModel,
                    max_new_tokens: int = 50) -> str:
    """Generate text using greedy decoding.

    Args:
        prompt: Starting text
        tokenizer: GPT-2 tokenizer
        model: Pretrained GPT-2
        max_new_tokens: Maximum number of tokens to generate

    Returns:
        Generated text (prompt + new tokens)
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Temperature Sampling (20 points)
#
# Implement `generate_temperature` that scales logits by temperature $T$ before sampling.
#
# $$P(w) = \frac{\exp(z_w / T)}{\sum_{w'} \exp(z_{w'} / T)}$$
#
# Use `torch.multinomial` to sample from the distribution.

# %%
def generate_temperature(prompt: str, tokenizer: GPT2Tokenizer,
                         model: GPT2LMHeadModel,
                         max_new_tokens: int = 50,
                         temperature: float = 1.0) -> str:
    """Generate text with temperature sampling.

    Args:
        prompt: Starting text
        tokenizer: GPT-2 tokenizer
        model: Pretrained GPT-2
        max_new_tokens: Maximum tokens to generate
        temperature: Sampling temperature (>0). Lower = more deterministic.

    Returns:
        Generated text
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Top-k Sampling (20 points)
#
# Implement `generate_top_k` that:
# 1. Applies temperature scaling
# 2. Keeps only the top-k highest-probability tokens
# 3. Sets all other logits to $-\infty$
# 4. Renormalizes via softmax and samples

# %%
def top_k_filter(logits: torch.Tensor, k: int) -> torch.Tensor:
    """Filter logits to keep only top-k values.

    Args:
        logits: (V,) raw logits
        k: Number of top values to keep

    Returns:
        filtered_logits: (V,) with non-top-k values set to -inf
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """


def generate_top_k(prompt: str, tokenizer: GPT2Tokenizer,
                   model: GPT2LMHeadModel,
                   max_new_tokens: int = 50,
                   temperature: float = 1.0,
                   k: int = 50) -> str:
    """Generate text with top-k sampling.

    Args:
        prompt: Starting text
        tokenizer: GPT-2 tokenizer
        model: Pretrained GPT-2
        max_new_tokens: Maximum tokens to generate
        temperature: Sampling temperature
        k: Number of top tokens to sample from

    Returns:
        Generated text
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Nucleus (Top-p) Sampling (20 points)
#
# Implement `generate_nucleus` that:
# 1. Applies temperature scaling
# 2. Sorts tokens by probability
# 3. Computes cumulative probability
# 4. Keeps the smallest set of tokens with cumulative probability >= p
# 5. Sets all other logits to $-\infty$ and samples

# %%
def nucleus_filter(logits: torch.Tensor, p: float) -> torch.Tensor:
    """Filter logits to keep nucleus (top-p) tokens.

    Args:
        logits: (V,) raw logits
        p: Cumulative probability threshold

    Returns:
        filtered_logits: (V,) with non-nucleus values set to -inf
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """


def generate_nucleus(prompt: str, tokenizer: GPT2Tokenizer,
                     model: GPT2LMHeadModel,
                     max_new_tokens: int = 50,
                     temperature: float = 1.0,
                     p: float = 0.95) -> str:
    """Generate text with nucleus (top-p) sampling.

    Args:
        prompt: Starting text
        tokenizer: GPT-2 tokenizer
        model: Pretrained GPT-2
        max_new_tokens: Maximum tokens to generate
        temperature: Sampling temperature
        p: Nucleus probability threshold

    Returns:
        Generated text
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 5: Perplexity Evaluation (20 points)
#
# Implement `compute_perplexity` that computes the perplexity of GPT-2 on a given text.
#
# $$\text{PPL} = \exp\left(-\frac{1}{T}\sum_{t=1}^{T} \log P(x_t \mid x_{<t})\right)$$
#
# **Shapes**:
# - Input IDs: (1, L)
# - Logits: (1, L, V)
# - For position t, the correct next token is `input_ids[0, t+1]`
# - Extract log prob: `log_softmax(logits[0, t])[input_ids[0, t+1]]`

# %%
def compute_perplexity(text: str, tokenizer: GPT2Tokenizer,
                        model: GPT2LMHeadModel) -> float:
    """Compute perplexity of GPT-2 on the given text.

    Args:
        text: Input text to evaluate
        tokenizer: GPT-2 tokenizer
        model: Pretrained GPT-2

    Returns:
        Perplexity (float, >= 1.0)
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """
