# %% [markdown]
# # Assignment 05: BERT Masked Prediction (100 points)
#
# **Unit 08 — Natural Language Processing (AI 510-NLP)**
#
# Use pretrained BERT to predict masked tokens, analyze attention patterns, and extract contextualized embeddings.

# %%
import torch
import torch.nn as nn
import numpy as np
from transformers import BertTokenizer, BertModel, BertForMaskedLM

# %% [markdown]
# ---
#
# **WARNING**: Do **not** modify any cell that you are not explicitly asked to modify. Do **not** import additional libraries unless specified. Write all solutions where indicated by `### WRITE YOUR SOLUTION HERE ###`.

# %% [markdown]
# ## Part 1: Masked Token Prediction (25 points)
#
# Implement `predict_masked` that:
# 1. Takes a sentence with one `[MASK]` token
# 2. Runs it through pretrained BERT
# 3. Returns the top-k predicted tokens with their probabilities
#
# **Shapes**:
# - Input token IDs: (1, L)
# - BERT output logits: (1, L, V) where V = 30522
# - Masked position logits: (V,)
# - After softmax: (V,) probabilities

# %%
def predict_masked(sentence: str, tokenizer: BertTokenizer,
                   model: BertForMaskedLM,
                   top_k: int = 10) -> list[tuple[str, float]]:
    """Predict the masked token in a sentence.

    Args:
        sentence: Input sentence containing exactly one [MASK] token
        tokenizer: BERT tokenizer
        model: Pretrained BERT for masked LM
        top_k: Number of top predictions to return

    Returns:
        List of (token_string, probability) tuples sorted by decreasing probability
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Multi-mask Prediction (20 points)
#
# Extend to handle sentences with **multiple** `[MASK]` tokens.
#
# For each masked position, independently predict the top-k tokens.
#
# Return a dictionary mapping mask position index to top-k predictions.

# %%
def predict_multi_mask(sentence: str, tokenizer: BertTokenizer,
                        model: BertForMaskedLM,
                        top_k: int = 5) -> dict[int, list[tuple[str, float]]]:
    """Predict multiple masked tokens in a sentence.

    Args:
        sentence: Input sentence containing one or more [MASK] tokens
        tokenizer: BERT tokenizer
        model: Pretrained BERT for masked LM
        top_k: Number of top predictions per mask

    Returns:
        Dict mapping mask_index (0-based among masks) to list of (token, prob) tuples
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Attention Analysis (25 points)
#
# Extract and analyze attention patterns from BERT.
#
# Implement `get_attention_map` that:
# 1. Runs a sentence through BERT with `output_attentions=True`
# 2. Extracts attention weights for a specified layer and head
# 3. Returns the attention weight matrix and corresponding tokens
#
# **Shapes**:
# - `outputs.attentions`: tuple of 12 tensors, each (B, 12, L, L)
# - Returned attention map: (L, L) numpy array

# %%
def get_attention_map(sentence: str, tokenizer: BertTokenizer,
                      model: BertModel, layer: int = 0,
                      head: int = 0) -> tuple[np.ndarray, list[str]]:
    """Extract attention weights for a specific layer and head.

    Args:
        sentence: Input sentence
        tokenizer: BERT tokenizer
        model: BERT model (with output_attentions=True in config)
        layer: Transformer layer index (0-11)
        head: Attention head index (0-11)

    Returns:
        attention_weights: (L, L) numpy array where [i][j] = how much token i attends to token j
        tokens: List of L token strings
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """


def find_attending_tokens(attention_weights: np.ndarray, tokens: list[str],
                          target_token: str, threshold: float = 0.1) -> list[tuple[str, float]]:
    """Find which tokens attend strongly to a target token.

    Args:
        attention_weights: (L, L) attention matrix
        tokens: List of token strings
        target_token: Token to analyze
        threshold: Minimum attention weight to include

    Returns:
        List of (token, weight) for tokens attending to target above threshold
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Contextualized Embeddings (30 points)
#
# Demonstrate that BERT produces different embeddings for the same word in different contexts.
#
# Implement `extract_word_embedding` that:
# 1. Tokenizes the sentence
# 2. Runs through BERT
# 3. Extracts the hidden state at the specified word's position (from a given layer)
#
# Then implement `compare_contexts` that takes a word and multiple sentences, extracts the word's embedding from each, and computes pairwise cosine similarities.
#
# **Shapes**:
# - Hidden states per layer: (1, L, 768)
# - Extracted embedding: (768,) numpy array
# - Similarity matrix: (N, N) numpy array for N sentences

# %%
def extract_word_embedding(sentence: str, target_word: str,
                            tokenizer: BertTokenizer, model: BertModel,
                            layer: int = -1) -> np.ndarray:
    """Extract BERT embedding for a specific word in a sentence.

    If the word is split into multiple subword tokens, average their embeddings.

    Args:
        sentence: Input sentence containing target_word
        target_word: Word to extract embedding for
        tokenizer: BERT tokenizer
        model: BERT model (output_hidden_states=True)
        layer: Which layer to extract from (-1 = last layer)

    Returns:
        embedding: (768,) numpy array
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """


def compare_contexts(target_word: str, sentences: list[str],
                      tokenizer: BertTokenizer, model: BertModel,
                      layer: int = -1) -> np.ndarray:
    """Compare embeddings of the same word across different contexts.

    Args:
        target_word: Word that appears in all sentences
        sentences: List of N sentences
        tokenizer, model: BERT tokenizer and model
        layer: Layer to extract from

    Returns:
        sim_matrix: (N, N) pairwise cosine similarity matrix
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """
