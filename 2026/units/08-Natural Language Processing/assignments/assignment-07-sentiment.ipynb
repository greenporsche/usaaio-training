# %% [markdown]
# # Assignment 07: Sentiment Classification (100 points)
#
# **Unit 08 — Natural Language Processing (AI 510-NLP)**
#
# Fine-tune a pretrained BERT model for binary sentiment classification on movie reviews.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertModel, get_linear_schedule_with_warmup

# %% [markdown]
# ---
#
# **WARNING**: Do **not** modify any cell that you are not explicitly asked to modify. Do **not** import additional libraries unless specified. Write all solutions where indicated by `### WRITE YOUR SOLUTION HERE ###`.

# %% [markdown]
# ## Part 1: Dataset Class (20 points)
#
# Implement `SentimentDataset` that:
# 1. Stores texts and binary labels (0=negative, 1=positive)
# 2. Tokenizes each text with BERT tokenizer on-the-fly
# 3. Pads/truncates to `max_length`
# 4. Returns a dictionary with `input_ids`, `attention_mask`, and `label`
#
# **Shapes**:
# - `input_ids`: (max_length,) int64
# - `attention_mask`: (max_length,) int64
# - `label`: scalar int64

# %%
class SentimentDataset(Dataset):
    def __init__(self, texts: list[str], labels: list[int],
                 tokenizer: BertTokenizer, max_length: int = 128):
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def __len__(self) -> int:
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def __getitem__(self, idx: int) -> dict[str, torch.Tensor]:
        """Return tokenized example.

        Returns dict with keys: input_ids, attention_mask, label
        """
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

# %% [markdown]
# ## Part 2: Sentiment Classifier Model (25 points)
#
# Implement `SentimentClassifier` that:
# 1. Uses a pretrained BERT backbone
# 2. Extracts the `[CLS]` token's hidden state from the last layer
# 3. Applies dropout and a linear classification head
# 4. Supports optional backbone freezing
#
# **Shapes**:
# - BERT output: (B, L, 768)
# - [CLS] embedding: (B, 768)
# - After dropout: (B, 768)
# - Logits: (B, 2)

# %%
class SentimentClassifier(nn.Module):
    def __init__(self, num_classes: int = 2, dropout: float = 0.1,
                 freeze_bert: bool = False):
        super().__init__()
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

    def forward(self, input_ids: torch.Tensor,
                attention_mask: torch.Tensor) -> torch.Tensor:
        """Forward pass.

        Args:
            input_ids: (B, L) token IDs
            attention_mask: (B, L) attention mask

        Returns:
            logits: (B, num_classes)
        """
        ### WRITE YOUR SOLUTION HERE ###

        pass

        """ END OF THIS PART """

# %% [markdown]
# ## Part 3: Training Loop with LR Scheduling (25 points)
#
# Implement `train_epoch` and `evaluate` functions.
#
# `train_epoch` must:
# 1. Iterate over the DataLoader
# 2. Compute cross-entropy loss
# 3. Backpropagate with gradient clipping (max_norm=1.0)
# 4. Step the optimizer and scheduler
# 5. Return average loss and accuracy
#
# `evaluate` must:
# 1. Run in `torch.no_grad()` mode
# 2. Return loss, accuracy, and predictions

# %%
def train_epoch(model: SentimentClassifier, dataloader: DataLoader,
                optimizer: torch.optim.Optimizer,
                scheduler, device: torch.device) -> tuple[float, float]:
    """Train for one epoch.

    Args:
        model: Sentiment classifier
        dataloader: Training DataLoader
        optimizer: Optimizer (AdamW)
        scheduler: Learning rate scheduler
        device: Device to train on

    Returns:
        avg_loss: Average training loss
        accuracy: Training accuracy
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """


def evaluate(model: SentimentClassifier, dataloader: DataLoader,
             device: torch.device) -> tuple[float, float, list[int]]:
    """Evaluate the model.

    Args:
        model: Sentiment classifier
        dataloader: Evaluation DataLoader
        device: Device

    Returns:
        avg_loss: Average evaluation loss
        accuracy: Evaluation accuracy
        predictions: List of predicted labels
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """

# %% [markdown]
# ## Part 4: Full Training Pipeline (30 points)
#
# Implement `train_sentiment_model` that ties everything together:
# 1. Creates the model, optimizer (AdamW with separate LRs for BERT and head), and scheduler
# 2. Trains for the specified number of epochs
# 3. Evaluates after each epoch
# 4. Returns the best model (by validation accuracy) and training history
#
# Use:
# - BERT LR: $2 \times 10^{-5}$
# - Head LR: $1 \times 10^{-4}$
# - Weight decay: 0.01
# - Linear warmup: 10% of total steps

# %%
def train_sentiment_model(
    train_texts: list[str], train_labels: list[int],
    val_texts: list[str], val_labels: list[int],
    num_epochs: int = 3, batch_size: int = 16,
    max_length: int = 128, freeze_bert: bool = False
) -> tuple[SentimentClassifier, dict]:
    """Full training pipeline for sentiment classification.

    Args:
        train_texts, train_labels: Training data
        val_texts, val_labels: Validation data
        num_epochs: Number of training epochs
        batch_size: Batch size
        max_length: Maximum sequence length
        freeze_bert: Whether to freeze BERT backbone

    Returns:
        best_model: Model with best validation accuracy
        history: Dict with 'train_loss', 'train_acc', 'val_loss', 'val_acc' lists
    """
    ### WRITE YOUR SOLUTION HERE ###

    pass

    """ END OF THIS PART """
