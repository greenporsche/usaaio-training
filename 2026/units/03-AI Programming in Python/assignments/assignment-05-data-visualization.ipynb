# %% [markdown]
# # Assignment 05: Data Visualization (100 points)
#
# ## Context
#
# Data visualization is how you communicate findings, diagnose model behavior, and understand data distributions. USAAIO problems may ask you to create specific plot types or interpret visualizations.
#
# ### Key Libraries
#
# - **Matplotlib**: the foundation -- gives you low-level control over every plot element
# - **Seaborn**: built on Matplotlib, provides higher-level statistical visualizations
#
# ### Object-Oriented API
#
# Always use the OO API: `fig, ax = plt.subplots()` then `ax.plot(...)`. This gives explicit control over multiple subplots and is the standard in professional code.

# %%
"""
DO NOT MAKE ANY CHANGE IN THIS CELL.
"""
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
np.random.seed(42)
sns.set_style('whitegrid')

# %% [markdown]
# > **WARNING !!!**
# >
# > - Beyond importing libraries/modules/classes/functions in the preceding cell, you are **NOT allowed to import anything else** for the following purposes:
# >     - **As a part of your final solution.**
# >     - **Temporarily import something to assist you to get a solution.**
# >
# >     **Rule of thumb:** Each part has its particular purpose to intentionally test you something. Do not attempt to find a shortcut to circumvent the rule.
# >
# > - Every plot **must** include: title, axis labels, and legend (where applicable).
# > - Use `plt.tight_layout()` before `plt.show()`.

# %% [markdown]
# ---
#
# ## Part 1 (20 points, coding task)
#
# **Reasoning is not required.**
#
# Create a figure with **3 subplots in a single row** showing different views of the same distribution data.

# %%
"""
DO NOT MAKE ANY CHANGE IN THIS CELL.
"""
group_A = np.random.normal(70, 10, 200)
group_B = np.random.normal(75, 15, 200)
group_C = np.random.normal(80, 8, 200)

df_groups = pd.DataFrame({
    'score': np.concatenate([group_A, group_B, group_C]),
    'group': np.repeat(['Group A', 'Group B', 'Group C'], 200)
})

# %% [markdown]
# 1. **Subplot 1** (left): Overlapping histograms of all 3 groups with `alpha=0.5`, `bins=25`
# 2. **Subplot 2** (center): KDE plot of all 3 groups using `sns.kdeplot` with `hue='group'`
# 3. **Subplot 3** (right): Box plot comparing the 3 groups using `sns.boxplot`
#
# Figure size: `(15, 4)`

# %%
### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
#
# ## Part 2 (20 points, coding task)
#
# **Reasoning is not required.**
#
# Create a scatter plot showing the relationship between study hours and exam scores, colored by study method, with a regression line per method.

# %%
"""
DO NOT MAKE ANY CHANGE IN THIS CELL.
"""
n = 150
study_data = pd.DataFrame({
    'hours': np.random.uniform(1, 10, n),
    'method': np.random.choice(['Textbook', 'Video', 'Practice'], n)
})
method_bonus = {'Textbook': 0, 'Video': 5, 'Practice': 10}
study_data['score'] = (
    50 + 4 * study_data['hours'] +
    study_data['method'].map(method_bonus) +
    np.random.randn(n) * 5
)

# %% [markdown]
# Create a plot with:
# - Scatter points colored by `method`
# - A regression line for **each** method (use `sns.lmplot` or `sns.regplot` per group)
# - Title: `"Study Hours vs Exam Score by Method"`
# - Axis labels: `"Study Hours"`, `"Exam Score"`
# - Legend

# %%
### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
#
# Heatmaps are used to visualize matrices -- especially correlation matrices and confusion matrices. The key is choosing the right colormap and centering it appropriately.

# %% [markdown]
# ---
#
# ## Part 3 (20 points, coding task)
#
# **Reasoning is not required.**
#
# Create a correlation heatmap for a dataset with 6 features.

# %%
"""
DO NOT MAKE ANY CHANGE IN THIS CELL.
"""
base = np.random.randn(200)
features = pd.DataFrame({
    'height': base * 10 + 170,
    'weight': base * 15 + 70 + np.random.randn(200) * 5,
    'age': np.random.randint(18, 65, 200),
    'exercise_hrs': np.abs(np.random.randn(200) * 3 + 5),
    'sleep_hrs': 8 - np.abs(np.random.randn(200)) + np.random.randn(200) * 0.5,
    'stress_level': 5 + np.random.randn(200) * 2
})

# %% [markdown]
# Create a heatmap with:
# - Annotated values formatted to 2 decimal places
# - `coolwarm` colormap centered at 0 with `vmin=-1`, `vmax=1`
# - Square cells
# - **Lower triangle only** (mask the upper triangle to avoid redundancy). Use `np.triu(np.ones_like(corr, dtype=bool))` as the mask.
# - Title: `"Feature Correlation Matrix"`

# %%
### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
#
# ## Part 4 (20 points, coding task)
#
# **Reasoning is not required.**
#
# Create a **2x2 model performance dashboard** showing 4 different views of training results.

# %%
"""
DO NOT MAKE ANY CHANGE IN THIS CELL.
"""
epochs = np.arange(1, 51)
train_loss = 2.0 * np.exp(-0.05 * epochs) + np.random.randn(50) * 0.05
val_loss = 2.0 * np.exp(-0.04 * epochs) + 0.1 + np.random.randn(50) * 0.08
train_acc = 1 - 0.8 * np.exp(-0.06 * epochs) + np.random.randn(50) * 0.02
val_acc = 1 - 0.85 * np.exp(-0.05 * epochs) + np.random.randn(50) * 0.03

cm = np.array([[45, 3, 2], [5, 40, 5], [1, 4, 45]])
class_names = ['Cat', 'Dog', 'Bird']
per_class_acc = cm.diagonal() / cm.sum(axis=1)

# %% [markdown]
# Create a `(12, 10)` figure with 4 subplots:
#
# - **Top-left**: Training & validation **loss** curves over epochs (two lines, with legend)
# - **Top-right**: Training & validation **accuracy** curves over epochs (two lines, with legend)
# - **Bottom-left**: Confusion matrix heatmap (annotated, `Blues` colormap, class names on axes)
# - **Bottom-right**: Per-class accuracy **bar chart** (one bar per class)
#
# Add `suptitle`: `"Model Performance Dashboard"`

# %%
### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """

# %% [markdown]
# ---
#
# ## Part 5 (20 points, coding task)
#
# **Reasoning is not required.**
#
# Create a **publication-quality** figure showing a 2D classification decision boundary.

# %%
"""
DO NOT MAKE ANY CHANGE IN THIS CELL.
"""
n_per_class = 100
class_0 = np.random.randn(n_per_class, 2) + np.array([-1, -1])
class_1 = np.random.randn(n_per_class, 2) + np.array([1, 1])
X_viz = np.vstack([class_0, class_1])
y_viz = np.array([0] * n_per_class + [1] * n_per_class)

# %% [markdown]
# Create an `(8, 6)` figure showing:
#
# 1. **(5 pts)** Scatter plot of both classes using different colors and markers
# 2. **(5 pts)** A linear decision boundary: the line $x_1 + x_2 = 0$ drawn as a dashed line
# 3. **(5 pts)** Shade the two decision regions using `ax.fill_between` or `ax.contourf` with light, transparent colors
# 4. **(5 pts)** Clean styling:
#    - Remove top and right spines
#    - Grid with `alpha=0.3`
#    - Title: `"2D Classification with Linear Decision Boundary"`
#    - Legend with class labels
#    - Equal aspect ratio

# %%
### WRITE YOUR SOLUTION HERE ###

# %% [markdown]
# """ END OF THIS PART """
