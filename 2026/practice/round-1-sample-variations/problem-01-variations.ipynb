# %% [markdown]
# # Problem 1 Variations: PCA & Projections (EXHAUSTIVE)
#
# > Original: Unit vectors, projections onto principal components, residuals
# > Core Skills: Vector normalization, dot products, projection formula, residual computation
#
# ---

# %% [markdown]
# ## CATEGORY A: Different Vector Values (Same Structure)

# %% [markdown]
# ---
#
# ### Variation A1
# Let d = 3. Consider vector **v** = $[2, 1, -2]^\top$. Let **$\hat{e}$** be in the same direction as **v**.
#
#
# **Part 1.1**: Write $\hat{e}$ = $\frac{1}{a} [b, c, d]^\top$ where a is a positive integer. What is a + b + c + d?
#
# **Part 1.2**: Let x = $[1, 2, 3]^\top$. Compute the scalar projection x $\cdot$ $\hat{e}$.
#
# **Part 1.3**: Compute the residual r = x - (x $\cdot$ $\hat{e}$)$\hat{e}$. What is $\|r\|^2$?

# %% [markdown]
# <details>
# <summary>Solution A1</summary>
#
#
# **1.1**: $\|v\|$ = $\sqrt{4+1+4}$ = 3, so $\hat{e}$ = $\frac{1}{3} [2,1,-2]^\top$. a=3, b=2, c=1, d=-2. **Answer: 4**
#
#
# **1.2**: x $\cdot$ $\hat{e}$ = $\frac{1}{3}$(2+2-6) = $\frac{-2}{3}$. **Answer: -2/3**
#
#
# **1.3**: proj = (-2/3)$\frac{1}{3} [2,1,-2]^\top$ = (-2/9)$[2,1,-2]^\top$ = $[-4/9, -2/9, 4/9]^\top$
#
# r = $[1,2,3]^\top$ - $[-4/9,-2/9,4/9]^\top$ = $[13/9, 20/9, 23/9]^\top$
#
# $\|r\|^2$ = (169+400+529)/81 = $\frac{1098}{81}$ = $\frac{122}{9}$. **Answer: 122/9**
# </details>

# %% [markdown]
# ---
#
# ### Variation A2
# Let d = 3. Consider vector **v** = $[1, -1, 1]^\top$.
#
#
# **Part 1.1**: Write $\hat{e}$ in the form (1/$\sqrt{a}$)$[b,c,d]^\top$ where a is not a perfect square. What is a + b + c + d?
#
# **Part 1.2**: Let x = $[3, 0, 3]^\top$. Compute the projection of x onto $\hat{e}$.
#
# **Part 1.3**: Verify that r $\perp$ $\hat{e}$ by computing r $\cdot$ $\hat{e}$.

# %% [markdown]
# <details>
# <summary>Solution A2</summary>
#
#
# **1.1**: $\|v\|$ = $\sqrt{3}$, so $\hat{e}$ = ($\frac{1}{\sqrt{3}}$)$[1,-1,1]^\top$. a=3, b=1, c=-1, d=1. **Answer: 4**
#
#
# **1.2**: x $\cdot$ $\hat{e}$ = ($\frac{1}{\sqrt{3}}$)(3+0+3) = $\frac{6}{\sqrt{3}}$ = $2\sqrt{3}$
#
# proj = $2\sqrt{3}$ $\cdot$ ($\frac{1}{\sqrt{3}}$)$[1,-1,1]^\top$ = 2$[1,-1,1]^\top$ = $[2,-2,2]^\top$. **Answer: $[2,-2,2]^\top$**
#
#
# **1.3**: r = $[3,0,3]^\top$ - $[2,-2,2]^\top$ = $[1,2,1]^\top$
# r $\cdot$ $\hat{e}$ = ($\frac{1}{\sqrt{3}}$)(1-2+1) = 0. **Answer: 0 ✓**
# </details>

# %% [markdown]
# ---
#
# ### Variation A3
# Let d = 3. Consider vector **v** = $[3, 4, 0]^\top$.
#
#
# **Part 1.1**: Compute $\|v\|$ and write $\hat{e}$.
#
# **Part 1.2**: Let x = $[6, 8, 5]^\top$. Compute the scalar projection and vector projection.
#
# **Part 1.3**: What is the angle $\theta$ between x and $\hat{e}$? (Give cos $\theta$)

# %% [markdown]
# <details>
# <summary>Solution A3</summary>
#
#
# **1.1**: $\|v\|$ = $\sqrt{9+16+0}$ = 5, $\hat{e}$ = $\frac{1}{5} [3,4,0]^\top$ = $[0.6, 0.8, 0]^\top$
#
#
# **1.2**: Scalar: x $\cdot$ $\hat{e}$ = $\frac{1}{5}$(18+32+0) = 10
# Vector: proj = 10 $\cdot$ $[0.6,0.8,0]^\top$ = $[6,8,0]^\top$
#
#
# **1.3**: cos $\theta$ = (x $\cdot$ $\hat{e}$)/($\|x\|$) = 10/$\sqrt{36+64+25}$ = $\frac{10}{\sqrt{125}}$ = 10/($5\sqrt{5}$) = $\frac{2}{\sqrt{5}}$ = $2\sqrt{5}$/5
# </details>

# %% [markdown]
# ---
#
# ### Variation A4
# Let d = 3. Consider vector **v** = $[1, 2, 2]^\top$.
#
#
# **Part 1.1**: Normalize v to get $\hat{e}$.
#
# **Part 1.2**: Let x = $[4, -1, 2]^\top$. Find the component of x parallel to $\hat{e}$.
#
# **Part 1.3**: Find the component of x perpendicular to $\hat{e}$.
#
# **Part 1.4**: Verify: $\|x\|^2$ = $\|x\_parallel\|^2$ + $\|x\_perp\|^2$

# %% [markdown]
# <details>
# <summary>Solution A4</summary>
#
#
# **1.1**: $\|v\|$ = $\sqrt{1+4+4}$ = 3, $\hat{e}$ = $\frac{1}{3} [1,2,2]^\top$
#
#
# **1.2**: x $\cdot$ $\hat{e}$ = $\frac{1}{3}$(4-2+4) = 2
#
# x_parallel = 2ê = $\frac{2}{3} [1,2,2]^\top$ = $[2/3, 4/3, 4/3]^\top$
#
#
# **1.3**: x_perp = x - x_parallel = $[4-2/3, -1-4/3, 2-4/3]^\top$ = $[10/3, -7/3, 2/3]^\top$
#
#
# **1.4**: $\|x\|^2$ = 16+1+4 = 21
#
# $\|x\_parallel\|^2$ = $\frac{4}{9}$(1+4+4) = 4
#
# $\|x\_perp\|^2$ = $\frac{1}{9}$(100+49+4) = $\frac{153}{9}$ = 17
# 4 + 17 = 21 ✓
# </details>

# %% [markdown]
# ---
#
# ### Variation A5
# Let d = 3. Consider vector **v** = $[1, 0, -1]^\top$.
#
#
# **Part 1.1**: Find $\hat{e}$.
#
# **Part 1.2**: Let x = $[a, b, c]^\top$ be arbitrary. Write the projection formula.
#
# **Part 1.3**: For what values of x is the projection zero?

# %% [markdown]
# <details>
# <summary>Solution A5</summary>
#
#
# **1.1**: $\|v\|$ = $\sqrt{2}$, $\hat{e}$ = ($\frac{1}{\sqrt{2}}$)$[1,0,-1]^\top$
#
#
# **1.2**: x $\cdot$ $\hat{e}$ = ($\frac{1}{\sqrt{2}}$)(a - c)
#
# proj = ((a-c)/$\sqrt{2}$) $\cdot$ ($\frac{1}{\sqrt{2}}$)$[1,0,-1]^\top$ = ((a-c)/2)$[1,0,-1]^\top$
#
#
# **1.3**: Projection is zero when a - c = 0, i.e., when a = c.
# Any vector of form $[a, b, a]^\top$ has zero projection onto $\hat{e}$.
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## CATEGORY B: Higher Dimensions

# %% [markdown]
# ---
#
# ### Variation B1 (d = 4)
# Let **v** = $[1, 1, 1, 1]^\top$ $\in \mathbb{R}^{4}$.
#
#
# **Part 1.1**: Find the unit vector $\hat{e}$.
#
# **Part 1.2**: Let x = $[4, 0, 0, 0]^\top$. Compute the projection.
#
# **Part 1.3**: Compute $\|r\|$.

# %% [markdown]
# <details>
# <summary>Solution B1</summary>
#
#
# **1.1**: $\|v\|$ = 2, $\hat{e}$ = $\frac{1}{2} [1,1,1,1]^\top$
#
#
# **1.2**: x $\cdot$ $\hat{e}$ = $\frac{1}{2}$(4) = 2
#
# proj = 2 $\cdot$ $\frac{1}{2} [1,1,1,1]^\top$ = $[1,1,1,1]^\top$
#
#
# **1.3**: r = $[4,0,0,0]^\top$ - $[1,1,1,1]^\top$ = $[3,-1,-1,-1]^\top$
#
# $\|r\|$ = $\sqrt{9+1+1+1}$ = $\sqrt{12}$ = $2\sqrt{3}$
# </details>

# %% [markdown]
# ---
#
# ### Variation B2 (d = 4)
# Let **v** = $[1, -1, 1, -1]^\top$ $\in \mathbb{R}^{4}$.
#
#
# **Part 1.1**: Find $\hat{e}$ and verify $\|\hat{e}\|$ = 1.
#
# **Part 1.2**: Let x = $[2, 2, 2, 2]^\top$. What is x $\cdot$ $\hat{e}$?
#
# **Part 1.3**: Interpret the result geometrically.

# %% [markdown]
# <details>
# <summary>Solution B2</summary>
#
#
# **1.1**: $\|v\|$ = 2, $\hat{e}$ = $\frac{1}{2} [1,-1,1,-1]^\top$
#
# $\|\hat{e}\|^2$ = $\frac{1}{4}$(1+1+1+1) = 1 ✓
#
#
# **1.2**: x $\cdot$ $\hat{e}$ = $\frac{1}{2}$(2-2+2-2) = 0
#
#
# **1.3**: x is orthogonal to $\hat{e}$. The projection is zero, meaning x lies entirely in the hyperplane perpendicular to $\hat{e}$.
# </details>

# %% [markdown]
# ---
#
# ### Variation B3 (d = 5)
# Let **v** = $[1, 2, 0, -2, 1]^\top$ $\in \mathbb{R}^{5}$.
#
#
# **Part 1.1**: Compute $\|v\|^2$ and $\|v\|$.
#
# **Part 1.2**: Let x = $[1, 1, 1, 1, 1]^\top$. Compute $x \cdot v$.
#
# **Part 1.3**: Compute the scalar projection of x onto v.

# %% [markdown]
# <details>
# <summary>Solution B3</summary>
#
#
# **1.1**: $\|v\|^2$ = 1+4+0+4+1 = 10, $\|v\|$ = $\sqrt{10}$
#
#
# **1.2**: $x \cdot v$ = 1+2+0-2+1 = 2
#
#
# **1.3**: Scalar projection = ($x \cdot v$)/$\|v\|$ = $\frac{2}{\sqrt{10}}$ = $\sqrt{10}$/5
# </details>

# %% [markdown]
# ---
#
# ### Variation B4 (d = 2, simpler)
# Let **v** = $[3, 4]^\top$ $\in \mathbb{R}^{2}$.
#
#
# **Part 1.1**: Find $\hat{e}$.
#
# **Part 1.2**: Let x = $[5, 0]^\top$. Find the projection.
#
# **Part 1.3**: Find the distance from x to the line spanned by v.

# %% [markdown]
# <details>
# <summary>Solution B4</summary>
#
#
# **1.1**: $\|v\|$ = 5, $\hat{e}$ = $[3/5, 4/5]^\top$ = $[0.6, 0.8]^\top$
#
#
# **1.2**: x $\cdot$ $\hat{e}$ = 3
#
# proj = 3$[0.6, 0.8]^\top$ = $[1.8, 2.4]^\top$
#
#
# **1.3**: r = $[5,0]^\top$ - $[1.8, 2.4]^\top$ = $[3.2, -2.4]^\top$
#
# distance = $\|r\|$ = $\sqrt{10.24 + 5.76}$ = $\sqrt{16}$ = 4
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## CATEGORY C: Multiple Principal Components

# %% [markdown]
# ---
#
# ### Variation C1 (Two orthogonal PCs)
# Let **$\hat{e}_1$** = ($\frac{1}{\sqrt{2}}$)$[1, 1, 0]^\top$ and **$\hat{e}_2$** = ($\frac{1}{\sqrt{2}}$)$[1, -1, 0]^\top$.
#
#
# **Part 1.1**: Verify $\hat{e}_1 \perp \hat{e}_2$.
#
# **Part 1.2**: Let x = $[3, 1, 5]^\top$. Project x onto span{$\hat{e}_1$, $\hat{e}_2$}.
#
# **Part 1.3**: What is the residual? Interpret geometrically.

# %% [markdown]
# <details>
# <summary>Solution C1</summary>
#
#
# **1.1**: $\hat{e}_1$ $\cdot$ $\hat{e}_2$ = $\frac{1}{2}$(1-1+0) = 0 ✓
#
#
# **1.2**:
# $x \cdot \hat{e}_1$ = ($\frac{1}{\sqrt{2}}$)(3+1) = $2\sqrt{2}$
# $x \cdot \hat{e}_2$ = ($\frac{1}{\sqrt{2}}$)(3-1) = $\sqrt{2}$
#
# proj = $2\sqrt{2}$ $\cdot$ $\hat{e}_1$ + $\sqrt{2}$ $\cdot$ $\hat{e}_2$ = 2$[1,1,0]^\top$ + $[1,-1,0]^\top$ = $[3, 1, 0]^\top$
#
#
# **1.3**: r = $[3,1,5]^\top$ - $[3,1,0]^\top$ = $[0,0,5]^\top$
# The residual is purely in the z-direction, which is orthogonal to the xy-plane spanned by $\hat{e}_1$ and $\hat{e}_2$.
# </details>

# %% [markdown]
# ---
#
# ### Variation C2 (Three orthonormal PCs in ℝ³)
# Let **$\hat{e}_1$** = $[1,0,0]^\top$, **$\hat{e}_2$** = $[0,1,0]^\top$, **$\hat{e}_3$** = $[0,0,1]^\top$ (standard basis).
#
#
# **Part 1.1**: For x = $[a,b,c]^\top$, what is the projection onto span{$\hat{e}_1$, $\hat{e}_2$}?
#
# **Part 1.2**: What is the residual?
#
# **Part 1.3**: If we project onto all three, what is the residual?

# %% [markdown]
# <details>
# <summary>Solution C2</summary>
#
#
# **1.1**: proj = ($x \cdot \hat{e}_1$)$\hat{e}_1$ + ($x \cdot \hat{e}_2$)$\hat{e}_2$ = a$\hat{e}_1$ + b$\hat{e}_2$ = $[a,b,0]^\top$
#
#
# **1.2**: r = $[a,b,c]^\top$ - $[a,b,0]^\top$ = $[0,0,c]^\top$
#
#
# **1.3**: proj = a$\hat{e}_1$ + b$\hat{e}_2$ + c$\hat{e}_3$ = $[a,b,c]^\top$ = x
#
# Residual = 0 (the three vectors span all of ℝ³)
# </details>

# %% [markdown]
# ---
#
# ### Variation C3 (Non-standard orthonormal basis)
# Let **$\hat{e}_1$** = ($\frac{1}{\sqrt{3}}$)$[1,1,1]^\top$, **$\hat{e}_2$** = ($\frac{1}{\sqrt{2}}$)$[1,-1,0]^\top$, **$\hat{e}_3$** = ($\frac{1}{\sqrt{6}}$)$[1,1,-2]^\top$.
#
#
# **Part 1.1**: Verify this is an orthonormal basis.
#
# **Part 1.2**: Express x = $[1,0,0]^\top$ in this basis.
#
# **Part 1.3**: Verify your answer by reconstruction.

# %% [markdown]
# <details>
# <summary>Solution C3</summary>
#
#
# **1.1**:
# - $\|\hat{e}₁\|^2$ = $\frac{1}{3}$(3) = 1 ✓
# - $\|\hat{e}₂\|^2$ = $\frac{1}{2}$(2) = 1 ✓
# - $\|\hat{e}₃\|^2$ = $\frac{1}{6}$(6) = 1 ✓
# - $\hat{e}_1 \cdot$$\hat{e}_2$ = ($\frac{1}{\sqrt{6}}$)(1-1+0) = 0 ✓
# - $\hat{e}_1 \cdot$$\hat{e}_3$ = ($\frac{1}{\sqrt{18}}$)(1+1-2) = 0 ✓
# - $\hat{e}_2 \cdot$$\hat{e}_3$ = ($\frac{1}{\sqrt{12}}$)(1-1+0) = 0 ✓
#
#
# **1.2**:
# c₁ = $x \cdot \hat{e}_1$ = $\frac{1}{\sqrt{3}}$
# c₂ = $x \cdot \hat{e}_2$ = $\frac{1}{\sqrt{2}}$
# c₃ = $x \cdot \hat{e}_3$ = $\frac{1}{\sqrt{6}}$
#
#
# **1.3**:
#
# x = c₁$\hat{e}_1$ + c₂$\hat{e}_2$ + c₃$\hat{e}_3$
# = ($\frac{1}{\sqrt{3}}$)($\frac{1}{\sqrt{3}}$)$[1,1,1]^\top$ + ($\frac{1}{\sqrt{2}}$)($\frac{1}{\sqrt{2}}$)$[1,-1,0]^\top$ + ($\frac{1}{\sqrt{6}}$)($\frac{1}{\sqrt{6}}$)$[1,1,-2]^\top$
# = $\frac{1}{3} [1,1,1]^\top$ + $\frac{1}{2} [1,-1,0]^\top$ + $\frac{1}{6} [1,1,-2]^\top$
# = $[1/3+1/2+1/6, 1/3-1/2+1/6, 1/3+0-1/3]^\top$
# = $[1, 0, 0]^\top$ ✓
# </details>

# %% [markdown]
# ---
#
# ### Variation C4 (Explained Variance)
# A dataset X $\in \mathbb{R}^{100×3}$ has been centered (mean subtracted). The first two principal components are:
# - **$\hat{e}_1$** with eigenvalue $\lambda_1$ = 50
# - **$\hat{e}_2$** with eigenvalue $\lambda_2$ = 30
# - **$\hat{e}_3$** with eigenvalue $\lambda_3$ = 20
#
#
# **Part 1.1**: What is the total variance in the data?
#
# **Part 1.2**: What fraction of variance is explained by the first PC alone?
#
# **Part 1.3**: What fraction is explained by the first two PCs together?
#
# **Part 1.4**: If we project all data onto span{$\hat{e}_1$, $\hat{e}_2$}, what is the average reconstruction error per sample?

# %% [markdown]
# <details>
# <summary>Solution C4</summary>
#
#
# **1.1**: Total variance = $\lambda_1$ + $\lambda_2$ + $\lambda_3$ = 50 + 30 + 20 = 100
#
#
# **1.2**: Fraction by PC1 = $\lambda_1$/total = $\frac{50}{100}$ = **0.5 or 50%**
#
#
# **1.3**: Fraction by PC1+PC2 = ($\lambda_1$+$\lambda_2$)/total = $\frac{80}{100}$ = **0.8 or 80%**
#
#
# **1.4**: Reconstruction error = variance not captured = $\lambda_3$ = 20
# Average per sample = $\frac{20}{100}$ = **0.2**
#
# Key insight: Eigenvalues in PCA represent variance along each principal direction.
# </details>

# %% [markdown]
# ---
#
# ### Variation C5 (Incremental PCA)
# You have projected x = $[10, 6, 3]^\top$ onto $\hat{e}_1$ = ($\frac{1}{\sqrt{2}}$)$[1, 1, 0]^\top$, obtaining:
# - Projection onto PC1: proj₁ = $[8, 8, 0]^\top$
# - Residual: r₁ = $[2, -2, 3]^\top$
#
# Now you add a second PC: $\hat{e}_2$ = ($\frac{1}{\sqrt{2}}$)$[1, -1, 0]^\top$.
#
#
# **Part 1.1**: What additional variance does PC2 capture from x?
#
# **Part 1.2**: What is the new residual after projecting onto both PCs?
#
# **Part 1.3**: Is there any benefit to adding a third PC $\hat{e}_3$ = $[0, 0, 1]^\top$?

# %% [markdown]
# <details>
# <summary>Solution C5</summary>
#
#
# **1.1**:
# r₁ $\cdot$ $\hat{e}_2$ = ($\frac{1}{\sqrt{2}}$)(2 - (-2) + 0) = $\frac{4}{\sqrt{2}}$ = $2\sqrt{2}$
# Additional projection = (r₁ $\cdot$ $\hat{e}_2$)$\hat{e}_2$ = $2\sqrt{2}$ $\cdot$ ($\frac{1}{\sqrt{2}}$)$[1,-1,0]^\top$ = 2$[1,-1,0]^\top$ = $[2,-2,0]^\top$
# Additional variance captured = $\|[2,-2,0]\|^2$ = 8
#
#
# **1.2**:
# proj₂ = proj₁ + $[2,-2,0]^\top$ = $[8,8,0]^\top$ + $[2,-2,0]^\top$ = $[10,6,0]^\top$
# New residual r₂ = x - proj₂ = $[10,6,3]^\top$ - $[10,6,0]^\top$ = $[0,0,3]^\top$
#
#
# **1.3**:
# r₂ $\cdot$ $\hat{e}_3$ = 3, so proj onto $\hat{e}_3$ is 3$[0,0,1]^\top$ = $[0,0,3]^\top$
# After PC3: residual = 0
# Yes! PC3 captures the remaining variance ($\|r₂\|^2$ = 9)
# </details>

# %% [markdown]
# ---
#
# ### Variation C6 (Choosing Number of PCs)
# A 1000-dimensional dataset has eigenvalues: $\lambda_1$=500, $\lambda_2$=200, $\lambda_3$=100, $\lambda_4$=50, and λᵢ≤10 for i≥5.
# Total variance = 1000.
#
#
# **Part 1.1**: How many PCs are needed to capture 80% of the variance?
#
# **Part 1.2**: How many PCs are needed to capture 95% of the variance?
#
# **Part 1.3**: What is the "elbow" in the scree plot, and what does it suggest?

# %% [markdown]
# <details>
# <summary>Solution C6</summary>
#
#
# **1.1**:
# - PC1: 500/1000 = 50%
# - PC1+PC2: (500+200)/1000 = 70%
# - PC1+PC2+PC3: (500+200+100)/1000 = 80% ✓
# **Answer: 3 PCs**
#
#
# **1.2**:
# - PC1-4: (500+200+100+50)/1000 = 85%
# - Remaining variance = 150, spread across ≤996 PCs with λᵢ≤10
# - Need enough to add 100 more (95%-85%=10% of 1000)
# - With max λᵢ=10, need at least 10 more PCs
# **Answer: At least 14 PCs** (upper bound estimate; exact count depends on individual λᵢ values)
#
#
# **1.3**: The elbow is at PC4→PC5 where eigenvalues drop from 50 to ≤10. This suggests 4 PCs capture the "signal" while remaining PCs capture "noise."
# </details>

# %% [markdown]
# ---
#
# ### Variation C7 (PCA Reconstruction)
# Given orthonormal PCs $\hat{e}_1$ = $[1,0,0]^\top$, $\hat{e}_2$ = $[0,1,0]^\top$ and original point x = $[3, 4, 5]^\top$.
#
#
# **Part 1.1**: Reconstruct x using only PC1. What is the reconstruction error?
#
# **Part 1.2**: Reconstruct x using PC1 and PC2. What is the reconstruction error?
#
# **Part 1.3**: Write the general formula for reconstruction using k PCs.

# %% [markdown]
# <details>
# <summary>Solution C7</summary>
#
#
# **1.1**:
# x̂₁ = ($x \cdot \hat{e}_1$)$\hat{e}_1$ = 3$[1,0,0]^\top$ = $[3,0,0]^\top$
#
# Error = $\|x - x̂₁\|^2$ = $\|[0,4,5]\|^2$ = 16 + 25 = **41**
#
#
# **1.2**:
# x̂₂ = ($x \cdot \hat{e}_1$)$\hat{e}_1$ + ($x \cdot \hat{e}_2$)$\hat{e}_2$ = $[3,0,0]^\top$ + $[0,4,0]^\top$ = $[3,4,0]^\top$
#
# Error = $\|x - x̂₂\|^2$ = $\|[0,0,5]\|^2$ = **25**
#
#
# **1.3**:
# x̂ₖ = Σᵢ₌₁ᵏ (x$\cdot$êᵢ)êᵢ
#
# Or in matrix form: x̂ₖ = Uₖ Uₖᵀ x where Uₖ = [$\hat{e}_1$ $| $\hat{e}_2$ |$ ... | êₖ]
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## CATEGORY D: Projection Properties & Proofs

# %% [markdown]
# ---
#
# ### Variation D1 (Idempotence)
# Let P be the projection matrix onto $\hat{e}$, where P = êêᵀ.
#
#
# **Part 1.1**: For $\hat{e}$ = ($\frac{1}{\sqrt{2}}$)$[1,1]^\top$, write P explicitly.
#
# **Part 1.2**: Compute P² and verify P² = P.
#
# **Part 1.3**: What are the eigenvalues of P?

# %% [markdown]
# <details>
# <summary>Solution D1</summary>
#
#
# **1.1**: P = êêᵀ = $\frac{1}{2} [1,1]^\top$[1,1] = $\frac{1}{2}$[[1,1],[1,1]]
#
#
# **1.2**: P² = $\frac{1}{4}$[[1,1],[1,1]][[1,1],[1,1]] = $\frac{1}{4}$[[2,2],[2,2]] = $\frac{1}{2}$[[1,1],[1,1]] = P ✓
#
#
# **1.3**: P is idempotent, so eigenvalues are 0 and 1.
# - $\lambda$=1: eigenvector is $\hat{e}$ (projection preserves vectors in its range)
# - $\lambda$=0: eigenvector is any vector $\perp$ $\hat{e}$
# </details>

# %% [markdown]
# ---
#
# ### Variation D2 (Symmetry)
#
# **Part 1.1**: Prove that P = êêᵀ is symmetric.
#
# **Part 1.2**: What does symmetry imply about the eigenvalues?
#
# **Part 1.3**: For P projecting onto a k-dimensional subspace in ℝⁿ, what is trace(P)?

# %% [markdown]
# <details>
# <summary>Solution D2</summary>
#
#
# **1.1**: Pᵀ = (êêᵀ)ᵀ = (êᵀ)ᵀ($\hat{e}$)ᵀ = êêᵀ = P ✓
#
#
# **1.2**: Symmetric matrices have real eigenvalues and orthogonal eigenvectors.
#
#
# **1.3**: trace(P) = sum of eigenvalues = k (there are k eigenvalues equal to 1, and n-k equal to 0)
# </details>

# %% [markdown]
# ---
#
# ### Variation D3 (Orthogonal complement)
# Let P project onto span{$\hat{e}$} and Q = I - P project onto the orthogonal complement.
#
#
# **Part 1.1**: Verify that PQ = 0.
#
# **Part 1.2**: Verify that P + Q = I.
#
# **Part 1.3**: For any x, verify $\|x\|^2$ = $\|Px\|^2$ + $\|Qx\|^2$.

# %% [markdown]
# <details>
# <summary>Solution D3</summary>
#
#
# **1.1**: PQ = P(I-P) = P - P² = P - P = 0 ✓
#
#
# **1.2**: P + Q = P + (I-P) = I ✓
#
#
# **1.3**: $\|x\|^2$ = xᵀx = xᵀ(P+Q)ᵀ(P+Q)x = xᵀ(P²+PQ+QP+Q²)x = xᵀ(P+Q)x = xᵀPx + xᵀQx = $\|Px\|^2$ + $\|Qx\|^2$ ✓
# (using P²=P, Q²=Q, PQ=QP=0)
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## CATEGORY E: Computational Variations (Different Numbers)

# %% [markdown]
# ---
#
# ### Variation E1
# v = $[2, -3, 6]^\top$, x = $[1, 1, 1]^\top$

# %% [markdown]
# <details>
# <summary>Solution E1</summary>
#
# $\|v\|$ = $\sqrt{4+9+36}$ = 7
# $\hat{e}$ = $\frac{1}{7} [2,-3,6]^\top$
# x$\cdot \hat{e}$ = $\frac{1}{7}$(2-3+6) = $\frac{5}{7}$
#
# proj = $\frac{5}{7} \frac{1}{7}$$[2,-3,6]^\top$ = $\frac{5}{49} [2,-3,6]^\top$ = $[10/49, -15/49, 30/49]^\top$
#
# r = $[1,1,1]^\top$ - $[10/49, -15/49, 30/49]^\top$ = $[39/49, 64/49, 19/49]^\top$
# </details>

# %% [markdown]
# ---
#
# ### Variation E2
# v = $[1, 2, -2, 4]^\top$, x = $[5, 0, 0, 0]^\top$

# %% [markdown]
# <details>
# <summary>Solution E2</summary>
#
# $\|v\|$ = $\sqrt{1+4+4+16}$ = 5
# $\hat{e}$ = $\frac{1}{5} [1,2,-2,4]^\top$
# x$\cdot \hat{e}$ = $\frac{1}{5}$(5) = 1
#
# proj = $\frac{1}{5} [1,2,-2,4]^\top$ = $[0.2, 0.4, -0.4, 0.8]^\top$
#
# r = $[5,0,0,0]^\top$ - $[0.2,0.4,-0.4,0.8]^\top$ = $[4.8, -0.4, 0.4, -0.8]^\top$
#
# $\|r\|^2$ = 23.04 + 0.16 + 0.16 + 0.64 = 24
# </details>

# %% [markdown]
# ---
#
# ### Variation E3
# v = $[1, 1, 1, 1, 1]^\top$, x = $[5, 4, 3, 2, 1]^\top$

# %% [markdown]
# <details>
# <summary>Solution E3</summary>
#
# $\|v\|$ = $\sqrt{5}$
# $\hat{e}$ = ($\frac{1}{\sqrt{5}}$)$[1,1,1,1,1]^\top$
# x$\cdot \hat{e}$ = ($\frac{1}{\sqrt{5}}$)(5+4+3+2+1) = $\frac{15}{\sqrt{5}}$ = $3\sqrt{5}$
#
# proj = $3\sqrt{5}$ $\cdot$ ($\frac{1}{\sqrt{5}}$)$[1,1,1,1,1]^\top$ = 3$[1,1,1,1,1]^\top$ = $[3,3,3,3,3]^\top$
#
# r = $[5,4,3,2,1]^\top$ - $[3,3,3,3,3]^\top$ = $[2,1,0,-1,-2]^\top$
#
# $\|r\|^2$ = 4+1+0+1+4 = 10
# </details>

# %% [markdown]
# ---
#
# ### Variation E4
# v = $[1, -1, 0]^\top$, x = $[a, a, b]^\top$ (parametric)

# %% [markdown]
# <details>
# <summary>Solution E4</summary>
#
# $\|v\|$ = $\sqrt{2}$
# $\hat{e}$ = ($\frac{1}{\sqrt{2}}$)$[1,-1,0]^\top$
# x$\cdot \hat{e}$ = ($\frac{1}{\sqrt{2}}$)(a - a) = 0
#
# proj = 0 (for any a, b!)
#
# r = x (the entire vector is the residual)
#
# Key insight: Any vector of form $[a,a,b]^\top$ is orthogonal to $[1,-1,0]^\top$.
# </details>

# %% [markdown]
# ---
#
# ### Variation E5
# v = $[cos \theta, sin \theta]^\top$ for arbitrary $\theta$, x = $[1, 0]^\top$

# %% [markdown]
# <details>
# <summary>Solution E5</summary>
#
# $\|v\|$ = $\sqrt{cos²θ + sin²θ}$ = 1 (already unit)
# $\hat{e}$ = $[cos \theta, sin \theta]^\top$
# x$\cdot \hat{e}$ = cos $\theta$
#
# proj = cos $\theta$ $\cdot$ $[cos \theta, sin \theta]^\top$ = $[cos²\theta, cos \theta sin \theta]^\top$
#
# r = $[1,0]^\top$ - $[cos²\theta, cos \theta sin \theta]^\top$ = $[sin²\theta, -cos \theta sin \theta]^\top$
#
# $\|r\|$ = $|sin $\theta$|$
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## CATEGORY F: Word Problems / Applications

# %% [markdown]
# ---
#
# ### Variation F1 (Physics: Force decomposition)
# A force F = $[10, 6, -8]^\top$ Newtons acts on an object. The object can only move along the direction v = $[1, 2, 2]^\top$.
#
#
# **Part 1.1**: What component of F does useful work (parallel to motion)?
#
# **Part 1.2**: What component is wasted (perpendicular to motion)?
#
# **Part 1.3**: If the object moves 5 meters along v, how much work is done?

# %% [markdown]
# <details>
# <summary>Solution F1</summary>
#
#
# **1.1**: $\|v\|$ = 3, $\hat{e}$ = $\frac{1}{3} [1,2,2]^\top$
# F$\cdot \hat{e}$ = $\frac{1}{3}$(10+12-16) = 2
#
# F_parallel = 2ê = $\frac{2}{3} [1,2,2]^\top$
#
#
# **1.2**: F_perp = F - F_parallel = $[10,6,-8]^\top$ - $[2/3, 4/3, 4/3]^\top$ = $[28/3, 14/3, -28/3]^\top$
#
#
# **1.3**: Work = $F_parallel \cdot displacement$ = $2 \cdot 5$ = 10 Joules
# (or: F $\cdot$ (5ê) = 5(F$\cdot \hat{e}$) = $5 \cdot 2$ = 10 J)
# </details>

# %% [markdown]
# ---
#
# ### Variation F2 (Statistics: Regression)
# In simple linear regression, we project y onto the column space of X = $[1, x]^\top$.
#
#
# **Part 1.1**: If x = $[1, 2, 3]^\top$ and y = $[2, 4, 5]^\top$, find the projection of y onto x.
#
# **Part 1.2**: What is the residual?
#
# **Part 1.3**: Verify the residual is orthogonal to x.

# %% [markdown]
# <details>
# <summary>Solution F2</summary>
#
#
# **1.1**: $\|x\|$ = $\sqrt{14}$
# $\hat{e}$ = ($\frac{1}{\sqrt{14}}$)$[1,2,3]^\top$
# y$\cdot \hat{e}$ = ($\frac{1}{\sqrt{14}}$)(2+8+15) = $\frac{25}{\sqrt{14}}$
#
# proj = ($\frac{25}{\sqrt{14}}$)($\frac{1}{\sqrt{14}}$)$[1,2,3]^\top$ = $\frac{25}{14} [1,2,3]^\top$ = $[25/14, 50/14, 75/14]^\top$
#
#
# **1.2**: r = $[2,4,5]^\top$ - $[25/14, 50/14, 75/14]^\top$ = $[3/14, 6/14, -5/14]^\top$ = $\frac{1}{14} [3,6,-5]^\top$
#
#
# **1.3**: $r \cdot x$ = $\frac{1}{14}$(3+12-15) = 0 ✓
# </details>

# %% [markdown]
# ---
#
# ### Variation F3 (Graphics: Shadow projection)
# A light source is directly above (along z-axis). An object at point P = $[3, 4, 5]^\top$ casts a shadow on the xy-plane.
#
#
# **Part 1.1**: What is the shadow point (projection onto z=0 plane)?
#
# **Part 1.2**: Express this as a projection onto span{$[1,0,0]^\top$, $[0,1,0]^\top$}.
#
# **Part 1.3**: What is the "height" (residual)?

# %% [markdown]
# <details>
# <summary>Solution F3</summary>
#
#
# **1.1**: Shadow = $[3, 4, 0]^\top$ (just drop the z-coordinate)
#
#
# **1.2**: Let $\hat{e}_1$ = $[1,0,0]^\top$, $\hat{e}_2$ = $[0,1,0]^\top$
#
# proj = ($P \cdot \hat{e}_1$)$\hat{e}_1$ + ($P \cdot \hat{e}_2$)$\hat{e}_2$ = 3$\hat{e}_1$ + 4$\hat{e}_2$ = $[3,4,0]^\top$ ✓
#
#
# **1.3**: r = P - proj = $[0,0,5]^\top$, $\|r\|$ = 5 (the height above the plane)
# </details>

# %% [markdown]
# ---
#
# ### Variation F4 (PCA for Dimensionality Reduction)
# You have 3D face scan data with 1000 points. After PCA, the first 2 PCs explain 95% of variance.
# A new face x = $[0.5, 0.3, 0.1]^\top$ (in PC coordinates: c₁=0.5, c₂=0.3, c₃=0.1) needs compression.
#
#
# **Part 1.1**: What is the 2D compressed representation?
#
# **Part 1.2**: Reconstruct the face from the 2D representation (assume PCs are standard basis).
#
# **Part 1.3**: What is the compression ratio (original dims / compressed dims)?

# %% [markdown]
# <details>
# <summary>Solution F4</summary>
#
#
# **1.1**: 2D representation = [c₁, c₂] = **[0.5, 0.3]** (drop PC3 coefficient)
#
#
# **1.2**: Reconstructed = c₁$\hat{e}_1$ + c₂$\hat{e}_2$ = 0.5$[1,0,0]^\top$ + 0.3$[0,1,0]^\top$ = **$[0.5, 0.3, 0]^\top$**
#
#
# **1.3**: Compression ratio = $\frac{3}{2}$ = **1.5x**
#
# For real applications: original might be 10000D → 50D, giving 200x compression!
# </details>

# %% [markdown]
# ---
#
# ### Variation F5 (Whitening Transformation)
# Data X has covariance matrix $\Sigma$ with eigendecomposition $\Sigma$ = UΛUᵀ where:
# - U = [[$\frac{1}{\sqrt{2}}$, $\frac{1}{\sqrt{2}}$], [$\frac{1}{\sqrt{2}}$, -$\frac{1}{\sqrt{2}}$]] (eigenvectors as columns)
# - $\Lambda$ = diag(4, 1) (eigenvalues)
#
#
# **Part 1.1**: What is the whitening transformation W?
#
# **Part 1.2**: Apply W to x = $[2, 0]^\top$ to get the whitened vector.
#
# **Part 1.3**: Verify: the transformed data has identity covariance (for this single point, show $\|Wx\|$ relates to original variance correctly).

# %% [markdown]
# <details>
# <summary>Solution F5</summary>
#
#
# **1.1**: Whitening transformation: W = $\Lambda$^(-1/2) Uᵀ
#
# $\Lambda$^(-1/2) = diag(1/2, 1)
#
# W = [[1/2, 0], [0, 1]] $\cdot$ [[$\frac{1}{\sqrt{2}}$, $\frac{1}{\sqrt{2}}$], [$\frac{1}{\sqrt{2}}$, -$\frac{1}{\sqrt{2}}$]]
#
# W = [[1/($2\sqrt{2}$), 1/($2\sqrt{2}$)], [$\frac{1}{\sqrt{2}}$, -$\frac{1}{\sqrt{2}}$]]
#
#
# **1.2**:
#
# Wx = [[1/($2\sqrt{2}$), 1/($2\sqrt{2}$)], [$\frac{1}{\sqrt{2}}$, -$\frac{1}{\sqrt{2}}$]] $\cdot$ $[2, 0]^\top$
# = $[2/($2\sqrt{2}$), $\frac{2}{$\sqrt{2}$}$]^\top$ = $[$\frac{1}{$\sqrt{2}$}$, $\sqrt{2}$]^\top$ ≈ $[0.707, 1.414]^\top$
#
#
# **1.3**:
# Original x in PC coords: Uᵀx = $[$\sqrt{2}$, $\sqrt{2}$]^\top$
# Scaled by eigenvalues: variance along PC1 is 4, along PC2 is 1
# After whitening: $[$\sqrt{2}$/2, $\sqrt{2} \cdot$1]^\top$ = $[$\frac{1}{$\sqrt{2}$}$, $\sqrt{2}$]^\top$ ✓
# Both components now have unit variance contribution.
# </details>

# %% [markdown]
# ---
#
# ### Variation F6 (Noise Filtering via PCA)
# A signal s = $[4, 4, 4]^\top$ is corrupted by noise n to give observed x = $[4.2, 3.8, 4.1]^\top$.
# The signal lies in direction v = $[1, 1, 1]^\top$.
#
#
# **Part 1.1**: Project x onto the signal direction to denoise it.
#
# **Part 1.2**: What is the estimated noise (residual)?
#
# **Part 1.3**: What SNR (signal-to-noise ratio in dB) does this correspond to?

# %% [markdown]
# <details>
# <summary>Solution F6</summary>
#
#
# **1.1**:
#
# $\|v\|$ = $\sqrt{3}$, $\hat{e}$ = ($\frac{1}{\sqrt{3}}$)$[1,1,1]^\top$
# x$\cdot \hat{e}$ = ($\frac{1}{\sqrt{3}}$)(4.2 + 3.8 + 4.1) = 12.$\frac{1}{\sqrt{3}}$ ≈ 6.987
#
# proj = 6.987 $\cdot$ ($\frac{1}{\sqrt{3}}$)$[1,1,1]^\top$ ≈ 4.033$[1,1,1]^\top$ = **$[4.033, 4.033, 4.033]^\top$**
#
#
# **1.2**:
#
# noise = x - proj = $[4.2-4.033, 3.8-4.033, 4.1-4.033]^\top$ ≈ **$[0.167, -0.233, 0.067]^\top$**
#
#
# **1.3**:
# Signal power = $\|proj\|^2$ ≈ $3 \cdot 4$.033² ≈ 48.8
# Noise power = $\|noise\|^2$ ≈ 0.028 + 0.054 + 0.004 ≈ 0.086
#
# SNR = 10$\cdot$log₁₀(48.8/0.086) ≈ 10$\cdot$log₁₀(567) ≈ **27.5 dB**
# </details>

# %% [markdown]
# ---
#
# ### Variation F7 (Data Visualization)
# High-dimensional word embeddings in ℝ^(300) need to be visualized in 2D. The first two PCs are $\hat{e}_1$, $\hat{e}_2$.
# Three words have coordinates:
# - "king": x₁ = [...] with x₁$\cdot \hat{e}_1$ = 2.5, x₁$\cdot \hat{e}_2$ = 1.0
# - "queen": x₂ = [...] with x₂$\cdot \hat{e}_1$ = 2.3, x₂$\cdot \hat{e}_2$ = 1.8
# - "man": x₃ = [...] with x₃$\cdot \hat{e}_1$ = 1.0, x₃$\cdot \hat{e}_2$ = 0.5
#
#
# **Part 1.1**: Plot the 2D projections (give coordinates).
#
# **Part 1.2**: In 2D, which two words are closest?
#
# **Part 1.3**: What information is lost in this visualization?

# %% [markdown]
# <details>
# <summary>Solution F7</summary>
#
#
# **1.1**: 2D coordinates:
# - "king": (2.5, 1.0)
# - "queen": (2.3, 1.8)
# - "man": (1.0, 0.5)
#
#
# **1.2**:
# d(king, queen) = $\sqrt{(2.5-2.3}$² + (1.0-1.8)²) = $\sqrt{0.04 + 0.64}$ = $\sqrt{0}$.68 ≈ 0.825
# d(king, man) = $\sqrt{(2.5-1.0}$² + (1.0-0.5)²) = $\sqrt{2.25 + 0.25}$ = $\sqrt{2}$.5 ≈ 1.58
# d(queen, man) = $\sqrt{(2.3-1.0}$² + (1.8-0.5)²) = $\sqrt{1.69 + 1.69}$ = $\sqrt{3}$.38 ≈ 1.84
# **Closest: king and queen**
#
#
# **1.3**: Lost information:
# - Distances in the remaining 298 dimensions
# - The relationship "king - man + woman = queen" might not be visible in 2D
# - Words that are similar in high-D but different in PC1-PC2 appear far apart
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## CATEGORY G: Edge Cases & Tricky Situations

# %% [markdown]
# ---
#
# ### Variation G1 (Zero projection)
# v = $[1, 0]^\top$, x = $[0, 5]^\top$
#
#
# **Part 1.1**: Compute the projection.
#
# **Part 1.2**: What does this mean geometrically?

# %% [markdown]
# <details>
# <summary>Solution G1</summary>
#
#
# **1.1**: $\hat{e}$ = $[1,0]^\top$, x$\cdot \hat{e}$ = 0, proj = 0
#
#
# **1.2**: x is perpendicular to v. The projection is zero because x has no component in the direction of v.
# </details>

# %% [markdown]
# ---
#
# ### Variation G2 (Full projection)
# v = $[2, 4]^\top$, x = $[1, 2]^\top$
#
#
# **Part 1.1**: Compute the projection.
#
# **Part 1.2**: What is the residual?
#
# **Part 1.3**: What does this mean?

# %% [markdown]
# <details>
# <summary>Solution G2</summary>
#
#
# **1.1**: $\|v\|$ = $\sqrt{20}$ = $2\sqrt{5}$, $\hat{e}$ = (1/$2\sqrt{5}$)$[2,4]^\top$ = ($\frac{1}{\sqrt{5}}$)$[1,2]^\top$
# x$\cdot \hat{e}$ = ($\frac{1}{\sqrt{5}}$)(1+4) = $\sqrt{5}$
#
# proj = $\sqrt{5}$ $\cdot$ ($\frac{1}{\sqrt{5}}$)$[1,2]^\top$ = $[1,2]^\top$ = x
#
#
# **1.2**: r = x - proj = 0
#
#
# **1.3**: x is parallel to v (x = $\frac{1}{2}$v). The projection equals x itself.
# </details>

# %% [markdown]
# ---
#
# ### Variation G3 (Negative scalar projection)
# v = $[1, 0]^\top$, x = $[-3, 4]^\top$
#
#
# **Part 1.1**: Compute the scalar projection.
#
# **Part 1.2**: Compute the vector projection.
#
# **Part 1.3**: Interpret the negative sign.

# %% [markdown]
# <details>
# <summary>Solution G3</summary>
#
#
# **1.1**: $\hat{e}$ = $[1,0]^\top$, scalar proj = x$\cdot \hat{e}$ = -3
#
#
# **1.2**: vector proj = -3$[1,0]^\top$ = $[-3, 0]^\top$
#
#
# **1.3**: The negative sign means x points "backwards" relative to $\hat{e}$. The angle between x and $\hat{e}$ is obtuse (> 90°).
# </details>

# %% [markdown]
# ---
#
# ### Variation G4 (Projection onto zero vector - undefined!)
#
# **Part 1.1**: What happens if we try to project x = $[1, 2]^\top$ onto v = $[0, 0]^\top$?
#
# **Part 1.2**: Why is this mathematically undefined?
#
# **Part 1.3**: How would you handle this case in code?

# %% [markdown]
# <details>
# <summary>Solution G4</summary>
#
#
# **1.1**: **The projection is undefined.**
# We would need $\hat{e}$ = v/$\|v\|$ = [0,0]/0, which involves division by zero.
#
#
# **1.2**: Geometrically: The zero vector doesn't define a direction to project onto.
# Algebraically: The projection formula ($x \cdot v$/$\|v\|^2$)v becomes (x$\cdot$0/0)$\cdot$0 = $\frac{0}{0}$, which is indeterminate.
#
#
# **1.3**: In code:
#
# </details>

# %%
def safe_project(x, v):
    norm_sq = np.dot(v, v)
    if norm_sq < 1e-10:  # numerical tolerance
        return np.zeros_like(x)  # or raise an error
    return (np.dot(x, v) / norm_sq) * v

# %% [markdown]
# ---
#
# ### Variation G5 (Nearly parallel vectors - numerical stability)
# v = $[1, 0]^\top$, x = $[1000000, 0.001]^\top$
#
#
# **Part 1.1**: Compute the projection analytically.
#
# **Part 1.2**: What is $\|r\|$/$\|x\|$?
#
# **Part 1.3**: What numerical issues might arise when computing this in floating point?

# %% [markdown]
# <details>
# <summary>Solution G5</summary>
#
#
# **1.1**:
# $\hat{e}$ = $[1, 0]^\top$
# x$\cdot \hat{e}$ = 1000000
#
# proj = 1000000$[1,0]^\top$ = $[1000000, 0]^\top$
#
#
# **1.2**:
#
# r = x - proj = $[0, 0.001]^\top$
#
# $\|r\|$ = 0.001
#
# $\|x\|$ = $\sqrt{10¹² + 10⁻⁶}$ ≈ 10⁶
#
# $\|r\|$/$\|x\|$ ≈ 10⁻⁹ (residual is 1 billionth of the original!)
#
#
# **1.3**: Numerical issues:
# - When computing $\|x\|^2$, we add 10¹² + 10⁻⁶. The small term is lost to floating-point rounding.
# - Subtractive cancellation: x - proj involves subtracting nearly equal large numbers
# - The tiny residual might round to exactly 0 due to limited precision
# - Solution: Use numerically stable orthogonalization (e.g., modified Gram-Schmidt)
# </details>

# %% [markdown]
# ---
#
# ### Variation G6 (Very high dimensions)
# In ℝ^1000, let v = $[1, 1, 1, ..., 1]^\top$ (all ones).
#
#
# **Part 1.1**: What is $\|v\|$?
#
# **Part 1.2**: Let x = eᵢ (the i-th standard basis vector). What is the projection of x onto v?
#
# **Part 1.3**: What is $\|r\|^2$ for this x?
#
# **Part 1.4**: What happens to the fraction $\|proj\|^2$/$\|x\|^2$ as dimension d → ∞?

# %% [markdown]
# <details>
# <summary>Solution G6</summary>
#
#
# **1.1**: $\|v\|$ = $\sqrt{1000}$ ≈ 31.62
#
#
# **1.2**:
# $\hat{e}$ = ($\frac{1}{\sqrt{1000}}$)$[1,1,...,1]^\top$
# eᵢ $\cdot$ $\hat{e}$ = $\frac{1}{\sqrt{1000}}$
#
# proj = ($\frac{1}{\sqrt{1000}}$) $\cdot$ ($\frac{1}{\sqrt{1000}}$)$[1,1,...,1]^\top$ = $\frac{1}{1000} [1,1,...,1]^\top$
#
#
# **1.3**:
#
# $\|proj\|^2$ = $\frac{1}{1000}$² $\cdot$ 1000 = $\frac{1}{1000}$
#
# $\|x\|^2$ = 1
#
# $\|r\|^2$ = $\|x\|^2$ - $\|proj\|^2$ = 1 - 1/1000 = **999/1000**
#
#
# **1.4**:
#
# $\|proj\|^2$/$\|x\|^2$ = 1/d → 0 as d → ∞
#
# Key insight: In high dimensions, almost all of a random vector is orthogonal to any fixed direction! This is the "curse of dimensionality."
# </details>

# %% [markdown]
# ---
#
# ### Variation G7 (Projection of projection)
# Let P be the projection matrix onto $\hat{e}$.
#
#
# **Part 1.1**: What is P(Px)? Simplify.
#
# **Part 1.2**: What is Pⁿx for any positive integer n?
#
# **Part 1.3**: Why does this property make sense geometrically?

# %% [markdown]
# <details>
# <summary>Solution G7</summary>
#
#
# **1.1**: P(Px) = P²x = Px (since P² = P for projection matrices)
#
#
# **1.2**: Pⁿx = Px for all n ≥ 1
#
#
# **1.3**: Once you project a vector onto a subspace, it's already in that subspace. Projecting again doesn't change it. It's like asking "what's the shadow of a shadow?" - it's the same shadow.
# </details>

# %% [markdown]
# ---
#
# ### Variation G8 (Projection preserves linear combinations)
# Let x = 3a + 2b where a = $[1, 0, 1]^\top$ and b = $[0, 1, 0]^\top$. Project onto $\hat{e}$ = ($\frac{1}{\sqrt{2}}$)$[1, 0, 1]^\top$.
#
#
# **Part 1.1**: Compute proj(x) directly.
#
# **Part 1.2**: Compute 3$\cdot$proj(a) + 2$\cdot$proj(b).
#
# **Part 1.3**: Are they equal? What property does this demonstrate?

# %% [markdown]
# <details>
# <summary>Solution G8</summary>
#
#
# **1.1**:
#
# x = $[3, 2, 3]^\top$
# x $\cdot$ $\hat{e}$ = ($\frac{1}{\sqrt{2}}$)(3 + 0 + 3) = $\frac{6}{\sqrt{2}}$ = $3\sqrt{2}$
# proj(x) = $3\sqrt{2}$ $\cdot$ ($\frac{1}{\sqrt{2}}$)$[1,0,1]^\top$ = 3$[1,0,1]^\top$ = $[3, 0, 3]^\top$
#
#
# **1.2**:
# a $\cdot$ $\hat{e}$ = ($\frac{1}{\sqrt{2}}$)(1 + 0 + 1) = $\sqrt{2}$, proj(a) = $\sqrt{2}$ $\cdot$ ($\frac{1}{\sqrt{2}}$)$[1,0,1]^\top$ = $[1,0,1]^\top$
# b $\cdot$ $\hat{e}$ = ($\frac{1}{\sqrt{2}}$)(0 + 0 + 0) = 0, proj(b) = $[0,0,0]^\top$
# 3$\cdot$proj(a) + 2$\cdot$proj(b) = 3$[1,0,1]^\top$ + 0 = $[3, 0, 3]^\top$
#
#
# **1.3**: Yes, they're equal! This demonstrates that projection is a **linear operator**:
# P(αx + βy) = αP(x) + βP(y)
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## CATEGORY H: Coding Implementations (NumPy/PyTorch)

# %% [markdown]
# ---
#
# ### Variation H1 (Basic Projection Function)
# Implement a function to project a vector onto a direction.
#
#
# **Part 1.1**: Write a NumPy function `project(x, v)` that returns the projection of x onto v.
#
# **Part 1.2**: Test with x = [3, 4] and v = [1, 0]. Expected output: [3, 0].
#
# **Part 1.3**: Handle the edge case where v is the zero vector.

# %% [markdown]
# <details>
# <summary>Solution H1</summary>
#
#
# *See code cell below.*
# </details>

# %%
import numpy as np

def project(x, v):
    """Project vector x onto direction v."""
    x = np.asarray(x, dtype=float)
    v = np.asarray(v, dtype=float)

    # Handle zero vector edge case
    v_norm_sq = np.dot(v, v)
    if v_norm_sq < 1e-10:
        return np.zeros_like(x)

    # Projection formula: (x·v / ||v||²) * v
    scalar_proj = np.dot(x, v) / v_norm_sq
    return scalar_proj * v

# Test
x = np.array([3, 4])
v = np.array([1, 0])
print(project(x, v))  # [3. 0.]

# Edge case
print(project(x, [0, 0]))  # [0. 0.]

# %% [markdown]
# ---
#
# ### Variation H2 (Projection Matrix)
#
# **Part 1.1**: Write a function to compute the projection matrix P = vvᵀ/(vᵀv) for a given v.
#
# **Part 1.2**: Verify P² = P (idempotence) numerically.
#
# **Part 1.3**: Verify Pᵀ = P (symmetry) numerically.

# %% [markdown]
# <details>
# <summary>Solution H2</summary>
#
#
# *See code cell below.*
# </details>

# %%
import numpy as np

def projection_matrix(v):
    """Return the projection matrix onto the span of v."""
    v = np.asarray(v, dtype=float).reshape(-1, 1)  # Column vector
    v_norm_sq = (v.T @ v)[0, 0]
    if v_norm_sq < 1e-10:
        return np.zeros((len(v), len(v)))
    return (v @ v.T) / v_norm_sq

# Test
v = np.array([1, 1])
P = projection_matrix(v)
print("P =\n", P)
# [[0.5 0.5]
#  [0.5 0.5]]

# Verify idempotence: P² = P
P_squared = P @ P
print("P² = P?", np.allclose(P_squared, P))  # True

# Verify symmetry: Pᵀ = P
print("Pᵀ = P?", np.allclose(P.T, P))  # True

# %% [markdown]
# ---
#
# ### Variation H3 (Multi-PC Projection)
#
# **Part 1.1**: Given orthonormal vectors U = [u₁, u₂, ...] as columns, write a function to project x onto their span.
#
# **Part 1.2**: Use the formula: proj = U @ Uᵀ @ x (vectorized, no loops).
#
# **Part 1.3**: Test with standard basis vectors projecting onto xy-plane.

# %% [markdown]
# <details>
# <summary>Solution H3</summary>
#
#
# *See code cell below.*
# </details>

# %%
import numpy as np

def project_onto_subspace(x, U):
    """
    Project x onto the subspace spanned by orthonormal columns of U.

    Args:
        x: vector to project (n,)
        U: matrix with orthonormal columns (n, k) where k <= n

    Returns:
        projection of x onto col(U)
    """
    x = np.asarray(x, dtype=float)
    U = np.asarray(U, dtype=float)

    # Projection: P = UUᵀ, so Px = U(Uᵀx)
    return U @ (U.T @ x)

# Test: project onto xy-plane
U = np.array([[1, 0],
              [0, 1],
              [0, 0]], dtype=float)  # e1 and e2 as columns

x = np.array([3, 4, 5])
proj = project_onto_subspace(x, U)
print(proj)  # [3. 4. 0.]

# Verify residual is orthogonal to subspace
r = x - proj
print("Residual orthogonal to U?", np.allclose(U.T @ r, 0))  # True

# %% [markdown]
# ---
#
# ### Variation H4 (Gram-Schmidt Orthogonalization)
# Given vectors v₁ = [1, 1, 0] and v₂ = [1, 0, 1], use projection to create an orthonormal basis.
#
#
# **Part 1.1**: Normalize v₁ to get u₁.
#
# **Part 1.2**: Project v₂ onto u₁ and subtract to get w₂ = v₂ - proj.
#
# **Part 1.3**: Normalize w₂ to get u₂. Verify $u_1 \perp u_2$.

# %% [markdown]
# <details>
# <summary>Solution H4</summary>
#
#
# *See code cell below.*
# </details>

# %%
import numpy as np

def gram_schmidt(vectors):
    """Orthonormalize a list of vectors using Gram-Schmidt."""
    vectors = [np.asarray(v, dtype=float) for v in vectors]
    orthonormal = []

    for v in vectors:
        # Subtract projections onto all previous orthonormal vectors
        w = v.copy()
        for u in orthonormal:
            w = w - np.dot(v, u) * u

        # Normalize if non-zero
        norm = np.linalg.norm(w)
        if norm > 1e-10:
            orthonormal.append(w / norm)

    return orthonormal

# Test
v1 = np.array([1, 1, 0])
v2 = np.array([1, 0, 1])

# Step by step:
u1 = v1 / np.linalg.norm(v1)
print("u1 =", u1)  # [0.707, 0.707, 0]

proj_v2_on_u1 = np.dot(v2, u1) * u1
w2 = v2 - proj_v2_on_u1
u2 = w2 / np.linalg.norm(w2)
print("u2 =", u2)  # [0.408, -0.408, 0.816]

print("u1 · u2 =", np.dot(u1, u2))  # ~0 (orthogonal)

# Using function:
basis = gram_schmidt([v1, v2])
print("Orthonormal basis:", basis)

# %% [markdown]
# ---
#
# ### Variation H5 (PCA from Scratch)
# Implement PCA projection without using sklearn.
#
#
# **Part 1.1**: Given data matrix X (n samples × d features), center it.
#
# **Part 1.2**: Compute covariance matrix and its eigenvectors.
#
# **Part 1.3**: Project data onto top k principal components.

# %% [markdown]
# <details>
# <summary>Solution H5</summary>
#
#
# *See code cell below.*
# </details>

# %%
import numpy as np

def pca_project(X, k):
    """
    Project data X onto its top k principal components.

    Args:
        X: data matrix (n_samples, n_features)
        k: number of principal components

    Returns:
        X_proj: projected data (n_samples, k)
        components: principal component directions (k, n_features)
        explained_var: variance explained by each PC
    """
    X = np.asarray(X, dtype=float)
    n, d = X.shape

    # Step 1: Center the data
    mean = X.mean(axis=0)
    X_centered = X - mean

    # Step 2: Compute covariance matrix
    cov = (X_centered.T @ X_centered) / (n - 1)

    # Step 3: Eigendecomposition
    eigenvalues, eigenvectors = np.linalg.eigh(cov)

    # Sort by eigenvalue (descending)
    idx = np.argsort(eigenvalues)[::-1]
    eigenvalues = eigenvalues[idx]
    eigenvectors = eigenvectors[:, idx]

    # Step 4: Select top k components
    components = eigenvectors[:, :k].T  # (k, d)

    # Step 5: Project
    X_proj = X_centered @ components.T  # (n, k)

    explained_var = eigenvalues[:k] / eigenvalues.sum()

    return X_proj, components, explained_var

# Test with simple data
np.random.seed(42)
X = np.random.randn(100, 3)
X[:, 0] = X[:, 0] * 5  # First feature has high variance

X_proj, components, explained = pca_project(X, k=2)
print(f"Projected shape: {X_proj.shape}")  # (100, 2)
print(f"Explained variance: {explained}")  # First PC explains most

# %% [markdown]
# ---
#
# ### Variation H6 (PyTorch Implementation)
# Implement projection using PyTorch tensors with gradient support.
#
#
# **Part 1.1**: Create a differentiable projection function.
#
# **Part 1.2**: Compute gradients of $\|proj(x, v)\|^2$ with respect to x.
#
# **Part 1.3**: Verify the gradient analytically.

# %% [markdown]
# <details>
# <summary>Solution H6</summary>
#
#
# *See code cell below.*
# </details>

# %%
import torch

def project_torch(x, v):
    """
    Differentiable projection of x onto v.
    """
    v_norm_sq = torch.dot(v, v)
    if v_norm_sq < 1e-10:
        return torch.zeros_like(x)
    scalar_proj = torch.dot(x, v) / v_norm_sq
    return scalar_proj * v

# Test with gradients
x = torch.tensor([3.0, 4.0], requires_grad=True)
v = torch.tensor([1.0, 0.0])  # Project onto x-axis

proj = project_torch(x, v)
print("Projection:", proj)  # tensor([3., 0.])

# Compute gradient of ||proj||² w.r.t. x
loss = torch.sum(proj ** 2)  # ||proj||² = 9
loss.backward()

print("Gradient d(||proj||²)/dx:", x.grad)  # tensor([6., 0.])

# Analytical verification:
# proj = (x·v/||v||²)v = x₁[1,0] for v = [1,0]
# ||proj||² = x₁²
# d(x₁²)/dx = [2x₁, 0] = [6, 0] ✓

# %% [markdown]
# ---
#
# ### Variation H7 (Vectorized Batch Projection)
# Project multiple vectors simultaneously (batch operation).
#
#
# **Part 1.1**: Given X (n × d) and v (d,), project all rows of X onto v.
#
# **Part 1.2**: Implement without loops using broadcasting.
#
# **Part 1.3**: Compare performance with loop-based version.

# %% [markdown]
# <details>
# <summary>Solution H7</summary>
#
#
# *See code cell below.*
# </details>

# %%
import numpy as np
import time

def project_batch_loop(X, v):
    """Project each row of X onto v using a loop."""
    v_norm_sq = np.dot(v, v)
    result = np.zeros_like(X)
    for i in range(len(X)):
        scalar = np.dot(X[i], v) / v_norm_sq
        result[i] = scalar * v
    return result

def project_batch_vectorized(X, v):
    """Project each row of X onto v using vectorization."""
    v = v.reshape(1, -1)  # (1, d)
    v_norm_sq = np.sum(v ** 2)
    scalars = (X @ v.T) / v_norm_sq  # (n, 1)
    return scalars * v  # (n, d) via broadcasting

# Test
np.random.seed(42)
X = np.random.randn(10000, 100)  # 10k vectors in R^100
v = np.random.randn(100)

# Correctness check
proj_loop = project_batch_loop(X, v)
proj_vec = project_batch_vectorized(X, v)
print("Results match:", np.allclose(proj_loop, proj_vec))  # True

# Performance comparison
start = time.time()
for _ in range(10):
    _ = project_batch_loop(X, v)
print(f"Loop: {time.time() - start:.3f}s")

start = time.time()
for _ in range(10):
    _ = project_batch_vectorized(X, v)
print(f"Vectorized: {time.time() - start:.3f}s")
# Vectorized is typically 10-100x faster!

# %% [markdown]
# ---

# %% [markdown]
# ## CATEGORY I: Proofs & Derivations

# %% [markdown]
# ---
#
# ### Variation I1 (Derive the Projection Formula)
#
# **Part 1.1**: Starting from "minimize $\|x - αv\|^2$", derive that $\alpha$ = ($x \cdot v$)/($v \cdot v$).
#
# **Part 1.2**: Why does minimizing distance give us the projection?
#
# **Part 1.3**: Show this is equivalent to requiring $r \perp v$.

# %% [markdown]
# <details>
# <summary>Solution I1</summary>
#
#
# **1.1**: We want to minimize f($\alpha$) = $\|x - αv\|^2$
#
# f($\alpha$) = (x - αv)$\cdot$(x - αv) = $x \cdot x$ - 2α($x \cdot v$) + α²($v \cdot v$)
#
# Take derivative and set to zero:
# df/dα = -2($x \cdot v$) + 2α($v \cdot v$) = 0
# $\alpha$ = ($x \cdot v$)/($v \cdot v$) ✓
#
# Second derivative: d²f/dα² = 2($v \cdot v$) > 0 (assuming v≠0), so this is indeed a minimum.
#
#
# **1.2**: The projection onto a line is defined as the closest point on that line. "Closest" means minimum distance, hence minimizing $\|x - proj\|$.
#
#
# **1.3**:
#
# r = x - αv is orthogonal to v when $r \cdot v$ = 0:
# $r \cdot v$ = (x - αv)$\cdot$v = $x \cdot v$ - $\alpha$($v \cdot v$) = 0
# $\alpha$ = ($x \cdot v$)/($v \cdot v$)
#
# This is the same formula! The geometric requirement (orthogonality) and the optimization requirement (minimum distance) give the same answer—because the shortest path to a line is perpendicular to it.
# </details>

# %% [markdown]
# ---
#
# ### Variation I2 (Prove Pythagorean Theorem for Projections)
#
# **Part 1.1**: Let proj = (x$\cdot \hat{e}$)$\hat{e}$ and r = x - proj. Prove $\|x\|^2$ = $\|proj\|^2$ + $\|r\|^2$.
#
# **Part 1.2**: What does this say about the relationship between total, explained, and unexplained variance?
#
# **Part 1.3**: Generalize to k orthogonal projections.

# %% [markdown]
# <details>
# <summary>Solution I2</summary>
#
#
# **1.1**:
#
# $\|x\|^2$ = $x \cdot x$ = (proj + r)$\cdot$(proj + r)
# = $proj \cdot proj$ + 2($proj \cdot r$) + $r \cdot r$
# = $\|proj\|^2$ + 2($proj \cdot r$) + $\|r\|^2$
#
# Now, $proj \cdot r$ = [(x$\cdot \hat{e}$)$\hat{e}$]$\cdot$r = (x$\cdot \hat{e}$)($\hat{e} \cdot$r)
#
# Since r = x - (x$\cdot \hat{e}$)$\hat{e}$, we have:
# $\hat{e} \cdot$r = $\hat{e} \cdot$x - (x$\cdot \hat{e}$)($\hat{e} \cdot$$\hat{e}$) = x$\cdot \hat{e}$ - x$\cdot \hat{e}$ = 0
#
# Therefore: $proj \cdot r$ = 0, and:
#
# $\|x\|^2$ = $\|proj\|^2$ + $\|r\|^2$ ✓
#
#
# **1.2**: In statistics:
# - $\|x\|^2$ ↔ total variance
# - $\|proj\|^2$ ↔ explained variance (by the model/PC)
# - $\|r\|^2$ ↔ residual/unexplained variance
#
# The Pythagorean theorem says: Total = Explained + Unexplained
#
#
# **1.3**: For orthonormal {$\hat{e}_1$, ..., êₖ}:
#
# $\|x\|^2$ = Σᵢ (x$\cdot$êᵢ)² + $\|r\|^2$
#
# where r = x - Σᵢ (x$\cdot$êᵢ)êᵢ
#
# Each term (x$\cdot$êᵢ)² represents variance along the i-th direction.
# </details>

# %% [markdown]
# ---
#
# ### Variation I3 (Prove Projection Matrix Properties)
# Let P = UUᵀ where U has orthonormal columns.
#
#
# **Part 1.1**: Prove P² = P (idempotence).
#
# **Part 1.2**: Prove Pᵀ = P (symmetry).
#
# **Part 1.3**: Prove rank(P) = number of columns in U.

# %% [markdown]
# <details>
# <summary>Solution I3</summary>
#
#
# **1.1**: P² = (UUᵀ)(UUᵀ) = U(UᵀU)Uᵀ
#
# Since U has orthonormal columns: UᵀU = I
#
# Therefore: P² = UIUᵀ = UUᵀ = P ✓
#
#
# **1.2**: Pᵀ = (UUᵀ)ᵀ = (Uᵀ)ᵀUᵀ = UUᵀ = P ✓
#
#
# **1.3**:
# - rank(P) = rank(UUᵀ)
# - For any matrices A, B: rank(AB) ≤ min(rank(A), rank(B))
# - rank(P) ≤ rank(U) = k (number of columns, since columns are linearly independent)
# - Also: Pu = UUᵀu for each column u of U gives Pu = u (since UᵀU = I means Uᵀu = eᵢ for i-th column)
# - So the k columns of U are eigenvectors of P with eigenvalue 1
# - Since P is symmetric, remaining n-k eigenvectors have eigenvalue 0
# - rank(P) = number of non-zero eigenvalues = k ✓
# </details>

# %% [markdown]
# ---
#
# ### Variation I4 (Prove Best Approximation Property)
#
# **Part 1.1**: Prove that for any vector y in the subspace W, $\|x - proj_W(x)\|$ ≤ $\|x - y\|$.
#
# **Part 1.2**: When does equality hold?
#
# **Part 1.3**: Why is this called the "best approximation theorem"?

# %% [markdown]
# <details>
# <summary>Solution I4</summary>
#
#
# **1.1**: Let p = proj_W(x) and r = x - p (residual).
#
# For any $y \in W$:
#
# $\|x - y\|^2$ = $\|(x - p) + (p - y)\|^2$ = $\|r + (p - y)\|^2$
#
# Since $r \perp W$ and (p - y) $\in$ W, we have $r \perp (p - y)$, so:
#
# $\|r + (p - y)\|^2$ = $\|r\|^2$ + $\|p - y\|^2$ (Pythagorean theorem)
#
# Therefore:
#
# $\|x - y\|^2$ = $\|x - p\|^2$ + $\|p - y\|^2$ ≥ $\|x - p\|^2$ ✓
#
# Taking square roots: $\|x - y\|$ ≥ $\|x - p\|$
#
#
# **1.2**: Equality holds when $\|p - y\|$ = 0, i.e., when y = p = proj_W(x).
#
#
# **1.3**: The projection is the "best approximation" of x by vectors in W, where "best" means minimum Euclidean distance. Among all vectors in W, the projection is uniquely closest to x.
#
# This is fundamental to:
# - Least squares regression (best linear fit)
# - PCA (best low-rank approximation)
# - Signal processing (best approximation in subspace)
# </details>

# %% [markdown]
# ---
#
# ### Variation I5 (Derive Normal Equations via Projection)
# In linear regression, we want to find $\beta$ that minimizes $\|y - Xβ\|^2$.
#
#
# **Part 1.1**: Interpret this as projecting y onto the column space of X.
#
# **Part 1.2**: Show that the residual r = y - Xβ must satisfy Xᵀr = 0.
#
# **Part 1.3**: Derive the normal equations: XᵀXβ = Xᵀy.

# %% [markdown]
# <details>
# <summary>Solution I5</summary>
#
#
# **1.1**: The column space of X, col(X), is all vectors of form Xβ for some $\beta$. Finding $\beta$ to minimize $\|y - Xβ\|$ means finding the point Xβ* in col(X) closest to y—this is the projection of y onto col(X).
#
#
# **1.2**: The residual r = y - Xβ* must be orthogonal to col(X). Since col(X) is spanned by the columns of X, r must be orthogonal to each column:
#
# xⱼᵀr = 0 for all columns xⱼ
#
# In matrix form: Xᵀr = 0
#
#
# **1.3**: Substituting r = y - Xβ:
# Xᵀ(y - Xβ) = 0
# Xᵀy - XᵀXβ = 0
# **XᵀXβ = Xᵀy** ✓
#
# If XᵀX is invertible: $\beta$ = (XᵀX)⁻¹Xᵀy
#
# This is the projection formula in disguise:
# - P = X(XᵀX)⁻¹Xᵀ is the projection matrix onto col(X)
# - ŷ = Py = X(XᵀX)⁻¹Xᵀy = Xβ
# </details>

# %% [markdown]
# ---
#
# ### Variation I6 (Eigenvalue Proof)
#
# **Part 1.1**: Prove that the eigenvalues of a projection matrix are 0 and 1 only.
#
# **Part 1.2**: How many eigenvalues equal 1?
#
# **Part 1.3**: What are the corresponding eigenvectors?

# %% [markdown]
# <details>
# <summary>Solution I6</summary>
#
#
# **1.1**: Let Pv = λv for some eigenvector v ≠ 0.
#
# Apply P again:
# P²v = P(λv) = λPv = λ²v
#
# But P² = P (idempotence), so:
#
# Pv = λ²v
#
# Therefore: λv = λ²v, which gives ($\lambda$ - λ²)v = 0.
#
# Since v ≠ 0: $\lambda$ - λ² = 0, so $\lambda$(1 - $\lambda$) = 0.
#
# Therefore: **$\lambda$ = 0 or $\lambda$ = 1** ✓
#
#
# **1.2**: The number of eigenvalues equal to 1 equals rank(P) = dim(range(P)) = dimension of the subspace being projected onto.
#
# For projection onto a k-dimensional subspace in ℝⁿ:
# - k eigenvalues equal to 1
# - n-k eigenvalues equal to 0
#
#
# **1.3**:
# - $\lambda$ = 1: eigenvectors are any vectors in the range of P (the subspace). These are fixed by projection.
# - $\lambda$ = 0: eigenvectors are any vectors in the null space of P (orthogonal complement). These are annihilated by projection.
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## CATEGORY J: Advanced Topics

# %% [markdown]
# ---
#
# ### Variation J1 (Oblique Projection)
# An **oblique projection** projects onto subspace W along a direction that is NOT perpendicular to W.
#
# Let W = span{$[1, 0]^\top$} and project along direction d = $[1, 1]^\top$ (not perpendicular to W).
#
#
# **Part 1.1**: For x = $[0, 2]^\top$, find the oblique projection onto W along d.
#
# **Part 1.2**: Compare with the orthogonal projection.
#
# **Part 1.3**: Is the oblique projection matrix idempotent?

# %% [markdown]
# <details>
# <summary>Solution J1</summary>
#
#
# **1.1**: The oblique projection of x finds the unique point $p \in W$ such that (x - p) is parallel to d.
#
#
# p = $\alpha [1, 0]^\top$ for some $\alpha$ (since $p \in W$)
# x - p = $[0, 2]^\top$ - $[\alpha, 0]^\top$ = $[-\alpha, 2]^\top$
#
# For this to be parallel to d = $[1, 1]^\top$:
# [-$\alpha$, 2] = $\beta$[1, 1] for some $\beta$
# -$\alpha$ = $\beta$ and 2 = $\beta$, so $\beta$ = 2, $\alpha$ = -2
#
#
# p = -2$[1, 0]^\top$ = **$[-2, 0]^\top$**
#
#
# **1.2**: Orthogonal projection:
# $\hat{e}$ = $[1, 0]^\top$
# x $\cdot$ $\hat{e}$ = 0
#
# proj_orthogonal = 0 $\cdot$ $[1, 0]^\top$ = **$[0, 0]^\top$**
#
# The oblique projection is $[-2, 0]^\top$ while the orthogonal projection is $[0, 0]^\top$!
#
#
# **1.3**: Yes, oblique projections are still idempotent (P² = P). Once you project onto W, applying the projection again doesn't change anything—the point is already in W.
#
# However, oblique projections are NOT symmetric (P ≠ Pᵀ) in general.
# </details>

# %% [markdown]
# ---
#
# ### Variation J2 (Projection onto Affine Subspace)
# Project x = $[3, 3, 3]^\top$ onto the plane x + y + z = 6 (not through origin!).
#
#
# **Part 1.1**: Find a point p₀ on the plane and the normal vector n.
#
# **Part 1.2**: Compute the projection.
#
# **Part 1.3**: Why can't we use the standard P = UUᵀ formula directly?

# %% [markdown]
# <details>
# <summary>Solution J2</summary>
#
#
# **1.1**:
# - Point on plane: p₀ = $[6, 0, 0]^\top$ (setting y=z=0)
# - Normal vector: n = $[1, 1, 1]^\top$ (coefficients of x+y+z=6)
#
#
# **1.2**:
# First, translate so the plane passes through origin:
# x' = x - p₀ = $[3, 3, 3]^\top$ - $[6, 0, 0]^\top$ = $[-3, 3, 3]^\top$
#
# Project onto the plane (= reject from normal direction):
#
# $\|n\|$ = $\sqrt{3}$, $\hat{e}$ = ($\frac{1}{\sqrt{3}}$)$[1, 1, 1]^\top$
# x' $\cdot$ $\hat{e}$ = ($\frac{1}{\sqrt{3}}$)(-3 + 3 + 3) = $\frac{3}{\sqrt{3}}$ = $\sqrt{3}$
#
# proj_onto_n = $\sqrt{3}$ $\cdot$ ($\frac{1}{\sqrt{3}}$)$[1, 1, 1]^\top$ = $[1, 1, 1]^\top$
#
# Projection onto plane (orthogonal complement of n):
# x'_plane = x' - proj_onto_n = $[-3, 3, 3]^\top$ - $[1, 1, 1]^\top$ = $[-4, 2, 2]^\top$
#
# Translate back:
#
# proj = x'_plane + p₀ = $[-4, 2, 2]^\top$ + $[6, 0, 0]^\top$ = **$[2, 2, 2]^\top$**
#
# Verify: 2 + 2 + 2 = 6 ✓ (on the plane)
#
#
# **1.3**: P = UUᵀ only works for linear subspaces (through origin). An affine subspace (like x+y+z=6) requires translation. The formula becomes:
# proj_affine(x) = p₀ + P_linear(x - p₀)
# </details>

# %% [markdown]
# ---
#
# ### Variation J3 (Projection onto Convex Set)
# Project x = $[3, 3]^\top$ onto the unit ball B = {y : $\|y\|$ ≤ 1}.
#
#
# **Part 1.1**: Is x inside B?
#
# **Part 1.2**: Find the projection.
#
# **Part 1.3**: Give the general formula for projection onto a ball of radius r centered at origin.

# %% [markdown]
# <details>
# <summary>Solution J3</summary>
#
#
# **1.1**: $\|x\|$ = $\sqrt{9 + 9}$ = $\sqrt{18}$ ≈ 4.24 > 1
# No, x is outside B.
#
#
# **1.2**: The projection onto a convex set is the closest point in the set. For a ball, this is the point on the boundary in the direction of x:
#
#
# proj = x / $\|x\|$ = $[3, 3]^\top$ / $\sqrt{18}$ = ($\frac{1}{\sqrt{18}}$)$[3, 3]^\top$ = **$[$\frac{1}{$\sqrt{2}$}$, $\frac{1}{$\sqrt{2}$}$]^\top$ ≈ $[0.707, 0.707]^\top$**
#
#
# **1.3**: General formula for ball of radius r:
#
# proj_B(x) =
# - x if $\|x\|$ ≤ r (inside ball: no change)
# - $r \cdot x$/$\|x\|$ if $\|x\|$ > r (outside: project to boundary)
#
# Or compactly: proj_B(x) = min(1, r/$\|x\|$) $\cdot$ x
#
# This is used in gradient clipping for neural networks!
# </details>

# %% [markdown]
# ---
#
# ### Variation J4 (Householder Reflection)
# A Householder reflection reflects vectors across a hyperplane with normal n.
#
#
# **Part 1.1**: The Householder matrix is H = I - 2nnᵀ (for unit n). Show H² = I.
#
# **Part 1.2**: Show H = I - 2P where P is the projection onto span{n}.
#
# **Part 1.3**: For n = ($\frac{1}{\sqrt{2}}$)$[1, 1]^\top$, apply H to x = $[1, 0]^\top$.

# %% [markdown]
# <details>
# <summary>Solution J4</summary>
#
#
# **1.1**:
# H² = (I - 2nnᵀ)(I - 2nnᵀ)
# = I - 2nnᵀ - 2nnᵀ + 4nnᵀnnᵀ
# = I - 4nnᵀ + 4n(nᵀn)nᵀ
# = I - 4nnᵀ + 4nnᵀ (since nᵀn = 1 for unit n)
# = I ✓
#
#
# **1.2**:
#
# P = nnᵀ (projection onto span{n})
# I - 2P = I - 2nnᵀ = H ✓
#
# Interpretation: H = I - 2P means "subtract twice the projection onto n", which reflects across the hyperplane perpendicular to n.
#
#
# **1.3**:
#
# n = ($\frac{1}{\sqrt{2}}$)$[1, 1]^\top$
# nnᵀ = $\frac{1}{2}$[[1, 1], [1, 1]]
#
# H = I - 2$\frac{1}{2}$[[1, 1], [1, 1]] = [[1,0],[0,1]] - [[1,1],[1,1]] = [[0, -1], [-1, 0]]
#
#
# Hx = [[0, -1], [-1, 0]] $\cdot$ $[1, 0]^\top$ = **$[0, -1]^\top$**
#
# Geometric check: x = [1, 0] reflected across the line y = x (perpendicular to n) gives [0, 1]... wait, we got [0, -1].
#
# Actually, the hyperplane perpendicular to [1,1] is the line x + y = 0 (through origin), which is y = -x. Reflecting [1, 0] across y = -x gives [0, -1] ✓
# </details>

# %% [markdown]
# ---
#
# ### Variation J5 (QR Decomposition via Projections)
# Use Gram-Schmidt to decompose A = [[1, 1], [1, 2], [0, 1]] into A = QR.
#
#
# **Part 1.1**: Find Q (orthonormal columns).
#
# **Part 1.2**: Find R (upper triangular).
#
# **Part 1.3**: Verify A = QR.

# %% [markdown]
# <details>
# <summary>Solution J5</summary>
#
#
# **1.1**: Apply Gram-Schmidt to columns of A.
#
# a₁ = $[1, 1, 0]^\top$
#
# $\|a₁\|$ = $\sqrt{2}$
# q₁ = ($\frac{1}{\sqrt{2}}$)$[1, 1, 0]^\top$
#
# a₂ = $[1, 2, 1]^\top$
#
# proj = (a₂ $\cdot$ q₁)q₁ = ($\frac{1}{\sqrt{2}}$)(1+2+0) $\cdot$ ($\frac{1}{\sqrt{2}}$)$[1,1,0]^\top$ = $\frac{3}{2} [1, 1, 0]^\top$
# w₂ = a₂ - proj = $[1, 2, 1]^\top$ - $[3/2, 3/2, 0]^\top$ = $[-1/2, 1/2, 1]^\top$
#
# $\|w₂\|$ = $\sqrt{1/4 + 1/4 + 1}$ = $\sqrt{3/2}$ = $\sqrt{6}$/2
# q₂ = ($\frac{2}{\sqrt{6}}$)$[-1/2, 1/2, 1]^\top$ = ($\frac{1}{\sqrt{6}}$)$[-1, 1, 2]^\top$
#
#
# Q = [[$\frac{1}{\sqrt{2}}$, -$\frac{1}{\sqrt{6}}$], [$\frac{1}{\sqrt{2}}$, $\frac{1}{\sqrt{6}}$], [0, $\frac{2}{\sqrt{6}}$]]
#
#
# **1.2**: R = QᵀA (since A = QR implies QᵀA = QᵀQR = R for orthogonal Q)
#
# r₁₁ = q₁ $\cdot$ a₁ = $\sqrt{2}$
# r₁₂ = q₁ $\cdot$ a₂ = ($\frac{1}{\sqrt{2}}$)(1+2+0) = $\frac{3}{\sqrt{2}}$
# r₂₂ = q₂ $\cdot$ a₂ = ($\frac{1}{\sqrt{6}}$)(-1+2+2) = $\frac{3}{\sqrt{6}}$ = $\sqrt{6}$/2
#
#
# R = [[$\sqrt{2}$, $\frac{3}{\sqrt{2}}$], [0, $\sqrt{6}$/2]]
#
#
# **1.3**: Verify QR = A (numerical check omitted for brevity, but can be verified by matrix multiplication)
# </details>

# %% [markdown]
# ---

# %% [markdown]
# ## KEY FORMULAS SUMMARY

# %% [markdown]
# ### Basic Projection
#
# | Concept | Formula |
# |---------|---------|
# | Unit vector | $\hat{e}$ = v / $\|\|$v$\|\|$ |
# | Scalar projection $| x $\cdot$ $\hat{e}$ |$
# | Vector projection | (x $\cdot$ $\hat{e}$)$\hat{e}$ |
# | Projection matrix (1D) | P = êêᵀ |
# | Residual | r = x - Px = (I - êêᵀ)x |
# | Pythagorean theorem $| \|$\|x\|$\|² = \|$\|proj\|$\|² + \|$\|r\|$\|² |$
# | Orthogonality check | r $\cdot$ $\hat{e}$ = 0 |

# %% [markdown]
# ### Multi-Component Projection
#
# | Concept | Formula |
# |---------|---------|
# | Multi-PC projection | Σᵢ (x $\cdot$ êᵢ)êᵢ |
# | Projection matrix (subspace) | P = UUᵀ (U has orthonormal columns) |
# | Reconstruction | x̂ₖ = Uₖ Uₖᵀ x |
# | Explained variance ratio | Σᵢ₌₁ᵏ λᵢ / Σⱼ λⱼ |

# %% [markdown]
# ### Projection Matrix Properties
#
# | Property | Condition |
# |----------|-----------|
# | Idempotence | P² = P |
# | Symmetry | Pᵀ = P |
# | Eigenvalues | $\lambda$ $\in$ {0, 1} only |
# | Rank | rank(P) = dim(subspace) = trace(P) |
# | Complement | I - P projects onto orthogonal complement |

# %% [markdown]
# ### Advanced Formulas
#
# | Concept | Formula |
# |---------|---------|
# | Normal equations | XᵀXβ = Xᵀy |
# | Least squares projection | P = X(XᵀX)⁻¹Xᵀ |
# | Householder reflection | H = I - 2nnᵀ |
# | Affine projection | p₀ + P_linear(x - p₀) |
# | Ball projection | min(1, r/$\|\|$x$\|\|$) $\cdot$ x |

# %% [markdown]
# ### NumPy Quick Reference

# %%
# Basic projection
def project(x, v):
    return (np.dot(x, v) / np.dot(v, v)) * v

# Projection matrix
P = np.outer(v, v) / np.dot(v, v)

# Subspace projection (U has orthonormal columns)
proj = U @ (U.T @ x)

# PCA projection
X_centered = X - X.mean(axis=0)
_, _, Vt = np.linalg.svd(X_centered)
X_proj = X_centered @ Vt[:k].T
