# %% [markdown]
# # **Problem 1**
#
# Let us consider the following sequence:
#
# $$
# F_n = F_{n-1} + F_{n-2} , \ \forall \ n \geq 2 .
# $$
#
# The initial conditions are $F_0 = 0$ and $F_1 = 1$.

# %% [markdown]
# ## **Part 1 (5 points, non-coding task)**
#
# **Manually write down $F_n$ for $n = 2, 3, \cdots , 10$.**
#
# * Reasoning is not required.

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 2 (5 points, non-coding task)**
#
# The recursive equation that defines the sequence in this problem can be written in a matrix form:
#
# $$
# \begin{bmatrix}
# F_n \\
# F_{n-1}
# \end{bmatrix}
# = \mathbf{A}
# \begin{bmatrix}
# F_{n-1} \\
# F_{n-2}
# \end{bmatrix}, \ \forall \ n \geq 2 ,
# $$
#
# where $\mathbf{A} \in \Bbb R^{2 \times 2}$.
#
# **Compute $\mathbf{A}$?**
#
# * Reasoning is not required.
#
# * The value of each entry in $\mathbf{A}$ must be exact. For instance, the following values are exact: $\sqrt{3}$, $\frac{2}{\sqrt{7}}$, $\pi + \frac{3}{8}$, $e^2$, $\sin 40^\circ$, $\log 18$. However, their float approximations are not exact.

# %% [markdown]
# $\color{green}{\text{WRITE YOUR SOLUTION IN THIS TEXT CELL.}}$

# %% [markdown]
# ## **Part 3 (5 points, non-coding task)**
#
# In the following eigenvalue equation
#
# $$
# \mathbf{A} \mathbf{x} = \lambda \mathbf{x} ,
# $$
#
# **compute two eigenvalues $\lambda_0$ and $\lambda_1$ whose values are in a descending order.**
#
# * Reasoning is required.

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 4 (5 points, non-coding task)**
#
# **For each eigenvalue $\lambda_i$ with $i \in \left\{ 0, 1 \right\}$, compute its associated eigenvector.**
#
# * Reasoning is required.
#
# * Since an eigenvector that is arbitrarily scaled by a scalar is still an eigenvector, to keep your answer simple, write each eigenvector associated with eigenvalue $\lambda_i$ as a polynomial function of $\lambda_i$ with all integer coefficients.

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 5 (5 points, non-coding task)**
#
# **Please do the eigendecomposition of matrix $\mathbf{A}$.** That is, you should write $\mathbf{A}$ is the following form:
#
# $$
# \mathbf{A} = \mathbf{Q} \mathbf{\Lambda} \mathbf{Q}^{-1} ,
# $$
#
# where
#
# * $\mathbf{Q} \in \Bbb R^{2 \times 2}$
#
# * $\mathbf{\Lambda} = \begin{bmatrix} \lambda_0 & 0 \\ 0 & \lambda_1 \end{bmatrix} \in \Bbb R^{2 \times 2}$ is a diagnomal matrix with $\lambda_0 > \lambda_1$
#
# Note:
#
# * Reasoning is required.
#
# * You need to compute three things: $\mathbf{Q}$, $\mathbf{\Lambda}$, $\mathbf{Q}^{-1}$.

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 6 (5 points, non-coding task)**
#
# **Use the eigendecomposition result from Part 5 to derive a closed form of $F_{n}$ for any $n \in \left\{ 0, 1, \cdots \right\}$.**
#
# * Reasoning is required.
#
# * Your answer shall be written in terms of one or two eigenvalues.

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 7 (5 points, non-coding task)**
#
# **Compute**
#
# $$
# \lim_{n \rightarrow \infty} \ \frac{F_n}{F_{n-1}} .
# $$
#
# * Reasoning is required.
#
# * Your answer shall be written in terms of one or two eigenvalues.

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# ## **Part 8 (20 points, coding task)**
#
# **Define a class called `My_Fib`.**
#
# * Attributes: $ $
#
#     * `Q`: This attribute is matrix $\mathbf{Q}$ computed above. It is a numpy array with shape `(2,2)`. The date type is float32.
#
#     * `Q_inv`: This attribute is matrix $\mathbf{Q}^{-1}$ computed above. It is a numpy array with shape `(2,2)`. The date type is float32.
#
#     * `lambdas`: This attribute is a numpy array with shape `(2,)` that includes two eigenvalues computed above. The date type is float32.
#
# * Method `__init__` **(5 points)**:
#
#     * All atttribute values shall be initialized when an object in this class is constructed.
#
# * Method `compute_fib` **(10 points)**:
#
#     * This method computes the sequence values on designated indices.
#
#     * You must use the eigendecomposition result to write this method.
#
#     * You are not allowed to use any `for` loop.
#
#     * Inputs:
#
#         * `f0`: The value of $F_0$
#
#         * `f1`: The value of $F_1$
#
#         * `indices`: a list/tuple/range object that includes indices with which the sequence values shall be computed.
#
#         For instance, if `indices` takes the value `[3, 5, 9]`, we need to compute $F_3$, $F_5$, $F_9$.
#
#         In our test cases, you are guaranteed that `len(indices)` is at least 1. You do not need to worry about the size of the test cases or whether the sequence values are too big (that is, on your side, you do not need to worry about those corner cases).
#
#     * Outputs:
#
#         * Return a numpy array `fib_values` with shape `(len(indices),)`.
#
#         * `fib_values[i]` takes the value of $F_{indices[i]}$.
#
#         For instance, if `indices` takes the value `[3, 5, 9]`, then `fib_values` has shape `(3,)`. The values of `fib_values[0]`, `fib_values[1]`, `fib_values[2]` are $F_3$, $F_5$, $F_9$, respectively.
#
# * Method `plot_fib` **(5 points)**:
#
#     * This method plots indices vs. sequence values on those indices
#
#     * Inputs: The same as the method `compute_fib(f0, f1, *indices)`
#
#     * Outputs: None
#
#     * In your plot,
#
#         * All data points with input indices are with marker `x`.
#
#         * The linestyle is `--`.
#
#         * The color is red.
#
#         * The x-lable is: $n$.
#
#         * The y-label is: $F_n$.
#
#         * The title is: Fibounacci sequence.

# %%
### Run the following code ###

"""DO NOT MAKE ANY CHANGE"""
import numpy as np
import matplotlib.pyplot as plt

""" WARNING: DO NOT IMPORT ANY ADDITIONAL LIBRARIES/MODULES/CLASSES/FUNCTIONS """

# %%
### WRITE YOUR SOLUTION HERE ###



class My_Fib:
    def __init__(# INSERT YOUR INPUT ARGUMENTS HERE):
        ### WRITE YOUR SOLUTION HERE ###

        """ END OF THIS PART """

    def compute_fib(# INSERT YOUR INPUT ARGUMENTS HERE):
        ### WRITE YOUR SOLUTION HERE ###

        """ END OF THIS PART """

    def plot_fib(# INSERT YOUR INPUT ARGUMENTS HERE):
        ### WRITE YOUR SOLUTION HERE ###

        """ END OF THIS PART """

# %% [markdown]
# ## **Part 9 (5 points, coding task)**
#
# This part follows from Part 8.
#
# Define an object of the class `My_Fib`.
#
# * Initialize the values of all attributes with your calculated eigenvalues and matrices $\mathbf{Q}$ and $\mathbf{Q}^{-1}$.

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# **END OF THIS PROBLEM**
