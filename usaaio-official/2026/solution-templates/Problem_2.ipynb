# %% [markdown]
# # **Problem 2, Part 1**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 2, Part 2**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 2, Part 3**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$
