# %% [markdown]
# # **Your solution**
#
# **This is an open problem. Please feel free to use as many text and code cells as needed.**
#
# **During grading, we will run your entire notebook.**

# %% [markdown]
# # **Your report**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR REPORT HERE ###}}$
#
#
# $\color{red}{\text{""" END OF YOUR REPORT """}}$
