# %% [markdown]
# # **Starter code**

# %%
# Paste the starter code provided in this problem. Run it.

# %% [markdown]
# # **Problem 5, Part 1**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 2**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 3**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 5, Part 4**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 5, Part 5**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 6**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 7**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 5, Part 8**

# %% [markdown]
# **Part 8.1 (coding task)**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# **Part 8.2 (non-coding task)**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 9**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 5, Part 10**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 11**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 5, Part 12**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """

# %% [markdown]
# # **Problem 5, Part 13**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 14**

# %% [markdown]
# $\color{green}{\text{### WRITE YOUR SOLUTION HERE ###}}$
#
#
# $\color{red}{\text{""" END OF THIS PART """}}$

# %% [markdown]
# # **Problem 5, Part 15**

# %%
### WRITE YOUR SOLUTION HERE ###


""" END OF THIS PART """
